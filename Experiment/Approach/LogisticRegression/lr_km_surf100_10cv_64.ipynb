# %% [markdown]
# # Setup

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from random import randint
import math
from datetime import datetime
import pickle

from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import roc_curve
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_curve
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score

# %%
os.getcwd()
# Out:
# 'D:\\Github\\Stomach-Status-Classification\\Experiment\\Approach\\LogisticRegression'

# %%
for i in range(3):
    os.chdir("..")

# %%
os.getcwd()
# Out:
# 'D:\\Github\\Stomach-Status-Classification'

# %%
main_data_dir = os.getcwd() + "\\Data set"
kmean_data_dir = main_data_dir + "\\kmean_dataset"
kmean_data_10cv_dir = kmean_data_dir + "\\10cv_64"
import glob

kmean_data_10cv_lst = [x for x in glob.glob(kmean_data_10cv_dir + '\\*') if 'surf_train_100' in x or 'surf_test_100' in x and 'index' in x]
print(kmean_data_10cv_lst)
# Out:
# ['D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_test_100_4_3_True_Falsehisto_64_cv_index0.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_test_100_4_3_True_Falsehisto_64_cv_index1.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_test_100_4_3_True_Falsehisto_64_cv_index2.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_test_100_4_3_True_Falsehisto_64_cv_index3.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_test_100_4_3_True_Falsehisto_64_cv_index4.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_test_100_4_3_True_Falsehisto_64_cv_index5.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_test_100_4_3_True_Falsehisto_64_cv_index6.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_test_100_4_3_True_Falsehisto_64_cv_index7.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_test_100_4_3_True_Falsehisto_64_cv_index8.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_test_100_4_3_True_Falsehisto_64_cv_index9.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_train_100_4_3_True_Falsehisto_64_cv_index0.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_train_100_4_3_True_Falsehisto_64_cv_index1.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_train_100_4_3_True_Falsehisto_64_cv_index2.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_train_100_4_3_True_Falsehisto_64_cv_index3.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_train_100_4_3_True_Falsehisto_64_cv_index4.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_train_100_4_3_True_Falsehisto_64_cv_index5.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_train_100_4_3_True_Falsehisto_64_cv_index6.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_train_100_4_3_True_Falsehisto_64_cv_index7.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_train_100_4_3_True_Falsehisto_64_cv_index8.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_train_100_4_3_True_Falsehisto_64_cv_index9.csv']

# %%
kmean_train_paths = [x for x in kmean_data_10cv_lst if 'train' in x]
kmean_test_paths = [x for x in kmean_data_10cv_lst if 'test' in x]
print(kmean_train_paths)
print()
print(kmean_test_paths)
print(len(kmean_train_paths))
print(len(kmean_test_paths))
# Out:
# ['D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_train_100_4_3_True_Falsehisto_64_cv_index0.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_train_100_4_3_True_Falsehisto_64_cv_index1.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_train_100_4_3_True_Falsehisto_64_cv_index2.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_train_100_4_3_True_Falsehisto_64_cv_index3.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_train_100_4_3_True_Falsehisto_64_cv_index4.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_train_100_4_3_True_Falsehisto_64_cv_index5.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_train_100_4_3_True_Falsehisto_64_cv_index6.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_train_100_4_3_True_Falsehisto_64_cv_index7.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_train_100_4_3_True_Falsehisto_64_cv_index8.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_train_100_4_3_True_Falsehisto_64_cv_index9.csv']
#
# ['D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_test_100_4_3_True_Falsehisto_64_cv_index0.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_test_100_4_3_True_Falsehisto_64_cv_index1.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_test_100_4_3_True_Falsehisto_64_cv_index2.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_test_100_4_3_True_Falsehisto_64_cv_index3.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_test_100_4_3_True_Falsehisto_64_cv_index4.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_test_100_4_3_True_Falsehisto_64_cv_index5.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_test_100_4_3_True_Falsehisto_64_cv_index6.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_test_100_4_3_True_Falsehisto_64_cv_index7.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_test_100_4_3_True_Falsehisto_64_cv_index8.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_64\\surf_test_100_4_3_True_Falsehisto_64_cv_index9.csv']
# 10
# 10

# %%
def to_categorical(y, num_classes=None, dtype='float32'):
    """to_categorical _summary_

    Arguments:
        y -- The label of the data set with the shape of [None, 1]

    Keyword Arguments:
        num_classes -- The num_classes in the data set (default: {None})
        dtype -- the type of each element of the label after reshape (default: {'float32'})

    Returns:
        the label of the data set with the shape of [number of samples, number of classes].
    """    
    y = np.array(y, dtype='int')
    input_shape = y.shape
    if input_shape and input_shape[-1] == 1 and len(input_shape) > 1:
        input_shape = tuple(input_shape[:-1])
    y = y.ravel()
    if not num_classes:
        num_classes = np.max(y) + 1
    n = y.shape[0]
    categorical = np.zeros((n, num_classes), dtype=dtype)
    categorical[np.arange(n), y] = 1
    output_shape = input_shape + (num_classes,)
    categorical = np.reshape(categorical, output_shape)
    return categorical

# %%
class roc_curve_score:
    def __init__(self, y_true, y_pred, num_class):
        self.y_test = to_categorical(y_true)
        self.y_score = to_categorical(y_pred)
        print(np.unique(self.y_test), np.unique(self.y_score))
        self.fprs = {}
        self.tprs = {}
        self.thresh_holds = {}
        for x in range(num_class):
            self.fprs[x], self.tprs[x], self.thresh_holds[x] = roc_curve(self.y_test[:, x], self.y_score[:, x], drop_intermediate=False)
            self.fprs[x] = self.fprs[x].tolist()
            self.tprs[x] = self.tprs[x].tolist()
            self.thresh_holds[x] = self.thresh_holds[x].tolist()
        
        self.fpr_micro_avg, self.tpr_micro_avg, self.threshold_micro_avg, = roc_curve(self.y_test.ravel(), self.y_score.ravel())
        
        all_fpr = np.unique(np.concatenate([self.fprs[i] for i in range(num_class)]))
        mean_tpr = np.zeros_like(all_fpr)
        for i in range(num_class):
            mean_tpr += np.interp(all_fpr, self.fprs[i], self.tprs[i])
        mean_tpr /= num_class
        self.fpr_macro_avg = all_fpr.tolist()
        self.tpr_macro_avg = mean_tpr.tolist()
    
    def get_tpr(self, _class = None):
        if(_class):
            return self.tprs[_class]
        else:
            return self.tprs
    
    def get_fpr(self, _class = None):
        if(_class):
            return self.fprs[_class]
        else:
            return self.fprs

    def get_thresholds(self, _class = None):
        if(_class):
            return self.thresh_holds[_class]
        else:
            return self.thresh_holds

    def get_roc_dict(self):
        return {
            "tpr" : self.get_tpr(),
            "fpr" : self.get_fpr(),
            "thresholds" : self.get_thresholds(),
            "fpr_micro_avg" : self.fpr_micro_avg.tolist(),
            "tpr_micro_avg" : self.tpr_micro_avg.tolist(),
            "fpr_macro_avg" : self.fpr_macro_avg,
            "tpr_macro_avg" : self.tpr_macro_avg,
        }

# %%
class utils:
    def __init__(self, confusion_matrix, y_true, y_pred):
        """
            - confusion_matrix: 2x2 numpy array
            - y_true: array of label
            - y_pred: array of output value calculated by model
            - fold_count: number of folds
        """
        
        # Initilize all indicator
        self.TP = confusion_matrix[0][0] # true positive
        self.FN = confusion_matrix[1][0] # false negative
        self.FP = confusion_matrix[1][0] # false positive
        self.TN = confusion_matrix[1][1] # true negative
        self.precision = self.TP/(self.FN +  self.TP) # Precision Score - Positive Predictive Value
        self.recall = self.TP / (self.TP + self.FN)
        self.f1_score =  (2 * self.TP) / (2 * self.TP + self.FP + self.FN)
        self.sensitivity = self.TP / (self.TP + self.FN) # True Positive Rate
        self.specificity = self.TN / (self.TN + self.FP) # False Positive Rate
        self.negative_predictive_value = self.TN / (self.TN + self.FN) # Negative Predictive Value
        self.false_negative_rate = self.FN / (self.FN + self.TP) # False Negative Rate
        self.false_positive_rate = self.FP / (self.FP + self.TN) # False Positive Rate
        self.false_discovery_rate = self.FP / (self.FP + self.TP) # False Discovery Rate
        self.false_omission_rate = self.FN / (self.FN + self.TN) # False Ommision Rate
        self.positive_likelihood_ratio = self.sensitivity / self.false_positive_rate # Positive Likelihood Ratio
        self.negative_likelihood_ratio = self.false_negative_rate / self.specificity # Negative Likelihood Ratio
        self.prevalence_threshold = math.sqrt(self.false_positive_rate) / (math.sqrt(self.sensitivity) + 
                                                                      math.sqrt(self.false_positive_rate)) # Prevalance Threshold
        self.threat_score = self.TP / (self.TN + self.FN + self.FP) # Threat Score
        self.prevalence = (self.TP + self.FN)/(self.TP + self.FN + self.TN + self.FP) # Prevalance 
        #  Matthews correlation coefficient
        self.matthews_correlation_coefficient = (self.TP*self.TN - self.FN*self.FP) / ((self.TP + self.FP)
                                                                                       *(self.TP + self.FN)
                                                                                       *(self.TN + self.FP)
                                                                                       *(self.TN + self.FN))
        self.fowlkes_mallows_index = math.sqrt(self.sensitivity + self.precision) # Fowlkes–Mallows index
        self.informedness = self.sensitivity + self.specificity - 1 # informedness
        self.markedness = self.precision + self.negative_predictive_value - 1 # markedness
        self.diagnostic_odds_ratio = self.positive_likelihood_ratio / self.negative_likelihood_ratio # Diagnostic odds ratio
        self.accuracy = (self.TP + self.TN) / (self.TP + self.TN + self.FP + self.FN)
        self.balanced_accuracy = (self.sensitivity + self.specificity) / 2
        self.roc_auc_macro = roc_auc_score(y_true, y_pred)
        self.roc_auc_micro = roc_auc_score(y_true, y_pred, average = 'micro')
        self.roc_auc_weighted = roc_auc_score(y_true, y_pred, average = 'weighted')
        self.cls_report = classification_report(y_true, y_pred)
        
        # Initilize the structure of output_dicts
        self.confusion_matrix = {
            "TP" : self.TP,
            "TN" : self.TN,
            "FN" : self.FN,
            "FP" : self.FP,
            "precision" : self.precision,
            "recall" : self.recall,
            "f1_score" : self.f1_score,
            "sensitivity" : self.sensitivity,
            "specificity" : self.specificity,
            "negative_predictive_value" : self.negative_predictive_value,
            "false_negative_rate" : self.false_negative_rate,
            "false_positive_rate" : self.false_positive_rate,
            "false_discovery_rate" : self.false_discovery_rate,
            "false_omission_rate" : self.false_omission_rate,
            "Positive_likelihood_ratio" : self.positive_likelihood_ratio,
            "Negative_likelihood_ratio" : self.negative_likelihood_ratio,
            "prevalence_threshold" : self.prevalence_threshold,
            "threat_score" : self.threat_score,
            "Prevalence" : self.prevalence,
            "Matthews_correlation_coefficient" : self.matthews_correlation_coefficient,
            "Fowlkes_Mallows_index" : self.fowlkes_mallows_index,
            "informedness" : self.informedness,
            "markedness" : self.markedness,
            "Diagnostic_odds_ratio" : self.diagnostic_odds_ratio,
            "accuracy" : self.accuracy,
            "balanced_accuracy" : self.balanced_accuracy
        }
        
        self.roc_auc_score = {
            "Macro": self.roc_auc_macro, 
            "Micro": self.roc_auc_micro,
            "Weight": self.roc_auc_weighted
        }
        
#         self.roc_curve = roc_curve_score(y_true=y_true, y_pred=y_pred, num_class=2).get_roc_dict()
        
        self.sub_dict = {
            "Confusion Matrix" : self.confusion_matrix,
            "ROC_AUC_SCORE" : self.roc_auc_score,
            "Classification Report" : classification_report(y_true.tolist(), y_pred.tolist(), 
                                                            labels = [0, 1], # 0 : Licit, 1 : Illicit
                                                            output_dict = True),
#             "ROC_DRAW" : self.roc_curve
        }
    def get_value(self):
        return self.sub_dict
        
# Test 
y_true = np.array([randint(0,1) for x in range(200)])
y_pred = np.array([randint(0,1) for x in range(200)])
confusion_matrix_test = confusion_matrix(y_true, y_pred)
base_utils = utils(confusion_matrix_test, y_true, y_pred)
base_utils.get_value()
# Out:
# {'Confusion Matrix': {'TP': 40,
#   'TN': 44,
#   'FN': 64,
#   'FP': 64,
#   'precision': 0.38461538461538464,
#   'recall': 0.38461538461538464,
#   'f1_score': 0.38461538461538464,
#   'sensitivity': 0.38461538461538464,
#   'specificity': 0.4074074074074074,
#   'negative_predictive_value': 0.4074074074074074,
#   'false_negative_rate': 0.6153846153846154,
#   'false_positive_rate': 0.5925925925925926,
#   'false_discovery_rate': 0.6153846153846154,
#   'false_omission_rate': 0.5925925925925926,
#   'Positive_likelihood_ratio': 0.6490384615384616,
#   'Negative_likelihood_ratio': 1.5104895104895106,
#   'prevalence_threshold': 0.5538235544489412,
#   'threat_score': 0.23255813953488372,
#   'Prevalence': 0.49056603773584906,
#   'Matthews_correlation_coefficient': -1.8516489314210112e-05,
#   'Fowlkes_Mallows_index': 0.8770580193070292,
#   'informedness': -0.20797720797720798,
#   'markedness': -0.20797720797720798,
#   'Diagnostic_odds_ratio': 0.4296875,
#   'accuracy': 0.39622641509433965,
#   'balanced_accuracy': 0.396011396011396},
#  'ROC_AUC_SCORE': {'Macro': 0.4210950080515298,
#   'Micro': 0.4210950080515298,
#   'Weight': 0.4210950080515298},
#  'Classification Report': {'0': {'precision': 0.38461538461538464,
#    'recall': 0.43478260869565216,
#    'f1-score': 0.40816326530612246,
#    'support': 92},
#   '1': {'precision': 0.4583333333333333,
#    'recall': 0.4074074074074074,
#    'f1-score': 0.4313725490196078,
#    'support': 108},
#   'accuracy': 0.42,
#   'macro avg': {'precision': 0.421474358974359,
#    'recall': 0.4210950080515298,
#    'f1-score': 0.41976790716286516,
#    'support': 200},
#   'weighted avg': {'precision': 0.42442307692307696,
#    'recall': 0.42,
#    'f1-score': 0.4206962785114045,
#    'support': 200}}}

# %%
class Training:
    def __init__(self, fold_count, X, y):
        self.fold_count = fold_count
        self.param_grid = {
            "penalty" : ["l2"],
            "fit_intercept" : [True, False],
            "class_weight" : ["balanced", None],
            "solver" : ["newton-cg", "lbfgs", "liblinear", "sag", "saga"]
        }
        self.kf = KFold(n_splits=fold_count)
        self.history = {}
        self.X = X
        self.y = y
    
    def get_fold_value(self):
        return self.kf        
        
    def training(self, penalty, 
                 fit_intercept, 
                 class_weight, 
                 solver, train_case):
    
        # output_dict initilize
        output_dict = {}
    
        # poiter track the index of fold
        fold_index = 0
    
        for train_index, test_index in zip(self.X, self.y):
            train_df = pd.read_csv(train_index)
            test_df = pd.read_csv(test_index)
            
            print("\tFold: {}".format(fold_index))
            print("\tTRAIN:", train_index, "\n\tTEST:", test_index)
        
            # folding data
            x_train, y_train = train_df.iloc[:, 2:-1], train_df.iloc[:, -1]
            x_test, y_test = test_df.iloc[:, 2:-1], test_df.iloc[:, -1]
    
            # Training
            print("\t\tTraining : {}".format(fold_index), end = " -- ")
            print("Start: {}".format(datetime.now().strftime("%m/%d/%Y, %H:%M:%S")), end=" --- ")
            model = LogisticRegression(penalty = penalty,
                                         fit_intercept = fit_intercept,
                                         class_weight = class_weight,
                                         solver = solver)
            model.fit(x_train,y_train)
            print("End: {}".format(datetime.now().strftime("%m/%d/%Y, %H:%M:%S")))
        
            # Testing
            print("\t\tValidation: {}".format(fold_index), end = " -- ")
            print("Start: {}".format(datetime.now().strftime("%m/%d/%Y, %H:%M:%S")), end="---")
            y_pred = model.predict(x_test)
            print("End: {}".format(datetime.now().strftime("%m/%d/%Y, %H:%M:%S")))
        
            # Evaluation
            cm = confusion_matrix(y_test, y_pred)
            current_utils = utils(cm, y_test, y_pred)
            output_dict["fold_{}".format(fold_index)] = current_utils.get_value()
            
            fold_index += 1
        print("\n")
        return output_dict 
    
    def train(self, path):
        count = 0
        for x in self.param_grid["penalty"]:
            for i in self.param_grid["fit_intercept"]:
                for j in self.param_grid["class_weight"]:
                    for k in self.param_grid["solver"]:
                        print("Traning Case: {}".format(count))
                        self.history["train_{}".format(count)] = {
                            "param" : {
                            "penalty" : x,
                            "fit_intercept" : i,
                            "class_weight" : j,
                            "solver" : k,
                            },
                            "train_fold" : self.training(x, i, j, k, count)
                        }
                        count += 1
        with open(path.format(self.fold_count), 'wb') as f:
            pickle.dump(self.history, f)
        
        return self.history

# %% [markdown]
# # Training

# %%
training = Training(10, kmean_train_paths, kmean_test_paths)
approach_dir = os.getcwd() + "\\Experiment\\Approach"
svm_dir = approach_dir + "\\LogisticRegression"
save_result_path = svm_dir + '\\lr_km64_surf100_result_fold{0}_0.9.pkl'
training.train(path = save_result_path)
# Out:
# Traning Case: 0
# 	Fold: 0
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index0.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index0.csv
# 		Training : 0 -- Start: 12/12/2022, 17:46:25 --- End: 12/12/2022, 17:46:25
# 		Validation: 0 -- Start: 12/12/2022, 17:46:25---End: 12/12/2022, 17:46:25
# 	Fold: 1
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index1.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index1.csv
# 		Training : 1 -- Start: 12/12/2022, 17:46:25 --- End: 12/12/2022, 17:46:25
# 		Validation: 1 -- Start: 12/12/2022, 17:46:25---End: 12/12/2022, 17:46:25
# 	Fold: 2
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index2.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index2.csv
# 		Training : 2 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 2 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
# 	Fold: 3
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index3.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index3.csv
# 		Training : 3 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 3 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
# 	Fold: 4
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index4.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index4.csv
# 		Training : 4 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 4 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
# 	Fold: 5
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index5.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index5.csv
# 		Training : 5 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 5 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
# 	Fold: 6
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index6.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index6.csv
# 		Training : 6 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 6 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
# 	Fold: 7
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index7.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index7.csv
# 		Training : 7 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 7 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
# 	Fold: 8
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index8.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index8.csv
# 		Training : 8 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 8 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
# 	Fold: 9
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index9.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index9.csv
# 		Training : 9 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 9 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
#
#
# Traning Case: 1
# 	Fold: 0
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index0.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index0.csv
# 		Training : 0 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 0 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
# 	Fold: 1
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index1.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index1.csv
# 		Training : 1 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 1 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
# 	Fold: 2
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index2.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index2.csv
# 		Training : 2 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 2 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
# 	Fold: 3
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index3.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index3.csv
# 		Training : 3 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 3 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
# 	Fold: 4
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index4.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index4.csv
# 		Training : 4 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 4 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
# 	Fold: 5
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index5.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index5.csv
# 		Training : 5 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 5 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
# 	Fold: 6
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index6.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index6.csv
# 		Training : 6 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 6 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
# 	Fold: 7
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index7.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index7.csv
# 		Training : 7 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 7 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
# 	Fold: 8
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index8.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index8.csv
# 		Training : 8 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 8 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
# 	Fold: 9
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index9.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index9.csv
# 		Training : 9 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 9 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
#
#
# Traning Case: 2
# 	Fold: 0
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index0.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index0.csv
# 		Training : 0 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 0 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
# 	Fold: 1
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index1.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index1.csv
# 		Training : 1 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 1 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
# 	Fold: 2
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index2.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index2.csv
# 		Training : 2 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 2 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
# 	Fold: 3
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index3.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index3.csv
# 		Training : 3 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 3 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
# 	Fold: 4
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index4.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index4.csv
# 		Training : 4 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 4 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
# 	Fold: 5
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index5.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index5.csv
# 		Training : 5 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 5 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
# 	Fold: 6
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index6.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index6.csv
# 		Training : 6 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 6 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
# 	Fold: 7
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index7.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index7.csv
# 		Training : 7 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 7 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
# 	Fold: 8
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index8.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index8.csv
# 		Training : 8 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 8 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
# 	Fold: 9
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index9.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index9.csv
# 		Training : 9 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 9 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
#
#
# Traning Case: 3
# 	Fold: 0
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index0.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index0.csv
# 		Training : 0 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 0 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
# 	Fold: 1
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index1.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index1.csv
# 		Training : 1 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 1 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
# 	Fold: 2
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index2.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index2.csv
# 		Training : 2 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 2 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
# 	Fold: 3
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index3.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index3.csv
# 		Training : 3 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 3 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
# 	Fold: 4
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index4.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index4.csv
# 		Training : 4 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 4 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
# 	Fold: 5
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index5.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index5.csv
# 		Training : 5 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 5 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
# 	Fold: 6
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index6.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index6.csv
# 		Training : 6 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 6 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
# 	Fold: 7
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index7.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index7.csv
# 		Training : 7 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 7 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
# 	Fold: 8
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index8.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index8.csv
# 		Training : 8 -- Start: 12/12/2022, 17:46:26 --- End: 12/12/2022, 17:46:26
# 		Validation: 8 -- Start: 12/12/2022, 17:46:26---End: 12/12/2022, 17:46:26
# 	Fold: 9
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index9.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index9.csv
# 		Training : 9 -- Start: 12/12/2022, 17:46:27 --- End: 12/12/2022, 17:46:27
# 		Validation: 9 -- Start: 12/12/2022, 17:46:27---End: 12/12/2022, 17:46:27
#
#
# Traning Case: 4
# 	Fold: 0
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index0.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index0.csv
# 		Training : 0 -- Start: 12/12/2022, 17:46:27 --- End: 12/12/2022, 17:46:27
# 		Validation: 0 -- Start: 12/12/2022, 17:46:27---End: 12/12/2022, 17:46:27
# 	Fold: 1
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index1.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index1.csv
# 		Training : 1 -- Start: 12/12/2022, 17:46:27 --- End: 12/12/2022, 17:46:27
# 		Validation: 1 -- Start: 12/12/2022, 17:46:27---End: 12/12/2022, 17:46:27
# 	Fold: 2
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index2.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index2.csv
# 		Training : 2 -- Start: 12/12/2022, 17:46:27 --- End: 12/12/2022, 17:46:27
# 		Validation: 2 -- Start: 12/12/2022, 17:46:27---End: 12/12/2022, 17:46:27
# 	Fold: 3
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index3.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index3.csv
# 		Training : 3 -- Start: 12/12/2022, 17:46:27 --- End: 12/12/2022, 17:46:27
# 		Validation: 3 -- Start: 12/12/2022, 17:46:27---End: 12/12/2022, 17:46:27
# 	Fold: 4
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index4.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index4.csv
# 		Training : 4 -- Start: 12/12/2022, 17:46:27 --- End: 12/12/2022, 17:46:27
# 		Validation: 4 -- Start: 12/12/2022, 17:46:27---End: 12/12/2022, 17:46:27
# 	Fold: 5
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index5.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index5.csv
# 		Training : 5 -- Start: 12/12/2022, 17:46:27 --- End: 12/12/2022, 17:46:27
# 		Validation: 5 -- Start: 12/12/2022, 17:46:27---End: 12/12/2022, 17:46:27
# 	Fold: 6
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index6.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index6.csv
# 		Training : 6 -- Start: 12/12/2022, 17:46:27 --- End: 12/12/2022, 17:46:27
# 		Validation: 6 -- Start: 12/12/2022, 17:46:27---End: 12/12/2022, 17:46:27
# 	Fold: 7
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index7.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index7.csv
# 		Training : 7 -- Start: 12/12/2022, 17:46:27 --- End: 12/12/2022, 17:46:27
# 		Validation: 7 -- Start: 12/12/2022, 17:46:27---End: 12/12/2022, 17:46:27
# 	Fold: 8
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index8.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index8.csv
# 		Training : 8 -- Start: 12/12/2022, 17:46:27 --- End: 12/12/2022, 17:46:27
# 		Validation: 8 -- Start: 12/12/2022, 17:46:27---End: 12/12/2022, 17:46:27
# 	Fold: 9
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index9.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index9.csv
# 		Training : 9 -- Start: 12/12/2022, 17:46:27 --- End: 12/12/2022, 17:46:27
# 		Validation: 9 -- Start: 12/12/2022, 17:46:27---End: 12/12/2022, 17:46:27
#
#
# Traning Case: 5
# 	Fold: 0
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index0.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index0.csv
# 		Training : 0 -- Start: 12/12/2022, 17:46:27 --- End: 12/12/2022, 17:46:27
# 		Validation: 0 -- Start: 12/12/2022, 17:46:27---End: 12/12/2022, 17:46:27
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:15: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.precision = self.TP/(self.FN +  self.TP) # Precision Score - Positive Predictive Value
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:16: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.recall = self.TP / (self.TP + self.FN)
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:17: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.f1_score =  (2 * self.TP) / (2 * self.TP + self.FP + self.FN)
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:18: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.sensitivity = self.TP / (self.TP + self.FN) # True Positive Rate
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:21: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.false_negative_rate = self.FN / (self.FN + self.TP) # False Negative Rate
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:23: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.false_discovery_rate = self.FP / (self.FP + self.TP) # False Discovery Rate
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:32: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.matthews_correlation_coefficient = (self.TP*self.TN - self.FN*self.FP) / ((self.TP + self.FP)
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:15: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.precision = self.TP/(self.FN +  self.TP) # Precision Score - Positive Predictive Value
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:16: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.recall = self.TP / (self.TP + self.FN)
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:17: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.f1_score =  (2 * self.TP) / (2 * self.TP + self.FP + self.FN)
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:18: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.sensitivity = self.TP / (self.TP + self.FN) # True Positive Rate
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:21: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.false_negative_rate = self.FN / (self.FN + self.TP) # False Negative Rate
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:23: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.false_discovery_rate = self.FP / (self.FP + self.TP) # False Discovery Rate
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:32: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.matthews_correlation_coefficient = (self.TP*self.TN - self.FN*self.FP) / ((self.TP + self.FP)
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:15: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.precision = self.TP/(self.FN +  self.TP) # Precision Score - Positive Predictive Value
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:16: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.recall = self.TP / (self.TP + self.FN)
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:17: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.f1_score =  (2 * self.TP) / (2 * self.TP + self.FP + self.FN)
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:18: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.sensitivity = self.TP / (self.TP + self.FN) # True Positive Rate
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:21: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.false_negative_rate = self.FN / (self.FN + self.TP) # False Negative Rate
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:23: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.false_discovery_rate = self.FP / (self.FP + self.TP) # False Discovery Rate
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:32: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.matthews_correlation_coefficient = (self.TP*self.TN - self.FN*self.FP) / ((self.TP + self.FP)
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:15: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.precision = self.TP/(self.FN +  self.TP) # Precision Score - Positive Predictive Value
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:16: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.recall = self.TP / (self.TP + self.FN)
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:17: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.f1_score =  (2 * self.TP) / (2 * self.TP + self.FP + self.FN)
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:18: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.sensitivity = self.TP / (self.TP + self.FN) # True Positive Rate
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:21: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.false_negative_rate = self.FN / (self.FN + self.TP) # False Negative Rate
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:23: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.false_discovery_rate = self.FP / (self.FP + self.TP) # False Discovery Rate
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:32: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.matthews_correlation_coefficient = (self.TP*self.TN - self.FN*self.FP) / ((self.TP + self.FP)
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:15: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.precision = self.TP/(self.FN +  self.TP) # Precision Score - Positive Predictive Value
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:16: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.recall = self.TP / (self.TP + self.FN)
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:17: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.f1_score =  (2 * self.TP) / (2 * self.TP + self.FP + self.FN)
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:18: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.sensitivity = self.TP / (self.TP + self.FN) # True Positive Rate
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:21: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.false_negative_rate = self.FN / (self.FN + self.TP) # False Negative Rate
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:23: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.false_discovery_rate = self.FP / (self.FP + self.TP) # False Discovery Rate
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:32: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.matthews_correlation_coefficient = (self.TP*self.TN - self.FN*self.FP) / ((self.TP + self.FP)
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:15: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.precision = self.TP/(self.FN +  self.TP) # Precision Score - Positive Predictive Value
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:16: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.recall = self.TP / (self.TP + self.FN)
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:17: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.f1_score =  (2 * self.TP) / (2 * self.TP + self.FP + self.FN)
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:18: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.sensitivity = self.TP / (self.TP + self.FN) # True Positive Rate
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:21: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.false_negative_rate = self.FN / (self.FN + self.TP) # False Negative Rate
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:23: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.false_discovery_rate = self.FP / (self.FP + self.TP) # False Discovery Rate
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:32: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.matthews_correlation_coefficient = (self.TP*self.TN - self.FN*self.FP) / ((self.TP + self.FP)
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:15: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.precision = self.TP/(self.FN +  self.TP) # Precision Score - Positive Predictive Value
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:16: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.recall = self.TP / (self.TP + self.FN)
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:17: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.f1_score =  (2 * self.TP) / (2 * self.TP + self.FP + self.FN)
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:18: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.sensitivity = self.TP / (self.TP + self.FN) # True Positive Rate
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:21: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.false_negative_rate = self.FN / (self.FN + self.TP) # False Negative Rate
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:23: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.false_discovery_rate = self.FP / (self.FP + self.TP) # False Discovery Rate
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:32: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.matthews_correlation_coefficient = (self.TP*self.TN - self.FN*self.FP) / ((self.TP + self.FP)
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:15: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.precision = self.TP/(self.FN +  self.TP) # Precision Score - Positive Predictive Value
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:16: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.recall = self.TP / (self.TP + self.FN)
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:17: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.f1_score =  (2 * self.TP) / (2 * self.TP + self.FP + self.FN)
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:18: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.sensitivity = self.TP / (self.TP + self.FN) # True Positive Rate
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:21: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.false_negative_rate = self.FN / (self.FN + self.TP) # False Negative Rate
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:23: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.false_discovery_rate = self.FP / (self.FP + self.TP) # False Discovery Rate
# C:\Users\kohi2\AppData\Local\Temp\ipykernel_17476\425510141.py:32: RuntimeWarning: invalid value encountered in longlong_scalars
#   self.matthews_correlation_coefficient = (self.TP*self.TN - self.FN*self.FP) / ((self.TP + self.FP)
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\github\stomach-status-classification\envir\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
#      'Prevalence': 0.0,
#      'Matthews_correlation_coefficient': nan,
#      'Fowlkes_Mallows_index': nan,
#      'informedness': nan,
#      'markedness': nan,
#      'Diagnostic_odds_ratio': nan,
#      'accuracy': 1.0,
#      'balanced_accuracy': nan},
#     'ROC_AUC_SCORE': {'Macro': 0.5, 'Micro': 0.5, 'Weight': 0.5},
#     'Classification Report': {'0': {'precision': 0.0,
#       'recall': 0.0,
#       'f1-score': 0.0,
#       'support': 6},
#      '1': {'precision': 0.6666666666666666,
#       'recall': 1.0,
#       'f1-score': 0.8,
#       'support': 12},
#      'accuracy': 0.6666666666666666,
#      'macro avg': {'precision': 0.3333333333333333,
#       'recall': 0.5,
#       'f1-score': 0.4,
#       'support': 18},
#      'weighted avg': {'precision': 0.4444444444444444,
#       'recall': 0.6666666666666666,
#       'f1-score': 0.5333333333333334,
#       'support': 18}}},
#    'fold_9': {'Confusion Matrix': {'TP': 0,
#      'TN': 11,
#      'FN': 0,
#      'FP': 0,
#      'precision': nan,
#      'recall': nan,
#      'f1_score': nan,
#      'sensitivity': nan,
#      'specificity': 1.0,
#      'negative_predictive_value': 1.0,
#      'false_negative_rate': nan,
#      'false_positive_rate': 0.0,
#      'false_discovery_rate': nan,
#      'false_omission_rate': 0.0,
#      'Positive_likelihood_ratio': nan,
#      'Negative_likelihood_ratio': nan,
#      'prevalence_threshold': nan,
#      'threat_score': 0.0,
#      'Prevalence': 0.0,
#      'Matthews_correlation_coefficient': nan,
#      'Fowlkes_Mallows_index': nan,
#      'informedness': nan,
#      'markedness': nan,
#      'Diagnostic_odds_ratio': nan,
#      'accuracy': 1.0,
#      'balanced_accuracy': nan},
#     'ROC_AUC_SCORE': {'Macro': 0.5, 'Micro': 0.5, 'Weight': 0.5},
#     'Classification Report': {'0': {'precision': 0.0,
#       'recall': 0.0,
#       'f1-score': 0.0,
#       'support': 2},
#      '1': {'precision': 0.8461538461538461,
#       'recall': 1.0,
#       'f1-score': 0.9166666666666666,
#       'support': 11},
#      'accuracy': 0.8461538461538461,
#      'macro avg': {'precision': 0.4230769230769231,
#       'recall': 0.5,
#       'f1-score': 0.4583333333333333,
#       'support': 13},
#      'weighted avg': {'precision': 0.7159763313609468,
#       'recall': 0.8461538461538461,
#       'f1-score': 0.7756410256410255,
#       'support': 13}}}}},
#  'train_19': {'param': {'penalty': 'l2',
#    'fit_intercept': False,
#    'class_weight': None,
#    'solver': 'saga'},
#   'train_fold': {'fold_0': {'Confusion Matrix': {'TP': 0,
#      'TN': 12,
#      'FN': 0,
#      'FP': 0,
#      'precision': nan,
#      'recall': nan,
#      'f1_score': nan,
#      'sensitivity': nan,
#      'specificity': 1.0,
#      'negative_predictive_value': 1.0,
#      'false_negative_rate': nan,
#      'false_positive_rate': 0.0,
#      'false_discovery_rate': nan,
#      'false_omission_rate': 0.0,
#      'Positive_likelihood_ratio': nan,
#      'Negative_likelihood_ratio': nan,
#      'prevalence_threshold': nan,
#      'threat_score': 0.0,
#      'Prevalence': 0.0,
#      'Matthews_correlation_coefficient': nan,
#      'Fowlkes_Mallows_index': nan,
#      'informedness': nan,
#      'markedness': nan,
#      'Diagnostic_odds_ratio': nan,
#      'accuracy': 1.0,
#      'balanced_accuracy': nan},
#     'ROC_AUC_SCORE': {'Macro': 0.5, 'Micro': 0.5, 'Weight': 0.5},
#     'Classification Report': {'0': {'precision': 0.0,
#       'recall': 0.0,
#       'f1-score': 0.0,
#       'support': 6},
#      '1': {'precision': 0.6666666666666666,
#       'recall': 1.0,
#       'f1-score': 0.8,
#       'support': 12},
#      'accuracy': 0.6666666666666666,
#      'macro avg': {'precision': 0.3333333333333333,
#       'recall': 0.5,
#       'f1-score': 0.4,
#       'support': 18},
#      'weighted avg': {'precision': 0.4444444444444444,
#       'recall': 0.6666666666666666,
#       'f1-score': 0.5333333333333334,
#       'support': 18}}},
#    'fold_1': {'Confusion Matrix': {'TP': 0,
#      'TN': 12,
#      'FN': 0,
#      'FP': 0,
#      'precision': nan,
#      'recall': nan,
#      'f1_score': nan,
#      'sensitivity': nan,
#      'specificity': 1.0,
#      'negative_predictive_value': 1.0,
#      'false_negative_rate': nan,
#      'false_positive_rate': 0.0,
#      'false_discovery_rate': nan,
#      'false_omission_rate': 0.0,
#      'Positive_likelihood_ratio': nan,
#      'Negative_likelihood_ratio': nan,
#      'prevalence_threshold': nan,
#      'threat_score': 0.0,
#      'Prevalence': 0.0,
#      'Matthews_correlation_coefficient': nan,
#      'Fowlkes_Mallows_index': nan,
#      'informedness': nan,
#      'markedness': nan,
#      'Diagnostic_odds_ratio': nan,
#      'accuracy': 1.0,
#      'balanced_accuracy': nan},
#     'ROC_AUC_SCORE': {'Macro': 0.5, 'Micro': 0.5, 'Weight': 0.5},
#     'Classification Report': {'0': {'precision': 0.0,
#       'recall': 0.0,
#       'f1-score': 0.0,
#       'support': 6},
#      '1': {'precision': 0.6666666666666666,
#       'recall': 1.0,
#       'f1-score': 0.8,
#       'support': 12},
#      'accuracy': 0.6666666666666666,
#      'macro avg': {'precision': 0.3333333333333333,
#       'recall': 0.5,
#       'f1-score': 0.4,
#       'support': 18},
#      'weighted avg': {'precision': 0.4444444444444444,
#       'recall': 0.6666666666666666,
#       'f1-score': 0.5333333333333334,
#       'support': 18}}},
#    'fold_2': {'Confusion Matrix': {'TP': 0,
#      'TN': 12,
#      'FN': 0,
#      'FP': 0,
#      'precision': nan,
#      'recall': nan,
#      'f1_score': nan,
#      'sensitivity': nan,
#      'specificity': 1.0,
#      'negative_predictive_value': 1.0,
#      'false_negative_rate': nan,
#      'false_positive_rate': 0.0,
#      'false_discovery_rate': nan,
#      'false_omission_rate': 0.0,
#      'Positive_likelihood_ratio': nan,
#      'Negative_likelihood_ratio': nan,
#      'prevalence_threshold': nan,
#      'threat_score': 0.0,
#      'Prevalence': 0.0,
#      'Matthews_correlation_coefficient': nan,
#      'Fowlkes_Mallows_index': nan,
#      'informedness': nan,
#      'markedness': nan,
#      'Diagnostic_odds_ratio': nan,
#      'accuracy': 1.0,
#      'balanced_accuracy': nan},
#     'ROC_AUC_SCORE': {'Macro': 0.5, 'Micro': 0.5, 'Weight': 0.5},
#     'Classification Report': {'0': {'precision': 0.0,
#       'recall': 0.0,
#       'f1-score': 0.0,
#       'support': 6},
#      '1': {'precision': 0.6666666666666666,
#       'recall': 1.0,
#       'f1-score': 0.8,
#       'support': 12},
#      'accuracy': 0.6666666666666666,
#      'macro avg': {'precision': 0.3333333333333333,
#       'recall': 0.5,
#       'f1-score': 0.4,
#       'support': 18},
#      'weighted avg': {'precision': 0.4444444444444444,
#       'recall': 0.6666666666666666,
#       'f1-score': 0.5333333333333334,
#       'support': 18}}},
#    'fold_3': {'Confusion Matrix': {'TP': 0,
#      'TN': 12,
#      'FN': 0,
#      'FP': 0,
#      'precision': nan,
#      'recall': nan,
#      'f1_score': nan,
#      'sensitivity': nan,
#      'specificity': 1.0,
#      'negative_predictive_value': 1.0,
#      'false_negative_rate': nan,
#      'false_positive_rate': 0.0,
#      'false_discovery_rate': nan,
#      'false_omission_rate': 0.0,
#      'Positive_likelihood_ratio': nan,
#      'Negative_likelihood_ratio': nan,
#      'prevalence_threshold': nan,
#      'threat_score': 0.0,
#      'Prevalence': 0.0,
#      'Matthews_correlation_coefficient': nan,
#      'Fowlkes_Mallows_index': nan,
#      'informedness': nan,
#      'markedness': nan,
#      'Diagnostic_odds_ratio': nan,
#      'accuracy': 1.0,
#      'balanced_accuracy': nan},
#     'ROC_AUC_SCORE': {'Macro': 0.5, 'Micro': 0.5, 'Weight': 0.5},
#     'Classification Report': {'0': {'precision': 0.0,
#       'recall': 0.0,
#       'f1-score': 0.0,
#       'support': 6},
#      '1': {'precision': 0.6666666666666666,
#       'recall': 1.0,
#       'f1-score': 0.8,
#       'support': 12},
#      'accuracy': 0.6666666666666666,
#      'macro avg': {'precision': 0.3333333333333333,
#       'recall': 0.5,
#       'f1-score': 0.4,
#       'support': 18},
#      'weighted avg': {'precision': 0.4444444444444444,
#       'recall': 0.6666666666666666,
#       'f1-score': 0.5333333333333334,
#       'support': 18}}},
#    'fold_4': {'Confusion Matrix': {'TP': 0,
#      'TN': 12,
#      'FN': 0,
#      'FP': 0,
#      'precision': nan,
#      'recall': nan,
#      'f1_score': nan,
#      'sensitivity': nan,
#      'specificity': 1.0,
#      'negative_predictive_value': 1.0,
#      'false_negative_rate': nan,
#      'false_positive_rate': 0.0,
#      'false_discovery_rate': nan,
#      'false_omission_rate': 0.0,
#      'Positive_likelihood_ratio': nan,
#      'Negative_likelihood_ratio': nan,
#      'prevalence_threshold': nan,
#      'threat_score': 0.0,
#      'Prevalence': 0.0,
#      'Matthews_correlation_coefficient': nan,
#      'Fowlkes_Mallows_index': nan,
#      'informedness': nan,
#      'markedness': nan,
#      'Diagnostic_odds_ratio': nan,
#      'accuracy': 1.0,
#      'balanced_accuracy': nan},
#     'ROC_AUC_SCORE': {'Macro': 0.5, 'Micro': 0.5, 'Weight': 0.5},
#     'Classification Report': {'0': {'precision': 0.0,
#       'recall': 0.0,
#       'f1-score': 0.0,
#       'support': 6},
#      '1': {'precision': 0.6666666666666666,
#       'recall': 1.0,
#       'f1-score': 0.8,
#       'support': 12},
#      'accuracy': 0.6666666666666666,
#      'macro avg': {'precision': 0.3333333333333333,
#       'recall': 0.5,
#       'f1-score': 0.4,
#       'support': 18},
#      'weighted avg': {'precision': 0.4444444444444444,
#       'recall': 0.6666666666666666,
#       'f1-score': 0.5333333333333334,
#       'support': 18}}},
#    'fold_5': {'Confusion Matrix': {'TP': 0,
#      'TN': 12,
#      'FN': 0,
#      'FP': 0,
#      'precision': nan,
#      'recall': nan,
#      'f1_score': nan,
#      'sensitivity': nan,
#      'specificity': 1.0,
#      'negative_predictive_value': 1.0,
#      'false_negative_rate': nan,
#      'false_positive_rate': 0.0,
#      'false_discovery_rate': nan,
#      'false_omission_rate': 0.0,
#      'Positive_likelihood_ratio': nan,
#      'Negative_likelihood_ratio': nan,
#      'prevalence_threshold': nan,
#      'threat_score': 0.0,
#      'Prevalence': 0.0,
#      'Matthews_correlation_coefficient': nan,
#      'Fowlkes_Mallows_index': nan,
#      'informedness': nan,
#      'markedness': nan,
#      'Diagnostic_odds_ratio': nan,
#      'accuracy': 1.0,
#      'balanced_accuracy': nan},
#     'ROC_AUC_SCORE': {'Macro': 0.5, 'Micro': 0.5, 'Weight': 0.5},
#     'Classification Report': {'0': {'precision': 0.0,
#       'recall': 0.0,
#       'f1-score': 0.0,
#       'support': 6},
#      '1': {'precision': 0.6666666666666666,
#       'recall': 1.0,
#       'f1-score': 0.8,
#       'support': 12},
#      'accuracy': 0.6666666666666666,
#      'macro avg': {'precision': 0.3333333333333333,
#       'recall': 0.5,
#       'f1-score': 0.4,
#       'support': 18},
#      'weighted avg': {'precision': 0.4444444444444444,
#       'recall': 0.6666666666666666,
#       'f1-score': 0.5333333333333334,
#       'support': 18}}},
#    'fold_6': {'Confusion Matrix': {'TP': 0,
#      'TN': 12,
#      'FN': 0,
#      'FP': 0,
#      'precision': nan,
#      'recall': nan,
#      'f1_score': nan,
#      'sensitivity': nan,
#      'specificity': 1.0,
#      'negative_predictive_value': 1.0,
#      'false_negative_rate': nan,
#      'false_positive_rate': 0.0,
#      'false_discovery_rate': nan,
#      'false_omission_rate': 0.0,
#      'Positive_likelihood_ratio': nan,
#      'Negative_likelihood_ratio': nan,
#      'prevalence_threshold': nan,
#      'threat_score': 0.0,
#      'Prevalence': 0.0,
#      'Matthews_correlation_coefficient': nan,
#      'Fowlkes_Mallows_index': nan,
#      'informedness': nan,
#      'markedness': nan,
#      'Diagnostic_odds_ratio': nan,
#      'accuracy': 1.0,
#      'balanced_accuracy': nan},
#     'ROC_AUC_SCORE': {'Macro': 0.5, 'Micro': 0.5, 'Weight': 0.5},
#     'Classification Report': {'0': {'precision': 0.0,
#       'recall': 0.0,
#       'f1-score': 0.0,
#       'support': 6},
#      '1': {'precision': 0.6666666666666666,
#       'recall': 1.0,
#       'f1-score': 0.8,
#       'support': 12},
#      'accuracy': 0.6666666666666666,
#      'macro avg': {'precision': 0.3333333333333333,
#       'recall': 0.5,
#       'f1-score': 0.4,
#       'support': 18},
#      'weighted avg': {'precision': 0.4444444444444444,
#       'recall': 0.6666666666666666,
#       'f1-score': 0.5333333333333334,
#       'support': 18}}},
#    'fold_7': {'Confusion Matrix': {'TP': 0,
#      'TN': 12,
#      'FN': 0,
#      'FP': 0,
#      'precision': nan,
#      'recall': nan,
#      'f1_score': nan,
#      'sensitivity': nan,
#      'specificity': 1.0,
#      'negative_predictive_value': 1.0,
#      'false_negative_rate': nan,
#      'false_positive_rate': 0.0,
#      'false_discovery_rate': nan,
#      'false_omission_rate': 0.0,
#      'Positive_likelihood_ratio': nan,
#      'Negative_likelihood_ratio': nan,
#      'prevalence_threshold': nan,
#      'threat_score': 0.0,
#      'Prevalence': 0.0,
#      'Matthews_correlation_coefficient': nan,
#      'Fowlkes_Mallows_index': nan,
#      'informedness': nan,
#      'markedness': nan,
#      'Diagnostic_odds_ratio': nan,
#      'accuracy': 1.0,
#      'balanced_accuracy': nan},
#     'ROC_AUC_SCORE': {'Macro': 0.5, 'Micro': 0.5, 'Weight': 0.5},
#     'Classification Report': {'0': {'precision': 0.0,
#       'recall': 0.0,
#       'f1-score': 0.0,
#       'support': 6},
#      '1': {'precision': 0.6666666666666666,
#       'recall': 1.0,
#       'f1-score': 0.8,
#       'support': 12},
#      'accuracy': 0.6666666666666666,
#      'macro avg': {'precision': 0.3333333333333333,
#       'recall': 0.5,
#       'f1-score': 0.4,
#       'support': 18},
#      'weighted avg': {'precision': 0.4444444444444444,
#       'recall': 0.6666666666666666,
#       'f1-score': 0.5333333333333334,
#       'support': 18}}},
#    'fold_8': {'Confusion Matrix': {'TP': 0,
#      'TN': 12,
#      'FN': 0,
#      'FP': 0,
#      'precision': nan,
#      'recall': nan,
#      'f1_score': nan,
#      'sensitivity': nan,
#      'specificity': 1.0,
#      'negative_predictive_value': 1.0,
#      'false_negative_rate': nan,
#      'false_positive_rate': 0.0,
#      'false_discovery_rate': nan,
#      'false_omission_rate': 0.0,
#      'Positive_likelihood_ratio': nan,
#      'Negative_likelihood_ratio': nan,
#      'prevalence_threshold': nan,
#      'threat_score': 0.0,
#      'Prevalence': 0.0,
#      'Matthews_correlation_coefficient': nan,
#      'Fowlkes_Mallows_index': nan,
#      'informedness': nan,
#      'markedness': nan,
#      'Diagnostic_odds_ratio': nan,
#      'accuracy': 1.0,
#      'balanced_accuracy': nan},
#     'ROC_AUC_SCORE': {'Macro': 0.5, 'Micro': 0.5, 'Weight': 0.5},
#     'Classification Report': {'0': {'precision': 0.0,
#       'recall': 0.0,
#       'f1-score': 0.0,
#       'support': 6},
#      '1': {'precision': 0.6666666666666666,
#       'recall': 1.0,
#       'f1-score': 0.8,
#       'support': 12},
#      'accuracy': 0.6666666666666666,
#      'macro avg': {'precision': 0.3333333333333333,
#       'recall': 0.5,
#       'f1-score': 0.4,
#       'support': 18},
#      'weighted avg': {'precision': 0.4444444444444444,
#       'recall': 0.6666666666666666,
#       'f1-score': 0.5333333333333334,
#       'support': 18}}},
#    'fold_9': {'Confusion Matrix': {'TP': 0,
#      'TN': 11,
#      'FN': 0,
#      'FP': 0,
#      'precision': nan,
#      'recall': nan,
#      'f1_score': nan,
#      'sensitivity': nan,
#      'specificity': 1.0,
#      'negative_predictive_value': 1.0,
#      'false_negative_rate': nan,
#      'false_positive_rate': 0.0,
#      'false_discovery_rate': nan,
#      'false_omission_rate': 0.0,
#      'Positive_likelihood_ratio': nan,
#      'Negative_likelihood_ratio': nan,
#      'prevalence_threshold': nan,
#      'threat_score': 0.0,
#      'Prevalence': 0.0,
#      'Matthews_correlation_coefficient': nan,
#      'Fowlkes_Mallows_index': nan,
#      'informedness': nan,
#      'markedness': nan,
#      'Diagnostic_odds_ratio': nan,
#      'accuracy': 1.0,
#      'balanced_accuracy': nan},
#     'ROC_AUC_SCORE': {'Macro': 0.5, 'Micro': 0.5, 'Weight': 0.5},
#     'Classification Report': {'0': {'precision': 0.0,
#       'recall': 0.0,
#       'f1-score': 0.0,
#       'support': 2},
#      '1': {'precision': 0.8461538461538461,
#       'recall': 1.0,
#       'f1-score': 0.9166666666666666,
#       'support': 11},
#      'accuracy': 0.8461538461538461,
#      'macro avg': {'precision': 0.4230769230769231,
#       'recall': 0.5,
#       'f1-score': 0.4583333333333333,
#       'support': 13},
#      'weighted avg': {'precision': 0.7159763313609468,
#       'recall': 0.8461538461538461,
#       'f1-score': 0.7756410256410255,
#       'support': 13}}}}}}

# %% [markdown]
# # Result Analyzing

# %%
file = open(save_result_path.format(10), 'rb')
result = pickle.load(file)
result
# Out:
# {'train_0': {'param': {'penalty': 'l2',
#    'fit_intercept': True,
#    'class_weight': 'balanced',
#    'solver': 'newton-cg'},
#   'train_fold': {'fold_0': {'Confusion Matrix': {'TP': 5,
#      'TN': 10,
#      'FN': 2,
#      'FP': 2,
#      'precision': 0.7142857142857143,
#      'recall': 0.7142857142857143,
#      'f1_score': 0.7142857142857143,
#      'sensitivity': 0.7142857142857143,
#      'specificity': 0.8333333333333334,
#      'negative_predictive_value': 0.8333333333333334,
#      'false_negative_rate': 0.2857142857142857,
#      'false_positive_rate': 0.16666666666666666,
#      'false_discovery_rate': 0.2857142857142857,
#      'false_omission_rate': 0.16666666666666666,
#      'Positive_likelihood_ratio': 4.2857142857142865,
#      'Negative_likelihood_ratio': 0.3428571428571428,
#      'prevalence_threshold': 0.32571203244301905,
#      'threat_score': 0.35714285714285715,
#      'Prevalence': 0.3684210526315789,
#      'Matthews_correlation_coefficient': 0.006519274376417234,
#      'Fowlkes_Mallows_index': 1.1952286093343936,
#      'informedness': 0.5476190476190477,
#      'markedness': 0.5476190476190477,
#      'Diagnostic_odds_ratio': 12.500000000000004,
#      'accuracy': 0.7894736842105263,
#      'balanced_accuracy': 0.7738095238095238},
#     'ROC_AUC_SCORE': {'Macro': 0.8333333333333334,
#      'Micro': 0.8333333333333334,
#      'Weight': 0.8333333333333334},
#     'Classification Report': {'0': {'precision': 0.7142857142857143,
#       'recall': 0.8333333333333334,
#       'f1-score': 0.7692307692307692,
#       'support': 6},
#      '1': {'precision': 0.9090909090909091,
#       'recall': 0.8333333333333334,
#       'f1-score': 0.8695652173913043,
#       'support': 12},
#      'accuracy': 0.8333333333333334,
#      'macro avg': {'precision': 0.8116883116883117,
#       'recall': 0.8333333333333334,
#       'f1-score': 0.8193979933110367,
#       'support': 18},
#      'weighted avg': {'precision': 0.8441558441558441,
#       'recall': 0.8333333333333334,
#       'f1-score': 0.8361204013377926,
#       'support': 18}}},
#    'fold_1': {'Confusion Matrix': {'TP': 4,
#      'TN': 10,
#      'FN': 2,
#      'FP': 2,
#      'precision': 0.6666666666666666,
#      'recall': 0.6666666666666666,
#      'f1_score': 0.6666666666666666,
#      'sensitivity': 0.6666666666666666,
#      'specificity': 0.8333333333333334,
#      'negative_predictive_value': 0.8333333333333334,
#      'false_negative_rate': 0.3333333333333333,
#      'false_positive_rate': 0.16666666666666666,
#      'false_discovery_rate': 0.3333333333333333,
#      'false_omission_rate': 0.16666666666666666,
#      'Positive_likelihood_ratio': 4.0,
#      'Negative_likelihood_ratio': 0.39999999999999997,
#      'prevalence_threshold': 0.33333333333333337,
#      'threat_score': 0.2857142857142857,
#      'Prevalence': 0.3333333333333333,
#      'Matthews_correlation_coefficient': 0.006944444444444444,
#      'Fowlkes_Mallows_index': 1.1547005383792515,
#      'informedness': 0.5,
#      'markedness': 0.5,
#      'Diagnostic_odds_ratio': 10.0,
#      'accuracy': 0.7777777777777778,
#      'balanced_accuracy': 0.75},
#     'ROC_AUC_SCORE': {'Macro': 0.7500000000000002,
#      'Micro': 0.7500000000000002,
#      'Weight': 0.7500000000000002},
#     'Classification Report': {'0': {'precision': 0.6666666666666666,
#       'recall': 0.6666666666666666,
#       'f1-score': 0.6666666666666666,
#       'support': 6},
#      '1': {'precision': 0.8333333333333334,
#       'recall': 0.8333333333333334,
#       'f1-score': 0.8333333333333334,
#       'support': 12},
#      'accuracy': 0.7777777777777778,
#      'macro avg': {'precision': 0.75,
#       'recall': 0.75,
#       'f1-score': 0.75,
#       'support': 18},
#      'weighted avg': {'precision': 0.7777777777777778,
#       'recall': 0.7777777777777778,
#       'f1-score': 0.7777777777777778,
#       'support': 18}}},
#    'fold_2': {'Confusion Matrix': {'TP': 4,
#      'TN': 11,
#      'FN': 1,
#      'FP': 1,
#      'precision': 0.8,
#      'recall': 0.8,
#      'f1_score': 0.8,
#      'sensitivity': 0.8,
#      'specificity': 0.9166666666666666,
#      'negative_predictive_value': 0.9166666666666666,
#      'false_negative_rate': 0.2,
#      'false_positive_rate': 0.08333333333333333,
#      'false_discovery_rate': 0.2,
#      'false_omission_rate': 0.08333333333333333,
#      'Positive_likelihood_ratio': 9.600000000000001,
#      'Negative_likelihood_ratio': 0.2181818181818182,
#      'prevalence_threshold': 0.24399845080999225,
#      'threat_score': 0.3076923076923077,
#      'Prevalence': 0.29411764705882354,
#      'Matthews_correlation_coefficient': 0.011944444444444445,
#      'Fowlkes_Mallows_index': 1.2649110640673518,
#      'informedness': 0.7166666666666668,
#      'markedness': 0.7166666666666668,
#      'Diagnostic_odds_ratio': 44.0,
#      'accuracy': 0.8823529411764706,
#      'balanced_accuracy': 0.8583333333333334},
#     'ROC_AUC_SCORE': {'Macro': 0.7916666666666667,
#      'Micro': 0.7916666666666667,
#      'Weight': 0.7916666666666667},
#     'Classification Report': {'0': {'precision': 0.8,
#       'recall': 0.6666666666666666,
#       'f1-score': 0.7272727272727272,
#       'support': 6},
#      '1': {'precision': 0.8461538461538461,
#       'recall': 0.9166666666666666,
#       'f1-score': 0.8799999999999999,
#       'support': 12},
#      'accuracy': 0.8333333333333334,
#      'macro avg': {'precision': 0.823076923076923,
#       'recall': 0.7916666666666666,
#       'f1-score': 0.8036363636363635,
#       'support': 18},
#      'weighted avg': {'precision': 0.8307692307692308,
#       'recall': 0.8333333333333334,
#       'f1-score': 0.829090909090909,
#       'support': 18}}},
#    'fold_3': {'Confusion Matrix': {'TP': 6,
#      'TN': 7,
#      'FN': 5,
#      'FP': 5,
#      'precision': 0.5454545454545454,
#      'recall': 0.5454545454545454,
#      'f1_score': 0.5454545454545454,
#      'sensitivity': 0.5454545454545454,
#      'specificity': 0.5833333333333334,
#      'negative_predictive_value': 0.5833333333333334,
#      'false_negative_rate': 0.45454545454545453,
#      'false_positive_rate': 0.4166666666666667,
#      'false_discovery_rate': 0.45454545454545453,
#      'false_omission_rate': 0.4166666666666667,
#      'Positive_likelihood_ratio': 1.3090909090909089,
#      'Negative_likelihood_ratio': 0.7792207792207791,
#      'prevalence_threshold': 0.4663841700122996,
#      'threat_score': 0.35294117647058826,
#      'Prevalence': 0.4782608695652174,
#      'Matthews_correlation_coefficient': 0.0009756657483930211,
#      'Fowlkes_Mallows_index': 1.044465935734187,
#      'informedness': 0.1287878787878789,
#      'markedness': 0.1287878787878789,
#      'Diagnostic_odds_ratio': 1.68,
#      'accuracy': 0.5652173913043478,
#      'balanced_accuracy': 0.5643939393939394},
#     'ROC_AUC_SCORE': {'Macro': 0.7916666666666667,
#      'Micro': 0.7916666666666667,
#      'Weight': 0.7916666666666667},
#     'Classification Report': {'0': {'precision': 0.5454545454545454,
#       'recall': 1.0,
#       'f1-score': 0.7058823529411764,
#       'support': 6},
#      '1': {'precision': 1.0,
#       'recall': 0.5833333333333334,
#       'f1-score': 0.7368421052631579,
#       'support': 12},
#      'accuracy': 0.7222222222222222,
#      'macro avg': {'precision': 0.7727272727272727,
#       'recall': 0.7916666666666667,
#       'f1-score': 0.7213622291021671,
#       'support': 18},
#      'weighted avg': {'precision': 0.8484848484848485,
#       'recall': 0.7222222222222222,
#       'f1-score': 0.7265221878224973,
#       'support': 18}}},
#    'fold_4': {'Confusion Matrix': {'TP': 6,
#      'TN': 11,
#      'FN': 1,
#      'FP': 1,
#      'precision': 0.8571428571428571,
#      'recall': 0.8571428571428571,
#      'f1_score': 0.8571428571428571,
#      'sensitivity': 0.8571428571428571,
#      'specificity': 0.9166666666666666,
#      'negative_predictive_value': 0.9166666666666666,
#      'false_negative_rate': 0.14285714285714285,
#      'false_positive_rate': 0.08333333333333333,
#      'false_discovery_rate': 0.14285714285714285,
#      'false_omission_rate': 0.08333333333333333,
#      'Positive_likelihood_ratio': 10.285714285714286,
#      'Negative_likelihood_ratio': 0.15584415584415584,
#      'prevalence_threshold': 0.23769145108682535,
#      'threat_score': 0.46153846153846156,
#      'Prevalence': 0.3684210526315789,
#      'Matthews_correlation_coefficient': 0.009212018140589568,
#      'Fowlkes_Mallows_index': 1.3093073414159542,
#      'informedness': 0.7738095238095237,
#      'markedness': 0.7738095238095237,
#      'Diagnostic_odds_ratio': 66.0,
#      'accuracy': 0.8947368421052632,
#      'balanced_accuracy': 0.8869047619047619},
#     'ROC_AUC_SCORE': {'Macro': 0.9583333333333333,
#      'Micro': 0.9583333333333333,
#      'Weight': 0.9583333333333333},
#     'Classification Report': {'0': {'precision': 0.8571428571428571,
#       'recall': 1.0,
#       'f1-score': 0.923076923076923,
#       'support': 6},
#      '1': {'precision': 1.0,
#       'recall': 0.9166666666666666,
#       'f1-score': 0.9565217391304348,
#       'support': 12},
#      'accuracy': 0.9444444444444444,
#      'macro avg': {'precision': 0.9285714285714286,
#       'recall': 0.9583333333333333,
#       'f1-score': 0.939799331103679,
#       'support': 18},
#      'weighted avg': {'precision': 0.9523809523809523,
#       'recall': 0.9444444444444444,
#       'f1-score': 0.9453734671125977,
#       'support': 18}}},
#    'fold_5': {'Confusion Matrix': {'TP': 5,
#      'TN': 10,
#      'FN': 2,
#      'FP': 2,
#      'precision': 0.7142857142857143,
#      'recall': 0.7142857142857143,
#      'f1_score': 0.7142857142857143,
#      'sensitivity': 0.7142857142857143,
#      'specificity': 0.8333333333333334,
#      'negative_predictive_value': 0.8333333333333334,
#      'false_negative_rate': 0.2857142857142857,
#      'false_positive_rate': 0.16666666666666666,
#      'false_discovery_rate': 0.2857142857142857,
#      'false_omission_rate': 0.16666666666666666,
#      'Positive_likelihood_ratio': 4.2857142857142865,
#      'Negative_likelihood_ratio': 0.3428571428571428,
#      'prevalence_threshold': 0.32571203244301905,
#      'threat_score': 0.35714285714285715,
#      'Prevalence': 0.3684210526315789,
#      'Matthews_correlation_coefficient': 0.006519274376417234,
#      'Fowlkes_Mallows_index': 1.1952286093343936,
#      'informedness': 0.5476190476190477,
#      'markedness': 0.5476190476190477,
#      'Diagnostic_odds_ratio': 12.500000000000004,
#      'accuracy': 0.7894736842105263,
#      'balanced_accuracy': 0.7738095238095238},
#     'ROC_AUC_SCORE': {'Macro': 0.8333333333333334,
#      'Micro': 0.8333333333333334,
#      'Weight': 0.8333333333333334},
#     'Classification Report': {'0': {'precision': 0.7142857142857143,
#       'recall': 0.8333333333333334,
#       'f1-score': 0.7692307692307692,
#       'support': 6},
#      '1': {'precision': 0.9090909090909091,
#       'recall': 0.8333333333333334,
#       'f1-score': 0.8695652173913043,
#       'support': 12},
#      'accuracy': 0.8333333333333334,
#      'macro avg': {'precision': 0.8116883116883117,
#       'recall': 0.8333333333333334,
#       'f1-score': 0.8193979933110367,
#       'support': 18},
#      'weighted avg': {'precision': 0.8441558441558441,
#       'recall': 0.8333333333333334,
#       'f1-score': 0.8361204013377926,
#       'support': 18}}},
#    'fold_6': {'Confusion Matrix': {'TP': 5,
#      'TN': 11,
#      'FN': 1,
#      'FP': 1,
#      'precision': 0.8333333333333334,
#      'recall': 0.8333333333333334,
#      'f1_score': 0.8333333333333334,
#      'sensitivity': 0.8333333333333334,
#      'specificity': 0.9166666666666666,
#      'negative_predictive_value': 0.9166666666666666,
#      'false_negative_rate': 0.16666666666666666,
#      'false_positive_rate': 0.08333333333333333,
#      'false_discovery_rate': 0.16666666666666666,
#      'false_omission_rate': 0.08333333333333333,
#      'Positive_likelihood_ratio': 10.000000000000002,
#      'Negative_likelihood_ratio': 0.18181818181818182,
#      'prevalence_threshold': 0.24025307335204216,
#      'threat_score': 0.38461538461538464,
#      'Prevalence': 0.3333333333333333,
#      'Matthews_correlation_coefficient': 0.010416666666666666,
#      'Fowlkes_Mallows_index': 1.2909944487358056,
#      'informedness': 0.75,
#      'markedness': 0.75,
#      'Diagnostic_odds_ratio': 55.00000000000001,
#      'accuracy': 0.8888888888888888,
#      'balanced_accuracy': 0.875},
#     'ROC_AUC_SCORE': {'Macro': 0.8749999999999999,
#      'Micro': 0.8749999999999999,
#      'Weight': 0.8749999999999999},
#     'Classification Report': {'0': {'precision': 0.8333333333333334,
#       'recall': 0.8333333333333334,
#       'f1-score': 0.8333333333333334,
#       'support': 6},
#      '1': {'precision': 0.9166666666666666,
#       'recall': 0.9166666666666666,
#       'f1-score': 0.9166666666666666,
#       'support': 12},
#      'accuracy': 0.8888888888888888,
#      'macro avg': {'precision': 0.875,
#       'recall': 0.875,
#       'f1-score': 0.875,
#       'support': 18},
#      'weighted avg': {'precision': 0.8888888888888888,
#       'recall': 0.8888888888888888,
#       'f1-score': 0.8888888888888888,
#       'support': 18}}},
#    'fold_7': {'Confusion Matrix': {'TP': 5,
#      'TN': 11,
#      'FN': 1,
#      'FP': 1,
#      'precision': 0.8333333333333334,
#      'recall': 0.8333333333333334,
#      'f1_score': 0.8333333333333334,
#      'sensitivity': 0.8333333333333334,
#      'specificity': 0.9166666666666666,
#      'negative_predictive_value': 0.9166666666666666,
#      'false_negative_rate': 0.16666666666666666,
#      'false_positive_rate': 0.08333333333333333,
#      'false_discovery_rate': 0.16666666666666666,
#      'false_omission_rate': 0.08333333333333333,
#      'Positive_likelihood_ratio': 10.000000000000002,
#      'Negative_likelihood_ratio': 0.18181818181818182,
#      'prevalence_threshold': 0.24025307335204216,
#      'threat_score': 0.38461538461538464,
#      'Prevalence': 0.3333333333333333,
#      'Matthews_correlation_coefficient': 0.010416666666666666,
#      'Fowlkes_Mallows_index': 1.2909944487358056,
#      'informedness': 0.75,
#      'markedness': 0.75,
#      'Diagnostic_odds_ratio': 55.00000000000001,
#      'accuracy': 0.8888888888888888,
#      'balanced_accuracy': 0.875},
#     'ROC_AUC_SCORE': {'Macro': 0.8749999999999999,
#      'Micro': 0.8749999999999999,
#      'Weight': 0.8749999999999999},
#     'Classification Report': {'0': {'precision': 0.8333333333333334,
#       'recall': 0.8333333333333334,
#       'f1-score': 0.8333333333333334,
#       'support': 6},
#      '1': {'precision': 0.9166666666666666,
#       'recall': 0.9166666666666666,
#       'f1-score': 0.9166666666666666,
#       'support': 12},
#      'accuracy': 0.8888888888888888,
#      'macro avg': {'precision': 0.875,
#       'recall': 0.875,
#       'f1-score': 0.875,
#       'support': 18},
#      'weighted avg': {'precision': 0.8888888888888888,
#       'recall': 0.8888888888888888,
#       'f1-score': 0.8888888888888888,
#       'support': 18}}},
#    'fold_8': {'Confusion Matrix': {'TP': 6,
#      'TN': 11,
#      'FN': 1,
#      'FP': 1,
#      'precision': 0.8571428571428571,
#      'recall': 0.8571428571428571,
#      'f1_score': 0.8571428571428571,
#      'sensitivity': 0.8571428571428571,
#      'specificity': 0.9166666666666666,
#      'negative_predictive_value': 0.9166666666666666,
#      'false_negative_rate': 0.14285714285714285,
#      'false_positive_rate': 0.08333333333333333,
#      'false_discovery_rate': 0.14285714285714285,
#      'false_omission_rate': 0.08333333333333333,
#      'Positive_likelihood_ratio': 10.285714285714286,
#      'Negative_likelihood_ratio': 0.15584415584415584,
#      'prevalence_threshold': 0.23769145108682535,
#      'threat_score': 0.46153846153846156,
#      'Prevalence': 0.3684210526315789,
#      'Matthews_correlation_coefficient': 0.009212018140589568,
#      'Fowlkes_Mallows_index': 1.3093073414159542,
#      'informedness': 0.7738095238095237,
#      'markedness': 0.7738095238095237,
#      'Diagnostic_odds_ratio': 66.0,
#      'accuracy': 0.8947368421052632,
#      'balanced_accuracy': 0.8869047619047619},
#     'ROC_AUC_SCORE': {'Macro': 0.9583333333333333,
#      'Micro': 0.9583333333333333,
#      'Weight': 0.9583333333333333},
#     'Classification Report': {'0': {'precision': 0.8571428571428571,
#       'recall': 1.0,
#       'f1-score': 0.923076923076923,
#       'support': 6},
#      '1': {'precision': 1.0,
#       'recall': 0.9166666666666666,
#       'f1-score': 0.9565217391304348,
#       'support': 12},
#      'accuracy': 0.9444444444444444,
#      'macro avg': {'precision': 0.9285714285714286,
#       'recall': 0.9583333333333333,
#       'f1-score': 0.939799331103679,
#       'support': 18},
#      'weighted avg': {'precision': 0.9523809523809523,
#       'recall': 0.9444444444444444,
#       'f1-score': 0.9453734671125977,
#       'support': 18}}},
#    'fold_9': {'Confusion Matrix': {'TP': 0,
#      'TN': 8,
#      'FN': 3,
#      'FP': 3,
#      'precision': 0.0,
#      'recall': 0.0,
#      'f1_score': 0.0,
#      'sensitivity': 0.0,
#      'specificity': 0.7272727272727273,
#      'negative_predictive_value': 0.7272727272727273,
#      'false_negative_rate': 1.0,
#      'false_positive_rate': 0.2727272727272727,
#      'false_discovery_rate': 1.0,
#      'false_omission_rate': 0.2727272727272727,
#      'Positive_likelihood_ratio': 0.0,
#      'Negative_likelihood_ratio': 1.375,
#      'prevalence_threshold': 1.0,
#      'threat_score': 0.0,
#      'Prevalence': 0.21428571428571427,
#      'Matthews_correlation_coefficient': -0.008264462809917356,
#      'Fowlkes_Mallows_index': 0.0,
#      'informedness': -0.2727272727272727,
#      'markedness': -0.2727272727272727,
#      'Diagnostic_odds_ratio': 0.0,
#      'accuracy': 0.5714285714285714,
#      'balanced_accuracy': 0.36363636363636365},
#     'ROC_AUC_SCORE': {'Macro': 0.36363636363636365,
#      'Micro': 0.36363636363636365,
#      'Weight': 0.36363636363636365},
#     'Classification Report': {'0': {'precision': 0.0,
#       'recall': 0.0,
#       'f1-score': 0.0,
#       'support': 2},
#      '1': {'precision': 0.8,
#       'recall': 0.7272727272727273,
#       'f1-score': 0.761904761904762,
#       'support': 11},
#      'accuracy': 0.6153846153846154,
#      'macro avg': {'precision': 0.4,
#       'recall': 0.36363636363636365,
#       'f1-score': 0.380952380952381,
#       'support': 13},
#      'weighted avg': {'precision': 0.676923076923077,
#       'recall': 0.6153846153846154,
#       'f1-score': 0.6446886446886447,
#       'support': 13}}}}},
#  'train_1': {'param': {'penalty': 'l2',
#    'fit_intercept': True,
#    'class_weight': 'balanced',
#    'solver': 'lbfgs'},
#   'train_fold': {'fold_0': {'Confusion Matrix': {'TP': 5,
#      'TN': 10,
#      'FN': 2,
#      'FP': 2,
#      'precision': 0.7142857142857143,
#      'recall': 0.7142857142857143,
#      'f1_score': 0.7142857142857143,
#      'sensitivity': 0.7142857142857143,
#      'specificity': 0.8333333333333334,
#      'negative_predictive_value': 0.8333333333333334,
#      'false_negative_rate': 0.2857142857142857,
#      'false_positive_rate': 0.16666666666666666,
#      'false_discovery_rate': 0.2857142857142857,
#      'false_omission_rate': 0.16666666666666666,
#      'Positive_likelihood_ratio': 4.2857142857142865,
#      'Negative_likelihood_ratio': 0.3428571428571428,
#      'prevalence_threshold': 0.32571203244301905,
#      'threat_score': 0.35714285714285715,
#      'Prevalence': 0.3684210526315789,
#      'Matthews_correlation_coefficient': 0.006519274376417234,
#      'Fowlkes_Mallows_index': 1.1952286093343936,
#      'informedness': 0.5476190476190477,
#      'markedness': 0.5476190476190477,
#      'Diagnostic_odds_ratio': 12.500000000000004,
#      'accuracy': 0.7894736842105263,
#      'balanced_accuracy': 0.7738095238095238},
#     'ROC_AUC_SCORE': {'Macro': 0.8333333333333334,
#      'Micro': 0.8333333333333334,
#      'Weight': 0.8333333333333334},
#     'Classification Report': {'0': {'precision': 0.7142857142857143,
#       'recall': 0.8333333333333334,
#       'f1-score': 0.7692307692307692,
#       'support': 6},
#      '1': {'precision': 0.9090909090909091,
#       'recall': 0.8333333333333334,
#       'f1-score': 0.8695652173913043,
#       'support': 12},
#      'accuracy': 0.8333333333333334,
#      'macro avg': {'precision': 0.8116883116883117,
#       'recall': 0.8333333333333334,
#       'f1-score': 0.8193979933110367,
#       'support': 18},
#      'weighted avg': {'precision': 0.8441558441558441,
#       'recall': 0.8333333333333334,
#       'f1-score': 0.8361204013377926,
#       'support': 18}}},
#    'fold_1': {'Confusion Matrix': {'TP': 4,
#      'TN': 10,
#      'FN': 2,
#      'FP': 2,
#      'precision': 0.6666666666666666,
#      'recall': 0.6666666666666666,
#      'f1_score': 0.6666666666666666,
#      'sensitivity': 0.6666666666666666,
#      'specificity': 0.8333333333333334,
#      'negative_predictive_value': 0.8333333333333334,
#      'false_negative_rate': 0.3333333333333333,
#      'false_positive_rate': 0.16666666666666666,
#      'false_discovery_rate': 0.3333333333333333,
#      'false_omission_rate': 0.16666666666666666,
#      'Positive_likelihood_ratio': 4.0,
#      'Negative_likelihood_ratio': 0.39999999999999997,
#      'prevalence_threshold': 0.33333333333333337,
#      'threat_score': 0.2857142857142857,
#      'Prevalence': 0.3333333333333333,
#      'Matthews_correlation_coefficient': 0.006944444444444444,
#      'Fowlkes_Mallows_index': 1.1547005383792515,
#      'informedness': 0.5,
#      'markedness': 0.5,
#      'Diagnostic_odds_ratio': 10.0,
#      'accuracy': 0.7777777777777778,
#      'balanced_accuracy': 0.75},
#     'ROC_AUC_SCORE': {'Macro': 0.7500000000000002,
#      'Micro': 0.7500000000000002,
#      'Weight': 0.7500000000000002},
#     'Classification Report': {'0': {'precision': 0.6666666666666666,
#       'recall': 0.6666666666666666,
#       'f1-score': 0.6666666666666666,
#       'support': 6},
#      '1': {'precision': 0.8333333333333334,
#       'recall': 0.8333333333333334,
#       'f1-score': 0.8333333333333334,
#       'support': 12},
#      'accuracy': 0.7777777777777778,
#      'macro avg': {'precision': 0.75,
#       'recall': 0.75,
#       'f1-score': 0.75,
#       'support': 18},
#      'weighted avg': {'precision': 0.7777777777777778,
#       'recall': 0.7777777777777778,
#       'f1-score': 0.7777777777777778,
#       'support': 18}}},
#    'fold_2': {'Confusion Matrix': {'TP': 4,
#      'TN': 11,
#      'FN': 1,
#      'FP': 1,
#      'precision': 0.8,
#      'recall': 0.8,
#      'f1_score': 0.8,
#      'sensitivity': 0.8,
#      'specificity': 0.9166666666666666,
#      'negative_predictive_value': 0.9166666666666666,
#      'false_negative_rate': 0.2,
#      'false_positive_rate': 0.08333333333333333,
#      'false_discovery_rate': 0.2,
#      'false_omission_rate': 0.08333333333333333,
#      'Positive_likelihood_ratio': 9.600000000000001,
#      'Negative_likelihood_ratio': 0.2181818181818182,
#      'prevalence_threshold': 0.24399845080999225,
#      'threat_score': 0.3076923076923077,
#      'Prevalence': 0.29411764705882354,
#      'Matthews_correlation_coefficient': 0.011944444444444445,
#      'Fowlkes_Mallows_index': 1.2649110640673518,
#      'informedness': 0.7166666666666668,
#      'markedness': 0.7166666666666668,
#      'Diagnostic_odds_ratio': 44.0,
#      'accuracy': 0.8823529411764706,
#      'balanced_accuracy': 0.8583333333333334},
#     'ROC_AUC_SCORE': {'Macro': 0.7916666666666667,
#      'Micro': 0.7916666666666667,
#      'Weight': 0.7916666666666667},
#     'Classification Report': {'0': {'precision': 0.8,
#       'recall': 0.6666666666666666,
#       'f1-score': 0.7272727272727272,
#       'support': 6},
#      '1': {'precision': 0.8461538461538461,
#       'recall': 0.9166666666666666,
#       'f1-score': 0.8799999999999999,
#       'support': 12},
#      'accuracy': 0.8333333333333334,
#      'macro avg': {'precision': 0.823076923076923,
#       'recall': 0.7916666666666666,
#       'f1-score': 0.8036363636363635,
#       'support': 18},
#      'weighted avg': {'precision': 0.8307692307692308,
#       'recall': 0.8333333333333334,
#       'f1-score': 0.829090909090909,
#       'support': 18}}},
#    'fold_3': {'Confusion Matrix': {'TP': 6,
#      'TN': 7,
#      'FN': 5,
#      'FP': 5,
#      'precision': 0.5454545454545454,
#      'recall': 0.5454545454545454,
#      'f1_score': 0.5454545454545454,
#      'sensitivity': 0.5454545454545454,
#      'specificity': 0.5833333333333334,
#      'negative_predictive_value': 0.5833333333333334,
#      'false_negative_rate': 0.45454545454545453,
#      'false_positive_rate': 0.4166666666666667,
#      'false_discovery_rate': 0.45454545454545453,
#      'false_omission_rate': 0.4166666666666667,
#      'Positive_likelihood_ratio': 1.3090909090909089,
#      'Negative_likelihood_ratio': 0.7792207792207791,
#      'prevalence_threshold': 0.4663841700122996,
#      'threat_score': 0.35294117647058826,
#      'Prevalence': 0.4782608695652174,
#      'Matthews_correlation_coefficient': 0.0009756657483930211,
#      'Fowlkes_Mallows_index': 1.044465935734187,
#      'informedness': 0.1287878787878789,
#      'markedness': 0.1287878787878789,
#      'Diagnostic_odds_ratio': 1.68,
#      'accuracy': 0.5652173913043478,
#      'balanced_accuracy': 0.5643939393939394},
#     'ROC_AUC_SCORE': {'Macro': 0.7916666666666667,
#      'Micro': 0.7916666666666667,
#      'Weight': 0.7916666666666667},
#     'Classification Report': {'0': {'precision': 0.5454545454545454,
#       'recall': 1.0,
#       'f1-score': 0.7058823529411764,
#       'support': 6},
#      '1': {'precision': 1.0,
#       'recall': 0.5833333333333334,
#       'f1-score': 0.7368421052631579,
#       'support': 12},
#      'accuracy': 0.7222222222222222,
#      'macro avg': {'precision': 0.7727272727272727,
#       'recall': 0.7916666666666667,
#       'f1-score': 0.7213622291021671,
#       'support': 18},
#      'weighted avg': {'precision': 0.8484848484848485,
#       'recall': 0.7222222222222222,
#       'f1-score': 0.7265221878224973,
#       'support': 18}}},
#    'fold_4': {'Confusion Matrix': {'TP': 6,
#      'TN': 11,
#      'FN': 1,
#      'FP': 1,
#      'precision': 0.8571428571428571,
#      'recall': 0.8571428571428571,
#      'f1_score': 0.8571428571428571,
#      'sensitivity': 0.8571428571428571,
#      'specificity': 0.9166666666666666,
#      'negative_predictive_value': 0.9166666666666666,
#      'false_negative_rate': 0.14285714285714285,
#      'false_positive_rate': 0.08333333333333333,
#      'false_discovery_rate': 0.14285714285714285,
#      'false_omission_rate': 0.08333333333333333,
#      'Positive_likelihood_ratio': 10.285714285714286,
#      'Negative_likelihood_ratio': 0.15584415584415584,
#      'prevalence_threshold': 0.23769145108682535,
#      'threat_score': 0.46153846153846156,
#      'Prevalence': 0.3684210526315789,
#      'Matthews_correlation_coefficient': 0.009212018140589568,
#      'Fowlkes_Mallows_index': 1.3093073414159542,
#      'informedness': 0.7738095238095237,
#      'markedness': 0.7738095238095237,
#      'Diagnostic_odds_ratio': 66.0,
#      'accuracy': 0.8947368421052632,
#      'balanced_accuracy': 0.8869047619047619},
#     'ROC_AUC_SCORE': {'Macro': 0.9583333333333333,
#      'Micro': 0.9583333333333333,
#      'Weight': 0.9583333333333333},
#     'Classification Report': {'0': {'precision': 0.8571428571428571,
#       'recall': 1.0,
#       'f1-score': 0.923076923076923,
#       'support': 6},
#      '1': {'precision': 1.0,
#       'recall': 0.9166666666666666,
#       'f1-score': 0.9565217391304348,
#       'support': 12},
#      'accuracy': 0.9444444444444444,
#      'macro avg': {'precision': 0.9285714285714286,
#       'recall': 0.9583333333333333,
#       'f1-score': 0.939799331103679,
#       'support': 18},
#      'weighted avg': {'precision': 0.9523809523809523,
#       'recall': 0.9444444444444444,
#       'f1-score': 0.9453734671125977,
#       'support': 18}}},
#    'fold_5': {'Confusion Matrix': {'TP': 5,
#      'TN': 10,
#      'FN': 2,
#      'FP': 2,
#      'precision': 0.7142857142857143,
#      'recall': 0.7142857142857143,
#      'f1_score': 0.7142857142857143,
#      'sensitivity': 0.7142857142857143,
#      'specificity': 0.8333333333333334,
#      'negative_predictive_value': 0.8333333333333334,
#      'false_negative_rate': 0.2857142857142857,
#      'false_positive_rate': 0.16666666666666666,
#      'false_discovery_rate': 0.2857142857142857,
#      'false_omission_rate': 0.16666666666666666,
#      'Positive_likelihood_ratio': 4.2857142857142865,
#      'Negative_likelihood_ratio': 0.3428571428571428,
#      'prevalence_threshold': 0.32571203244301905,
#      'threat_score': 0.35714285714285715,
#      'Prevalence': 0.3684210526315789,
#      'Matthews_correlation_coefficient': 0.006519274376417234,
#      'Fowlkes_Mallows_index': 1.1952286093343936,
#      'informedness': 0.5476190476190477,
#      'markedness': 0.5476190476190477,
#      'Diagnostic_odds_ratio': 12.500000000000004,
#      'accuracy': 0.7894736842105263,
#      'balanced_accuracy': 0.7738095238095238},
#     'ROC_AUC_SCORE': {'Macro': 0.8333333333333334,
#      'Micro': 0.8333333333333334,
#      'Weight': 0.8333333333333334},
#     'Classification Report': {'0': {'precision': 0.7142857142857143,
#       'recall': 0.8333333333333334,
#       'f1-score': 0.7692307692307692,
#       'support': 6},
#      '1': {'precision': 0.9090909090909091,
#       'recall': 0.8333333333333334,
#       'f1-score': 0.8695652173913043,
#       'support': 12},
#      'accuracy': 0.8333333333333334,
#      'macro avg': {'precision': 0.8116883116883117,
#       'recall': 0.8333333333333334,
#       'f1-score': 0.8193979933110367,
#       'support': 18},
#      'weighted avg': {'precision': 0.8441558441558441,
#       'recall': 0.8333333333333334,
#       'f1-score': 0.8361204013377926,
#       'support': 18}}},
#    'fold_6': {'Confusion Matrix': {'TP': 5,
#      'TN': 11,
#      'FN': 1,
#      'FP': 1,
#      'precision': 0.8333333333333334,
#      'recall': 0.8333333333333334,
#      'f1_score': 0.8333333333333334,
#      'sensitivity': 0.8333333333333334,
#      'specificity': 0.9166666666666666,
#      'negative_predictive_value': 0.9166666666666666,
#      'false_negative_rate': 0.16666666666666666,
#      'false_positive_rate': 0.08333333333333333,
#      'false_discovery_rate': 0.16666666666666666,
#      'false_omission_rate': 0.08333333333333333,
#      'Positive_likelihood_ratio': 10.000000000000002,
#      'Negative_likelihood_ratio': 0.18181818181818182,
#      'prevalence_threshold': 0.24025307335204216,
#      'threat_score': 0.38461538461538464,
#      'Prevalence': 0.3333333333333333,
#      'Matthews_correlation_coefficient': 0.010416666666666666,
#      'Fowlkes_Mallows_index': 1.2909944487358056,
#      'informedness': 0.75,
#      'markedness': 0.75,
#      'Diagnostic_odds_ratio': 55.00000000000001,
#      'accuracy': 0.8888888888888888,
#      'balanced_accuracy': 0.875},
#     'ROC_AUC_SCORE': {'Macro': 0.8749999999999999,
#      'Micro': 0.8749999999999999,
#      'Weight': 0.8749999999999999},
#     'Classification Report': {'0': {'precision': 0.8333333333333334,
#       'recall': 0.8333333333333334,
#       'f1-score': 0.8333333333333334,
#       'support': 6},
#      '1': {'precision': 0.9166666666666666,
#       'recall': 0.9166666666666666,
#       'f1-score': 0.9166666666666666,
#       'support': 12},
#      'accuracy': 0.8888888888888888,
#      'macro avg': {'precision': 0.875,
#       'recall': 0.875,
#       'f1-score': 0.875,
#       'support': 18},
#      'weighted avg': {'precision': 0.8888888888888888,
#       'recall': 0.8888888888888888,
#       'f1-score': 0.8888888888888888,
#       'support': 18}}},
#    'fold_7': {'Confusion Matrix': {'TP': 5,
#      'TN': 11,
#      'FN': 1,
#      'FP': 1,
#      'precision': 0.8333333333333334,
#      'recall': 0.8333333333333334,
#      'f1_score': 0.8333333333333334,
#      'sensitivity': 0.8333333333333334,
#      'specificity': 0.9166666666666666,
#      'negative_predictive_value': 0.9166666666666666,
#      'false_negative_rate': 0.16666666666666666,
#      'false_positive_rate': 0.08333333333333333,
#      'false_discovery_rate': 0.16666666666666666,
#      'false_omission_rate': 0.08333333333333333,
#      'Positive_likelihood_ratio': 10.000000000000002,
#      'Negative_likelihood_ratio': 0.18181818181818182,
#      'prevalence_threshold': 0.24025307335204216,
#      'threat_score': 0.38461538461538464,
#      'Prevalence': 0.3333333333333333,
#      'Matthews_correlation_coefficient': 0.010416666666666666,
#      'Fowlkes_Mallows_index': 1.2909944487358056,
#      'informedness': 0.75,
#      'markedness': 0.75,
#      'Diagnostic_odds_ratio': 55.00000000000001,
#      'accuracy': 0.8888888888888888,
#      'balanced_accuracy': 0.875},
#     'ROC_AUC_SCORE': {'Macro': 0.8749999999999999,
#      'Micro': 0.8749999999999999,
#      'Weight': 0.8749999999999999},
#     'Classification Report': {'0': {'precision': 0.8333333333333334,
#       'recall': 0.8333333333333334,
#       'f1-score': 0.8333333333333334,
#       'support': 6},
#      '1': {'precision': 0.9166666666666666,
#       'recall': 0.9166666666666666,
#       'f1-score': 0.9166666666666666,
#       'support': 12},
#      'accuracy': 0.8888888888888888,
#      'macro avg': {'precision': 0.875,
#       'recall': 0.875,
#       'f1-score': 0.875,
#       'support': 18},
#      'weighted avg': {'precision': 0.8888888888888888,
#       'recall': 0.8888888888888888,
#       'f1-score': 0.8888888888888888,
#       'support': 18}}},
#    'fold_8': {'Confusion Matrix': {'TP': 6,
#      'TN': 11,
#      'FN': 1,
#      'FP': 1,
#      'precision': 0.8571428571428571,
#      'recall': 0.8571428571428571,
#      'f1_score': 0.8571428571428571,
#      'sensitivity': 0.8571428571428571,
#      'specificity': 0.9166666666666666,
#      'negative_predictive_value': 0.9166666666666666,
#      'false_negative_rate': 0.14285714285714285,
#      'false_positive_rate': 0.08333333333333333,
#      'false_discovery_rate': 0.14285714285714285,
#      'false_omission_rate': 0.08333333333333333,
#      'Positive_likelihood_ratio': 10.285714285714286,
#      'Negative_likelihood_ratio': 0.15584415584415584,
#      'prevalence_threshold': 0.23769145108682535,
#      'threat_score': 0.46153846153846156,
#      'Prevalence': 0.3684210526315789,
#      'Matthews_correlation_coefficient': 0.009212018140589568,
#      'Fowlkes_Mallows_index': 1.3093073414159542,
#      'informedness': 0.7738095238095237,
#      'markedness': 0.7738095238095237,
#      'Diagnostic_odds_ratio': 66.0,
#      'accuracy': 0.8947368421052632,
#      'balanced_accuracy': 0.8869047619047619},
#     'ROC_AUC_SCORE': {'Macro': 0.9583333333333333,
#      'Micro': 0.9583333333333333,
#      'Weight': 0.9583333333333333},
#     'Classification Report': {'0': {'precision': 0.8571428571428571,
#       'recall': 1.0,
#       'f1-score': 0.923076923076923,
#       'support': 6},
#      '1': {'precision': 1.0,
#       'recall': 0.9166666666666666,
#       'f1-score': 0.9565217391304348,
#       'support': 12},
#      'accuracy': 0.9444444444444444,
#      'macro avg': {'precision': 0.9285714285714286,
#       'recall': 0.9583333333333333,
#       'f1-score': 0.939799331103679,
#       'support': 18},
#      'weighted avg': {'precision': 0.9523809523809523,
#       'recall': 0.9444444444444444,
#       'f1-score': 0.9453734671125977,
#       'support': 18}}},
#    'fold_9': {'Confusion Matrix': {'TP': 0,
#      'TN': 8,
#      'FN': 3,
#      'FP': 3,
#      'precision': 0.0,
#      'recall': 0.0,
#      'f1_score': 0.0,
#      'sensitivity': 0.0,
#      'specificity': 0.7272727272727273,
#      'negative_predictive_value': 0.7272727272727273,
#      'false_negative_rate': 1.0,
#      'false_positive_rate': 0.2727272727272727,
#      'false_discovery_rate': 1.0,
#      'false_omission_rate': 0.2727272727272727,
#      'Positive_likelihood_ratio': 0.0,
#      'Negative_likelihood_ratio': 1.375,
#      'prevalence_threshold': 1.0,
#      'threat_score': 0.0,
#      'Prevalence': 0.21428571428571427,
#      'Matthews_correlation_coefficient': -0.008264462809917356,
#      'Fowlkes_Mallows_index': 0.0,
#      'informedness': -0.2727272727272727,
#      'markedness': -0.2727272727272727,
#      'Diagnostic_odds_ratio': 0.0,
#      'accuracy': 0.5714285714285714,
#      'balanced_accuracy': 0.36363636363636365},
#     'ROC_AUC_SCORE': {'Macro': 0.36363636363636365,
#      'Micro': 0.36363636363636365,
#      'Weight': 0.36363636363636365},
#     'Classification Report': {'0': {'precision': 0.0,
#       'recall': 0.0,
#       'f1-score': 0.0,
#       'support': 2},
#      '1': {'precision': 0.8,
#       'recall': 0.7272727272727273,
#       'f1-score': 0.761904761904762,
#       'support': 11},
#      'accuracy': 0.6153846153846154,
#      'macro avg': {'precision': 0.4,
#       'recall': 0.36363636363636365,
#       'f1-score': 0.380952380952381,
#       'support': 13},
#      'weighted avg': {'precision': 0.676923076923077,
#       'recall': 0.6153846153846154,
#       'f1-score': 0.6446886446886447,
#       'support': 13}}}}},
#  'train_2': {'param': {'penalty': 'l2',
#    'fit_intercept': True,
#    'class_weight': 'balanced',
#    'solver': 'liblinear'},
#   'train_fold': {'fold_0': {'Confusion Matrix': {'TP': 5,
#      'TN': 10,
#      'FN': 2,
#      'FP': 2,
#      'precision': 0.7142857142857143,
#      'recall': 0.7142857142857143,
#      'f1_score': 0.7142857142857143,
#      'sensitivity': 0.7142857142857143,
#      'specificity': 0.8333333333333334,
#      'negative_predictive_value': 0.8333333333333334,
#      'false_negative_rate': 0.2857142857142857,
#      'false_positive_rate': 0.16666666666666666,
#      'false_discovery_rate': 0.2857142857142857,
#      'false_omission_rate': 0.16666666666666666,
#      'Positive_likelihood_ratio': 4.2857142857142865,
#      'Negative_likelihood_ratio': 0.3428571428571428,
#      'prevalence_threshold': 0.32571203244301905,
#      'threat_score': 0.35714285714285715,
#      'Prevalence': 0.3684210526315789,
#      'Matthews_correlation_coefficient': 0.006519274376417234,
#      'Fowlkes_Mallows_index': 1.1952286093343936,
#      'informedness': 0.5476190476190477,
#      'markedness': 0.5476190476190477,
#      'Diagnostic_odds_ratio': 12.500000000000004,
#      'accuracy': 0.7894736842105263,
#      'balanced_accuracy': 0.7738095238095238},
#     'ROC_AUC_SCORE': {'Macro': 0.8333333333333334,
#      'Micro': 0.8333333333333334,
#      'Weight': 0.8333333333333334},
#     'Classification Report': {'0': {'precision': 0.7142857142857143,
#       'recall': 0.8333333333333334,
#       'f1-score': 0.7692307692307692,
#       'support': 6},
#      '1': {'precision': 0.9090909090909091,
#       'recall': 0.8333333333333334,
#       'f1-score': 0.8695652173913043,
#       'support': 12},
#      'accuracy': 0.8333333333333334,
#      'macro avg': {'precision': 0.8116883116883117,
#       'recall': 0.8333333333333334,
#       'f1-score': 0.8193979933110367,
#       'support': 18},
#      'weighted avg': {'precision': 0.8441558441558441,
#       'recall': 0.8333333333333334,
#       'f1-score': 0.8361204013377926,
#       'support': 18}}},
#    'fold_1': {'Confusion Matrix': {'TP': 4,
#      'TN': 10,
#      'FN': 2,
#      'FP': 2,
#      'precision': 0.6666666666666666,
#      'recall': 0.6666666666666666,
#      'f1_score': 0.6666666666666666,
#      'sensitivity': 0.6666666666666666,
#      'specificity': 0.8333333333333334,
#      'negative_predictive_value': 0.8333333333333334,
#      'false_negative_rate': 0.3333333333333333,
#      'false_positive_rate': 0.16666666666666666,
#      'false_discovery_rate': 0.3333333333333333,
#      'false_omission_rate': 0.16666666666666666,
#      'Positive_likelihood_ratio': 4.0,
#      'Negative_likelihood_ratio': 0.39999999999999997,
#      'prevalence_threshold': 0.33333333333333337,
#      'threat_score': 0.2857142857142857,
#      'Prevalence': 0.3333333333333333,
#      'Matthews_correlation_coefficient': 0.006944444444444444,
#      'Fowlkes_Mallows_index': 1.1547005383792515,
#      'informedness': 0.5,
#      'markedness': 0.5,
#      'Diagnostic_odds_ratio': 10.0,
#      'accuracy': 0.7777777777777778,
#      'balanced_accuracy': 0.75},
#     'ROC_AUC_SCORE': {'Macro': 0.7500000000000002,
#      'Micro': 0.7500000000000002,
#      'Weight': 0.7500000000000002},
#     'Classification Report': {'0': {'precision': 0.6666666666666666,
#       'recall': 0.6666666666666666,
#       'f1-score': 0.6666666666666666,
#       'support': 6},
#      '1': {'precision': 0.8333333333333334,
#       'recall': 0.8333333333333334,
#       'f1-score': 0.8333333333333334,
#       'support': 12},
#      'accuracy': 0.7777777777777778,
#      'macro avg': {'precision': 0.75,
#       'recall': 0.75,
#       'f1-score': 0.75,
#       'support': 18},
#      'weighted avg': {'precision': 0.7777777777777778,
#       'recall': 0.7777777777777778,
#       'f1-score': 0.7777777777777778,
#       'support': 18}}},
#    'fold_2': {'Confusion Matrix': {'TP': 4,
#      'TN': 11,
#      'FN': 1,
#      'FP': 1,
#      'precision': 0.8,
#      'recall': 0.8,
#      'f1_score': 0.8,
#      'sensitivity': 0.8,
#      'specificity': 0.9166666666666666,
#      'negative_predictive_value': 0.9166666666666666,
#      'false_negative_rate': 0.2,
#      'false_positive_rate': 0.08333333333333333,
#      'false_discovery_rate': 0.2,
#      'false_omission_rate': 0.08333333333333333,
#      'Positive_likelihood_ratio': 9.600000000000001,
#      'Negative_likelihood_ratio': 0.2181818181818182,
#      'prevalence_threshold': 0.24399845080999225,
#      'threat_score': 0.3076923076923077,
#      'Prevalence': 0.29411764705882354,
#      'Matthews_correlation_coefficient': 0.011944444444444445,
#      'Fowlkes_Mallows_index': 1.2649110640673518,
#      'informedness': 0.7166666666666668,
#      'markedness': 0.7166666666666668,
#      'Diagnostic_odds_ratio': 44.0,
#      'accuracy': 0.8823529411764706,
#      'balanced_accuracy': 0.8583333333333334},
#     'ROC_AUC_SCORE': {'Macro': 0.7916666666666667,
#      'Micro': 0.7916666666666667,
#      'Weight': 0.7916666666666667},
#     'Classification Report': {'0': {'precision': 0.8,
#       'recall': 0.6666666666666666,
#       'f1-score': 0.7272727272727272,
#       'support': 6},
#      '1': {'precision': 0.8461538461538461,
#       'recall': 0.9166666666666666,
#       'f1-score': 0.8799999999999999,
#       'support': 12},
#      'accuracy': 0.8333333333333334,
#      'macro avg': {'precision': 0.823076923076923,
#       'recall': 0.7916666666666666,
#       'f1-score': 0.8036363636363635,
#       'support': 18},
#      'weighted avg': {'precision': 0.8307692307692308,
#       'recall': 0.8333333333333334,
#       'f1-score': 0.829090909090909,
#       'support': 18}}},
#    'fold_3': {'Confusion Matrix': {'TP': 6,
#      'TN': 7,
#      'FN': 5,
#      'FP': 5,
#      'precision': 0.5454545454545454,
#      'recall': 0.5454545454545454,
#      'f1_score': 0.5454545454545454,
#      'sensitivity': 0.5454545454545454,
#      'specificity': 0.5833333333333334,
#      'negative_predictive_value': 0.5833333333333334,
#      'false_negative_rate': 0.45454545454545453,
#      'false_positive_rate': 0.4166666666666667,
#      'false_discovery_rate': 0.45454545454545453,
#      'false_omission_rate': 0.4166666666666667,
#      'Positive_likelihood_ratio': 1.3090909090909089,
#      'Negative_likelihood_ratio': 0.7792207792207791,
#      'prevalence_threshold': 0.4663841700122996,
#      'threat_score': 0.35294117647058826,
#      'Prevalence': 0.4782608695652174,
#      'Matthews_correlation_coefficient': 0.0009756657483930211,
#      'Fowlkes_Mallows_index': 1.044465935734187,
#      'informedness': 0.1287878787878789,
#      'markedness': 0.1287878787878789,
#      'Diagnostic_odds_ratio': 1.68,
#      'accuracy': 0.5652173913043478,
#      'balanced_accuracy': 0.5643939393939394},
#     'ROC_AUC_SCORE': {'Macro': 0.7916666666666667,
#      'Micro': 0.7916666666666667,
#      'Weight': 0.7916666666666667},
#     'Classification Report': {'0': {'precision': 0.5454545454545454,
#       'recall': 1.0,
#       'f1-score': 0.7058823529411764,
#       'support': 6},
#      '1': {'precision': 1.0,
#       'recall': 0.5833333333333334,
#       'f1-score': 0.7368421052631579,
#       'support': 12},
#      'accuracy': 0.7222222222222222,
#      'macro avg': {'precision': 0.7727272727272727,
#       'recall': 0.7916666666666667,
#       'f1-score': 0.7213622291021671,
#       'support': 18},
#      'weighted avg': {'precision': 0.8484848484848485,
#       'recall': 0.7222222222222222,
#       'f1-score': 0.7265221878224973,
#       'support': 18}}},
#    'fold_4': {'Confusion Matrix': {'TP': 6,
#      'TN': 11,
#      'FN': 1,
#      'FP': 1,
#      'precision': 0.8571428571428571,
#      'recall': 0.8571428571428571,
#      'f1_score': 0.8571428571428571,
#      'sensitivity': 0.8571428571428571,
#      'specificity': 0.9166666666666666,
#      'negative_predictive_value': 0.9166666666666666,
#      'false_negative_rate': 0.14285714285714285,
#      'false_positive_rate': 0.08333333333333333,
#      'false_discovery_rate': 0.14285714285714285,
#      'false_omission_rate': 0.08333333333333333,
#      'Positive_likelihood_ratio': 10.285714285714286,
#      'Negative_likelihood_ratio': 0.15584415584415584,
#      'prevalence_threshold': 0.23769145108682535,
#      'threat_score': 0.46153846153846156,
#      'Prevalence': 0.3684210526315789,
#      'Matthews_correlation_coefficient': 0.009212018140589568,
#      'Fowlkes_Mallows_index': 1.3093073414159542,
#      'informedness': 0.7738095238095237,
#      'markedness': 0.7738095238095237,
#      'Diagnostic_odds_ratio': 66.0,
#      'accuracy': 0.8947368421052632,
#      'balanced_accuracy': 0.8869047619047619},
#     'ROC_AUC_SCORE': {'Macro': 0.9583333333333333,
#      'Micro': 0.9583333333333333,
#      'Weight': 0.9583333333333333},
#     'Classification Report': {'0': {'precision': 0.8571428571428571,
#       'recall': 1.0,
#       'f1-score': 0.923076923076923,
#       'support': 6},
#      '1': {'precision': 1.0,
#       'recall': 0.9166666666666666,
#       'f1-score': 0.9565217391304348,
#       'support': 12},
#      'accuracy': 0.9444444444444444,
#      'macro avg': {'precision': 0.9285714285714286,
#       'recall': 0.9583333333333333,
#       'f1-score': 0.939799331103679,
#       'support': 18},
#      'weighted avg': {'precision': 0.9523809523809523,
#       'recall': 0.9444444444444444,
#       'f1-score': 0.9453734671125977,
#       'support': 18}}},
#    'fold_5': {'Confusion Matrix': {'TP': 5,
#      'TN': 10,
#      'FN': 2,
#      'FP': 2,
#      'precision': 0.7142857142857143,
#      'recall': 0.7142857142857143,
#      'f1_score': 0.7142857142857143,
#      'sensitivity': 0.7142857142857143,
#      'specificity': 0.8333333333333334,
#      'negative_predictive_value': 0.8333333333333334,
#      'false_negative_rate': 0.2857142857142857,
#      'false_positive_rate': 0.16666666666666666,
#      'false_discovery_rate': 0.2857142857142857,
#      'false_omission_rate': 0.16666666666666666,
#      'Positive_likelihood_ratio': 4.2857142857142865,
#      'Negative_likelihood_ratio': 0.3428571428571428,
#      'prevalence_threshold': 0.32571203244301905,
#      'threat_score': 0.35714285714285715,
#      'Prevalence': 0.3684210526315789,
#      'Matthews_correlation_coefficient': 0.006519274376417234,
#      'Fowlkes_Mallows_index': 1.1952286093343936,
#      'informedness': 0.5476190476190477,
#      'markedness': 0.5476190476190477,
#      'Diagnostic_odds_ratio': 12.500000000000004,
#      'accuracy': 0.7894736842105263,
#      'balanced_accuracy': 0.7738095238095238},
#     'ROC_AUC_SCORE': {'Macro': 0.8333333333333334,
#      'Micro': 0.8333333333333334,
#      'Weight': 0.8333333333333334},
#     'Classification Report': {'0': {'precision': 0.7142857142857143,
#       'recall': 0.8333333333333334,
#       'f1-score': 0.7692307692307692,
#       'support': 6},
#      '1': {'precision': 0.9090909090909091,
#       'recall': 0.8333333333333334,
#       'f1-score': 0.8695652173913043,
#       'support': 12},
#      'accuracy': 0.8333333333333334,
#      'macro avg': {'precision': 0.8116883116883117,
#       'recall': 0.8333333333333334,
#       'f1-score': 0.8193979933110367,
#       'support': 18},
#      'weighted avg': {'precision': 0.8441558441558441,
#       'recall': 0.8333333333333334,
#       'f1-score': 0.8361204013377926,
#       'support': 18}}},
#    'fold_6': {'Confusion Matrix': {'TP': 5,
#      'TN': 11,
#      'FN': 1,
#      'FP': 1,
#      'precision': 0.8333333333333334,
#      'recall': 0.8333333333333334,
#      'f1_score': 0.8333333333333334,
#      'sensitivity': 0.8333333333333334,
#      'specificity': 0.9166666666666666,
#      'negative_predictive_value': 0.9166666666666666,
#      'false_negative_rate': 0.16666666666666666,
#      'false_positive_rate': 0.08333333333333333,
#      'false_discovery_rate': 0.16666666666666666,
#      'false_omission_rate': 0.08333333333333333,
#      'Positive_likelihood_ratio': 10.000000000000002,
#      'Negative_likelihood_ratio': 0.18181818181818182,
#      'prevalence_threshold': 0.24025307335204216,
#      'threat_score': 0.38461538461538464,
#      'Prevalence': 0.3333333333333333,
#      'Matthews_correlation_coefficient': 0.010416666666666666,
#      'Fowlkes_Mallows_index': 1.2909944487358056,
#      'informedness': 0.75,
#      'markedness': 0.75,
#      'Diagnostic_odds_ratio': 55.00000000000001,
#      'accuracy': 0.8888888888888888,
#      'balanced_accuracy': 0.875},
#     'ROC_AUC_SCORE': {'Macro': 0.8749999999999999,
#      'Micro': 0.8749999999999999,
#      'Weight': 0.8749999999999999},
# ...
#      'Prevalence': 0.0,
#      'Matthews_correlation_coefficient': nan,
#      'Fowlkes_Mallows_index': nan,
#      'informedness': nan,
#      'markedness': nan,
#      'Diagnostic_odds_ratio': nan,
#      'accuracy': 1.0,
#      'balanced_accuracy': nan},
#     'ROC_AUC_SCORE': {'Macro': 0.5, 'Micro': 0.5, 'Weight': 0.5},
#     'Classification Report': {'0': {'precision': 0.0,
#       'recall': 0.0,
#       'f1-score': 0.0,
#       'support': 6},
#      '1': {'precision': 0.6666666666666666,
#       'recall': 1.0,
#       'f1-score': 0.8,
#       'support': 12},
#      'accuracy': 0.6666666666666666,
#      'macro avg': {'precision': 0.3333333333333333,
#       'recall': 0.5,
#       'f1-score': 0.4,
#       'support': 18},
#      'weighted avg': {'precision': 0.4444444444444444,
#       'recall': 0.6666666666666666,
#       'f1-score': 0.5333333333333334,
#       'support': 18}}},
#    'fold_9': {'Confusion Matrix': {'TP': 0,
#      'TN': 11,
#      'FN': 0,
#      'FP': 0,
#      'precision': nan,
#      'recall': nan,
#      'f1_score': nan,
#      'sensitivity': nan,
#      'specificity': 1.0,
#      'negative_predictive_value': 1.0,
#      'false_negative_rate': nan,
#      'false_positive_rate': 0.0,
#      'false_discovery_rate': nan,
#      'false_omission_rate': 0.0,
#      'Positive_likelihood_ratio': nan,
#      'Negative_likelihood_ratio': nan,
#      'prevalence_threshold': nan,
#      'threat_score': 0.0,
#      'Prevalence': 0.0,
#      'Matthews_correlation_coefficient': nan,
#      'Fowlkes_Mallows_index': nan,
#      'informedness': nan,
#      'markedness': nan,
#      'Diagnostic_odds_ratio': nan,
#      'accuracy': 1.0,
#      'balanced_accuracy': nan},
#     'ROC_AUC_SCORE': {'Macro': 0.5, 'Micro': 0.5, 'Weight': 0.5},
#     'Classification Report': {'0': {'precision': 0.0,
#       'recall': 0.0,
#       'f1-score': 0.0,
#       'support': 2},
#      '1': {'precision': 0.8461538461538461,
#       'recall': 1.0,
#       'f1-score': 0.9166666666666666,
#       'support': 11},
#      'accuracy': 0.8461538461538461,
#      'macro avg': {'precision': 0.4230769230769231,
#       'recall': 0.5,
#       'f1-score': 0.4583333333333333,
#       'support': 13},
#      'weighted avg': {'precision': 0.7159763313609468,
#       'recall': 0.8461538461538461,
#       'f1-score': 0.7756410256410255,
#       'support': 13}}}}},
#  'train_19': {'param': {'penalty': 'l2',
#    'fit_intercept': False,
#    'class_weight': None,
#    'solver': 'saga'},
#   'train_fold': {'fold_0': {'Confusion Matrix': {'TP': 0,
#      'TN': 12,
#      'FN': 0,
#      'FP': 0,
#      'precision': nan,
#      'recall': nan,
#      'f1_score': nan,
#      'sensitivity': nan,
#      'specificity': 1.0,
#      'negative_predictive_value': 1.0,
#      'false_negative_rate': nan,
#      'false_positive_rate': 0.0,
#      'false_discovery_rate': nan,
#      'false_omission_rate': 0.0,
#      'Positive_likelihood_ratio': nan,
#      'Negative_likelihood_ratio': nan,
#      'prevalence_threshold': nan,
#      'threat_score': 0.0,
#      'Prevalence': 0.0,
#      'Matthews_correlation_coefficient': nan,
#      'Fowlkes_Mallows_index': nan,
#      'informedness': nan,
#      'markedness': nan,
#      'Diagnostic_odds_ratio': nan,
#      'accuracy': 1.0,
#      'balanced_accuracy': nan},
#     'ROC_AUC_SCORE': {'Macro': 0.5, 'Micro': 0.5, 'Weight': 0.5},
#     'Classification Report': {'0': {'precision': 0.0,
#       'recall': 0.0,
#       'f1-score': 0.0,
#       'support': 6},
#      '1': {'precision': 0.6666666666666666,
#       'recall': 1.0,
#       'f1-score': 0.8,
#       'support': 12},
#      'accuracy': 0.6666666666666666,
#      'macro avg': {'precision': 0.3333333333333333,
#       'recall': 0.5,
#       'f1-score': 0.4,
#       'support': 18},
#      'weighted avg': {'precision': 0.4444444444444444,
#       'recall': 0.6666666666666666,
#       'f1-score': 0.5333333333333334,
#       'support': 18}}},
#    'fold_1': {'Confusion Matrix': {'TP': 0,
#      'TN': 12,
#      'FN': 0,
#      'FP': 0,
#      'precision': nan,
#      'recall': nan,
#      'f1_score': nan,
#      'sensitivity': nan,
#      'specificity': 1.0,
#      'negative_predictive_value': 1.0,
#      'false_negative_rate': nan,
#      'false_positive_rate': 0.0,
#      'false_discovery_rate': nan,
#      'false_omission_rate': 0.0,
#      'Positive_likelihood_ratio': nan,
#      'Negative_likelihood_ratio': nan,
#      'prevalence_threshold': nan,
#      'threat_score': 0.0,
#      'Prevalence': 0.0,
#      'Matthews_correlation_coefficient': nan,
#      'Fowlkes_Mallows_index': nan,
#      'informedness': nan,
#      'markedness': nan,
#      'Diagnostic_odds_ratio': nan,
#      'accuracy': 1.0,
#      'balanced_accuracy': nan},
#     'ROC_AUC_SCORE': {'Macro': 0.5, 'Micro': 0.5, 'Weight': 0.5},
#     'Classification Report': {'0': {'precision': 0.0,
#       'recall': 0.0,
#       'f1-score': 0.0,
#       'support': 6},
#      '1': {'precision': 0.6666666666666666,
#       'recall': 1.0,
#       'f1-score': 0.8,
#       'support': 12},
#      'accuracy': 0.6666666666666666,
#      'macro avg': {'precision': 0.3333333333333333,
#       'recall': 0.5,
#       'f1-score': 0.4,
#       'support': 18},
#      'weighted avg': {'precision': 0.4444444444444444,
#       'recall': 0.6666666666666666,
#       'f1-score': 0.5333333333333334,
#       'support': 18}}},
#    'fold_2': {'Confusion Matrix': {'TP': 0,
#      'TN': 12,
#      'FN': 0,
#      'FP': 0,
#      'precision': nan,
#      'recall': nan,
#      'f1_score': nan,
#      'sensitivity': nan,
#      'specificity': 1.0,
#      'negative_predictive_value': 1.0,
#      'false_negative_rate': nan,
#      'false_positive_rate': 0.0,
#      'false_discovery_rate': nan,
#      'false_omission_rate': 0.0,
#      'Positive_likelihood_ratio': nan,
#      'Negative_likelihood_ratio': nan,
#      'prevalence_threshold': nan,
#      'threat_score': 0.0,
#      'Prevalence': 0.0,
#      'Matthews_correlation_coefficient': nan,
#      'Fowlkes_Mallows_index': nan,
#      'informedness': nan,
#      'markedness': nan,
#      'Diagnostic_odds_ratio': nan,
#      'accuracy': 1.0,
#      'balanced_accuracy': nan},
#     'ROC_AUC_SCORE': {'Macro': 0.5, 'Micro': 0.5, 'Weight': 0.5},
#     'Classification Report': {'0': {'precision': 0.0,
#       'recall': 0.0,
#       'f1-score': 0.0,
#       'support': 6},
#      '1': {'precision': 0.6666666666666666,
#       'recall': 1.0,
#       'f1-score': 0.8,
#       'support': 12},
#      'accuracy': 0.6666666666666666,
#      'macro avg': {'precision': 0.3333333333333333,
#       'recall': 0.5,
#       'f1-score': 0.4,
#       'support': 18},
#      'weighted avg': {'precision': 0.4444444444444444,
#       'recall': 0.6666666666666666,
#       'f1-score': 0.5333333333333334,
#       'support': 18}}},
#    'fold_3': {'Confusion Matrix': {'TP': 0,
#      'TN': 12,
#      'FN': 0,
#      'FP': 0,
#      'precision': nan,
#      'recall': nan,
#      'f1_score': nan,
#      'sensitivity': nan,
#      'specificity': 1.0,
#      'negative_predictive_value': 1.0,
#      'false_negative_rate': nan,
#      'false_positive_rate': 0.0,
#      'false_discovery_rate': nan,
#      'false_omission_rate': 0.0,
#      'Positive_likelihood_ratio': nan,
#      'Negative_likelihood_ratio': nan,
#      'prevalence_threshold': nan,
#      'threat_score': 0.0,
#      'Prevalence': 0.0,
#      'Matthews_correlation_coefficient': nan,
#      'Fowlkes_Mallows_index': nan,
#      'informedness': nan,
#      'markedness': nan,
#      'Diagnostic_odds_ratio': nan,
#      'accuracy': 1.0,
#      'balanced_accuracy': nan},
#     'ROC_AUC_SCORE': {'Macro': 0.5, 'Micro': 0.5, 'Weight': 0.5},
#     'Classification Report': {'0': {'precision': 0.0,
#       'recall': 0.0,
#       'f1-score': 0.0,
#       'support': 6},
#      '1': {'precision': 0.6666666666666666,
#       'recall': 1.0,
#       'f1-score': 0.8,
#       'support': 12},
#      'accuracy': 0.6666666666666666,
#      'macro avg': {'precision': 0.3333333333333333,
#       'recall': 0.5,
#       'f1-score': 0.4,
#       'support': 18},
#      'weighted avg': {'precision': 0.4444444444444444,
#       'recall': 0.6666666666666666,
#       'f1-score': 0.5333333333333334,
#       'support': 18}}},
#    'fold_4': {'Confusion Matrix': {'TP': 0,
#      'TN': 12,
#      'FN': 0,
#      'FP': 0,
#      'precision': nan,
#      'recall': nan,
#      'f1_score': nan,
#      'sensitivity': nan,
#      'specificity': 1.0,
#      'negative_predictive_value': 1.0,
#      'false_negative_rate': nan,
#      'false_positive_rate': 0.0,
#      'false_discovery_rate': nan,
#      'false_omission_rate': 0.0,
#      'Positive_likelihood_ratio': nan,
#      'Negative_likelihood_ratio': nan,
#      'prevalence_threshold': nan,
#      'threat_score': 0.0,
#      'Prevalence': 0.0,
#      'Matthews_correlation_coefficient': nan,
#      'Fowlkes_Mallows_index': nan,
#      'informedness': nan,
#      'markedness': nan,
#      'Diagnostic_odds_ratio': nan,
#      'accuracy': 1.0,
#      'balanced_accuracy': nan},
#     'ROC_AUC_SCORE': {'Macro': 0.5, 'Micro': 0.5, 'Weight': 0.5},
#     'Classification Report': {'0': {'precision': 0.0,
#       'recall': 0.0,
#       'f1-score': 0.0,
#       'support': 6},
#      '1': {'precision': 0.6666666666666666,
#       'recall': 1.0,
#       'f1-score': 0.8,
#       'support': 12},
#      'accuracy': 0.6666666666666666,
#      'macro avg': {'precision': 0.3333333333333333,
#       'recall': 0.5,
#       'f1-score': 0.4,
#       'support': 18},
#      'weighted avg': {'precision': 0.4444444444444444,
#       'recall': 0.6666666666666666,
#       'f1-score': 0.5333333333333334,
#       'support': 18}}},
#    'fold_5': {'Confusion Matrix': {'TP': 0,
#      'TN': 12,
#      'FN': 0,
#      'FP': 0,
#      'precision': nan,
#      'recall': nan,
#      'f1_score': nan,
#      'sensitivity': nan,
#      'specificity': 1.0,
#      'negative_predictive_value': 1.0,
#      'false_negative_rate': nan,
#      'false_positive_rate': 0.0,
#      'false_discovery_rate': nan,
#      'false_omission_rate': 0.0,
#      'Positive_likelihood_ratio': nan,
#      'Negative_likelihood_ratio': nan,
#      'prevalence_threshold': nan,
#      'threat_score': 0.0,
#      'Prevalence': 0.0,
#      'Matthews_correlation_coefficient': nan,
#      'Fowlkes_Mallows_index': nan,
#      'informedness': nan,
#      'markedness': nan,
#      'Diagnostic_odds_ratio': nan,
#      'accuracy': 1.0,
#      'balanced_accuracy': nan},
#     'ROC_AUC_SCORE': {'Macro': 0.5, 'Micro': 0.5, 'Weight': 0.5},
#     'Classification Report': {'0': {'precision': 0.0,
#       'recall': 0.0,
#       'f1-score': 0.0,
#       'support': 6},
#      '1': {'precision': 0.6666666666666666,
#       'recall': 1.0,
#       'f1-score': 0.8,
#       'support': 12},
#      'accuracy': 0.6666666666666666,
#      'macro avg': {'precision': 0.3333333333333333,
#       'recall': 0.5,
#       'f1-score': 0.4,
#       'support': 18},
#      'weighted avg': {'precision': 0.4444444444444444,
#       'recall': 0.6666666666666666,
#       'f1-score': 0.5333333333333334,
#       'support': 18}}},
#    'fold_6': {'Confusion Matrix': {'TP': 0,
#      'TN': 12,
#      'FN': 0,
#      'FP': 0,
#      'precision': nan,
#      'recall': nan,
#      'f1_score': nan,
#      'sensitivity': nan,
#      'specificity': 1.0,
#      'negative_predictive_value': 1.0,
#      'false_negative_rate': nan,
#      'false_positive_rate': 0.0,
#      'false_discovery_rate': nan,
#      'false_omission_rate': 0.0,
#      'Positive_likelihood_ratio': nan,
#      'Negative_likelihood_ratio': nan,
#      'prevalence_threshold': nan,
#      'threat_score': 0.0,
#      'Prevalence': 0.0,
#      'Matthews_correlation_coefficient': nan,
#      'Fowlkes_Mallows_index': nan,
#      'informedness': nan,
#      'markedness': nan,
#      'Diagnostic_odds_ratio': nan,
#      'accuracy': 1.0,
#      'balanced_accuracy': nan},
#     'ROC_AUC_SCORE': {'Macro': 0.5, 'Micro': 0.5, 'Weight': 0.5},
#     'Classification Report': {'0': {'precision': 0.0,
#       'recall': 0.0,
#       'f1-score': 0.0,
#       'support': 6},
#      '1': {'precision': 0.6666666666666666,
#       'recall': 1.0,
#       'f1-score': 0.8,
#       'support': 12},
#      'accuracy': 0.6666666666666666,
#      'macro avg': {'precision': 0.3333333333333333,
#       'recall': 0.5,
#       'f1-score': 0.4,
#       'support': 18},
#      'weighted avg': {'precision': 0.4444444444444444,
#       'recall': 0.6666666666666666,
#       'f1-score': 0.5333333333333334,
#       'support': 18}}},
#    'fold_7': {'Confusion Matrix': {'TP': 0,
#      'TN': 12,
#      'FN': 0,
#      'FP': 0,
#      'precision': nan,
#      'recall': nan,
#      'f1_score': nan,
#      'sensitivity': nan,
#      'specificity': 1.0,
#      'negative_predictive_value': 1.0,
#      'false_negative_rate': nan,
#      'false_positive_rate': 0.0,
#      'false_discovery_rate': nan,
#      'false_omission_rate': 0.0,
#      'Positive_likelihood_ratio': nan,
#      'Negative_likelihood_ratio': nan,
#      'prevalence_threshold': nan,
#      'threat_score': 0.0,
#      'Prevalence': 0.0,
#      'Matthews_correlation_coefficient': nan,
#      'Fowlkes_Mallows_index': nan,
#      'informedness': nan,
#      'markedness': nan,
#      'Diagnostic_odds_ratio': nan,
#      'accuracy': 1.0,
#      'balanced_accuracy': nan},
#     'ROC_AUC_SCORE': {'Macro': 0.5, 'Micro': 0.5, 'Weight': 0.5},
#     'Classification Report': {'0': {'precision': 0.0,
#       'recall': 0.0,
#       'f1-score': 0.0,
#       'support': 6},
#      '1': {'precision': 0.6666666666666666,
#       'recall': 1.0,
#       'f1-score': 0.8,
#       'support': 12},
#      'accuracy': 0.6666666666666666,
#      'macro avg': {'precision': 0.3333333333333333,
#       'recall': 0.5,
#       'f1-score': 0.4,
#       'support': 18},
#      'weighted avg': {'precision': 0.4444444444444444,
#       'recall': 0.6666666666666666,
#       'f1-score': 0.5333333333333334,
#       'support': 18}}},
#    'fold_8': {'Confusion Matrix': {'TP': 0,
#      'TN': 12,
#      'FN': 0,
#      'FP': 0,
#      'precision': nan,
#      'recall': nan,
#      'f1_score': nan,
#      'sensitivity': nan,
#      'specificity': 1.0,
#      'negative_predictive_value': 1.0,
#      'false_negative_rate': nan,
#      'false_positive_rate': 0.0,
#      'false_discovery_rate': nan,
#      'false_omission_rate': 0.0,
#      'Positive_likelihood_ratio': nan,
#      'Negative_likelihood_ratio': nan,
#      'prevalence_threshold': nan,
#      'threat_score': 0.0,
#      'Prevalence': 0.0,
#      'Matthews_correlation_coefficient': nan,
#      'Fowlkes_Mallows_index': nan,
#      'informedness': nan,
#      'markedness': nan,
#      'Diagnostic_odds_ratio': nan,
#      'accuracy': 1.0,
#      'balanced_accuracy': nan},
#     'ROC_AUC_SCORE': {'Macro': 0.5, 'Micro': 0.5, 'Weight': 0.5},
#     'Classification Report': {'0': {'precision': 0.0,
#       'recall': 0.0,
#       'f1-score': 0.0,
#       'support': 6},
#      '1': {'precision': 0.6666666666666666,
#       'recall': 1.0,
#       'f1-score': 0.8,
#       'support': 12},
#      'accuracy': 0.6666666666666666,
#      'macro avg': {'precision': 0.3333333333333333,
#       'recall': 0.5,
#       'f1-score': 0.4,
#       'support': 18},
#      'weighted avg': {'precision': 0.4444444444444444,
#       'recall': 0.6666666666666666,
#       'f1-score': 0.5333333333333334,
#       'support': 18}}},
#    'fold_9': {'Confusion Matrix': {'TP': 0,
#      'TN': 11,
#      'FN': 0,
#      'FP': 0,
#      'precision': nan,
#      'recall': nan,
#      'f1_score': nan,
#      'sensitivity': nan,
#      'specificity': 1.0,
#      'negative_predictive_value': 1.0,
#      'false_negative_rate': nan,
#      'false_positive_rate': 0.0,
#      'false_discovery_rate': nan,
#      'false_omission_rate': 0.0,
#      'Positive_likelihood_ratio': nan,
#      'Negative_likelihood_ratio': nan,
#      'prevalence_threshold': nan,
#      'threat_score': 0.0,
#      'Prevalence': 0.0,
#      'Matthews_correlation_coefficient': nan,
#      'Fowlkes_Mallows_index': nan,
#      'informedness': nan,
#      'markedness': nan,
#      'Diagnostic_odds_ratio': nan,
#      'accuracy': 1.0,
#      'balanced_accuracy': nan},
#     'ROC_AUC_SCORE': {'Macro': 0.5, 'Micro': 0.5, 'Weight': 0.5},
#     'Classification Report': {'0': {'precision': 0.0,
#       'recall': 0.0,
#       'f1-score': 0.0,
#       'support': 2},
#      '1': {'precision': 0.8461538461538461,
#       'recall': 1.0,
#       'f1-score': 0.9166666666666666,
#       'support': 11},
#      'accuracy': 0.8461538461538461,
#      'macro avg': {'precision': 0.4230769230769231,
#       'recall': 0.5,
#       'f1-score': 0.4583333333333333,
#       'support': 13},
#      'weighted avg': {'precision': 0.7159763313609468,
#       'recall': 0.8461538461538461,
#       'f1-score': 0.7756410256410255,
#       'support': 13}}}}}}

# %%
print("Number of Training: {}".format(len(list(result.keys()))))
# Out:
# Number of Training: 20

# %%
training_case_lst = list(result.keys())
print(training_case_lst[0])
# Out:
# train_0

# %%
train_sample = result[training_case_lst[0]]
print(train_sample['param'])
print("Number of Fold: {}".format(len(train_sample['train_fold'])))
# Out:
# {'penalty': 'l2', 'fit_intercept': True, 'class_weight': 'balanced', 'solver': 'newton-cg'}
# Number of Fold: 10

# %%
fold_sample = train_sample['train_fold']['fold_0']
print(fold_sample['Classification Report'])
# Out:
# {'0': {'precision': 0.7142857142857143, 'recall': 0.8333333333333334, 'f1-score': 0.7692307692307692, 'support': 6}, '1': {'precision': 0.9090909090909091, 'recall': 0.8333333333333334, 'f1-score': 0.8695652173913043, 'support': 12}, 'accuracy': 0.8333333333333334, 'macro avg': {'precision': 0.8116883116883117, 'recall': 0.8333333333333334, 'f1-score': 0.8193979933110367, 'support': 18}, 'weighted avg': {'precision': 0.8441558441558441, 'recall': 0.8333333333333334, 'f1-score': 0.8361204013377926, 'support': 18}}

# %%
result_analyze_dict = {
    'Train' : [],
    'MACC' : [],
    'MAP' : [],
    'MASens' : [],
    'MASpec' : [],
    'MAF1' : [],
    'AUC' : []
}

for result_key in result:
    result_analyze_dict['Train'].append(result_key)
    train_base = result[result_key]
    fold_base = train_base['train_fold']
    acc_lst, pre_lst, re_lst, spec_lst, f1_lst, auc_lst = [], [], [], [], [], []
    for fold_key in fold_base:
        current_fold = fold_base[fold_key]
        current_fold_cls = current_fold['Classification Report']
        acc_lst.append(current_fold_cls['accuracy'])
        pre_lst.append(current_fold_cls['macro avg']['precision'])
        re_lst.append(current_fold_cls['macro avg']['recall'])
        spec_lst.append(current_fold['Confusion Matrix']['specificity'])
        auc_lst.append(current_fold['ROC_AUC_SCORE']['Macro'])
        f1_lst.append(current_fold_cls['macro avg']['f1-score'])
    result_analyze_dict['MACC'].append(sum(acc_lst)/len(acc_lst))
    result_analyze_dict['MAP'].append(sum(pre_lst)/len(pre_lst))
    result_analyze_dict['MASens'].append(sum(re_lst)/len(re_lst))
    result_analyze_dict['MASpec'].append(sum(spec_lst)/len(spec_lst))
    result_analyze_dict['MAF1'].append(sum(f1_lst)/len(f1_lst))
    result_analyze_dict['AUC'].append(sum(auc_lst)/len(auc_lst))

result_df = pd.DataFrame(result_analyze_dict)
result_df.head()
# Out:
#      Train      MACC       MAP   MASens    MASpec      MAF1      AUC
# 0  train_0  0.828205  0.797632  0.80303  0.839394  0.792435  0.80303
# 1  train_1  0.828205  0.797632  0.80303  0.839394  0.792435  0.80303
# 2  train_2  0.828205  0.797632  0.80303  0.839394  0.792435  0.80303
# 3  train_3  0.828205  0.797632  0.80303  0.839394  0.792435  0.80303
# 4  train_4  0.828205  0.797632  0.80303  0.839394  0.792435  0.80303

# %%
result_max = result_df.max()
result_max
# Out:
# Train      train_9
# MACC      0.828205
# MAP       0.808799
# MASens    0.852652
# MASpec         1.0
# MAF1      0.802172
# AUC       0.852652
# dtype: object

# %%
id_result_max = result_df.iloc[:, 1:].idxmax()
id_result_max
# Out:
# MACC       0
# MAP       10
# MASens    10
# MASpec     5
# MAF1      10
# AUC       10
# dtype: int64

# %%
id_max = 'train_{}'.format(id_result_max.mode()[0])
print(id_max)
# Out:
# train_10

# %%
result_df.loc[result_df['Train'] == id_max]
# Out:
#        Train      MACC       MAP    MASens    MASpec      MAF1       AUC
# 10  train_10  0.813675  0.808799  0.852652  0.755303  0.802172  0.852652

# %%
train_max = result[id_max]
train_max['param']
# Out:
# {'penalty': 'l2',
#  'fit_intercept': False,
#  'class_weight': 'balanced',
#  'solver': 'newton-cg'}

# %%
train_max_fold = train_max['train_fold']
train_max_analyze = {
    'Fold' : [],
    'ACC' : [],
    'AP' : [],
    'ASens' : [],
    'ASpec' : [],
    'AF1' : [],
    'AUC' : []
}

for fold_key in train_max_fold:
    train_max_analyze['Fold'].append(fold_key)
    current_fold = train_max_fold[fold_key]
    current_fold_cls = current_fold['Classification Report']
    train_max_analyze['ACC'].append(current_fold_cls['accuracy'])
    train_max_analyze['AP'].append(current_fold_cls['macro avg']['precision'])
    train_max_analyze['ASens'].append(current_fold_cls['macro avg']['recall'])
    train_max_analyze['ASpec'].append(current_fold['Confusion Matrix']['specificity'])
    train_max_analyze['AF1'].append(current_fold_cls['macro avg']['f1-score'])
    train_max_analyze['AUC'].append(current_fold['ROC_AUC_SCORE']['Macro'])

train_max_analyze_df = pd.DataFrame(train_max_analyze)
train_max_analyze_df
# Out:
#      Fold       ACC        AP     ASens     ASpec       AF1       AUC
# 0  fold_0  0.833333  0.833333  0.875000  0.750000  0.828571  0.875000
# 1  fold_1  0.777778  0.762500  0.791667  0.750000  0.766234  0.791667
# 2  fold_2  0.833333  0.811688  0.833333  0.833333  0.819398  0.833333
# 3  fold_3  0.722222  0.772727  0.791667  0.583333  0.721362  0.791667
# 4  fold_4  0.888889  0.875000  0.916667  0.833333  0.883117  0.916667
# 5  fold_5  0.777778  0.762500  0.791667  0.750000  0.766234  0.791667
# 6  fold_6  0.944444  0.928571  0.958333  0.916667  0.939799  0.958333
# 7  fold_7  0.777778  0.800000  0.833333  0.666667  0.775000  0.833333
# 8  fold_8  0.888889  0.875000  0.916667  0.833333  0.883117  0.916667
# 9  fold_9  0.692308  0.666667  0.818182  0.636364  0.638889  0.818182

# %% [markdown]
# # N_times_K_folds

# %%
# Setup

train_max_param = train_max['param']
n_times = 100

nt_kf_output_dict = {
    'Train' : [], # <index>_<fold>
    'ACC' : [],
    'AP' : [],
    'ASens' : [],
    'ASpec' : [],
    'AF1' : [],
    'AUC' : []
}

for n in range(n_times):
    print("Training {}".format(n))
    fold_index = 0
    for train_index, test_index in zip(kmean_train_paths, kmean_test_paths):
        train_df = pd.read_csv(train_index)
        test_df = pd.read_csv(test_index)      
    
        print("\tFold: {}".format(fold_index))
        print("\tTRAIN:", train_index, "\n\tTEST:", test_index)

        # folding data
        x_train, y_train = train_df.iloc[:, 2:-1], train_df.iloc[:, -1]
        x_test, y_test = test_df.iloc[:, 2:-1], test_df.iloc[:, -1]
        
        # Training
        print("\t\tTraining : {}".format(fold_index), end = " -- ")
        print("Start: {}".format(datetime.now().strftime("%m/%d/%Y, %H:%M:%S")), end=" --- ")
        model = LogisticRegression(penalty = train_max_param['penalty'],
                                 fit_intercept = train_max_param['fit_intercept'],
                                 class_weight = train_max_param['class_weight'],
                                 solver = train_max_param['solver'])
        model.fit(x_train,y_train)
        print("End: {}".format(datetime.now().strftime("%m/%d/%Y, %H:%M:%S")))

        # Testing
        print("\t\tValidation: {}".format(fold_index), end = " -- ")
        print("Start: {}".format(datetime.now().strftime("%m/%d/%Y, %H:%M:%S")), end="---")
        y_pred = model.predict(x_test)
        print("End: {}".format(datetime.now().strftime("%m/%d/%Y, %H:%M:%S")))
        
        # Evaluation
        cm = confusion_matrix(y_test, y_pred)
        base_result = utils(cm, y_test, y_pred).get_value()
        
        # Result Storing
        nt_kf_output_dict['Train'].append('{0}_{1}'.format(n, fold_index))
        cls = base_result['Classification Report']
        nt_kf_output_dict['ACC'].append(cls['accuracy'])
        nt_kf_output_dict['AP'].append(cls['macro avg']['precision'])
        nt_kf_output_dict['ASens'].append(cls['macro avg']['recall'])
        nt_kf_output_dict['ASpec'].append(base_result['Confusion Matrix']['specificity'])
        nt_kf_output_dict['AF1'].append(cls['macro avg']['f1-score'])
        nt_kf_output_dict['AUC'].append(base_result['ROC_AUC_SCORE']['Macro'])
        
        # Fold index increment
        fold_index += 1
# Out:
# Training 0
# 	Fold: 0
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index0.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index0.csv
# 		Training : 0 -- Start: 12/12/2022, 17:46:31 --- End: 12/12/2022, 17:46:31
# 		Validation: 0 -- Start: 12/12/2022, 17:46:31---End: 12/12/2022, 17:46:31
# 	Fold: 1
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index1.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index1.csv
# 		Training : 1 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 1 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 2
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index2.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index2.csv
# 		Training : 2 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 2 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 3
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index3.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index3.csv
# 		Training : 3 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 3 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 4
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index4.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index4.csv
# 		Training : 4 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 4 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 5
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index5.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index5.csv
# 		Training : 5 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 5 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 6
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index6.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index6.csv
# 		Training : 6 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 6 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 7
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index7.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index7.csv
# 		Training : 7 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 7 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 8
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index8.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index8.csv
# 		Training : 8 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 8 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 9
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index9.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index9.csv
# 		Training : 9 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 9 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# Training 1
# 	Fold: 0
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index0.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index0.csv
# 		Training : 0 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 0 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 1
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index1.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index1.csv
# 		Training : 1 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 1 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 2
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index2.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index2.csv
# 		Training : 2 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 2 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 3
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index3.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index3.csv
# 		Training : 3 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 3 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 4
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index4.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index4.csv
# 		Training : 4 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 4 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 5
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index5.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index5.csv
# 		Training : 5 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 5 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 6
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index6.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index6.csv
# 		Training : 6 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 6 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 7
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index7.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index7.csv
# 		Training : 7 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 7 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 8
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index8.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index8.csv
# 		Training : 8 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 8 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 9
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index9.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index9.csv
# 		Training : 9 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 9 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# Training 2
# 	Fold: 0
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index0.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index0.csv
# 		Training : 0 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 0 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 1
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index1.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index1.csv
# 		Training : 1 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 1 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 2
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index2.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index2.csv
# 		Training : 2 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 2 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 3
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index3.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index3.csv
# 		Training : 3 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 3 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 4
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index4.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index4.csv
# 		Training : 4 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 4 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 5
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index5.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index5.csv
# 		Training : 5 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 5 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 6
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index6.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index6.csv
# 		Training : 6 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 6 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 7
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index7.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index7.csv
# 		Training : 7 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 7 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 8
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index8.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index8.csv
# 		Training : 8 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 8 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 9
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index9.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index9.csv
# 		Training : 9 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 9 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# Training 3
# 	Fold: 0
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index0.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index0.csv
# 		Training : 0 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 0 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 1
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index1.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index1.csv
# 		Training : 1 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 1 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 2
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index2.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index2.csv
# 		Training : 2 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 2 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 3
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index3.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index3.csv
# 		Training : 3 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 3 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 4
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index4.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index4.csv
# 		Training : 4 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 4 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 5
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index5.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index5.csv
# 		Training : 5 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 5 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 6
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index6.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index6.csv
# 		Training : 6 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 6 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 7
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index7.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index7.csv
# 		Training : 7 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 7 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 8
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index8.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index8.csv
# 		Training : 8 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 8 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 9
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index9.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index9.csv
# 		Training : 9 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 9 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# Training 4
# 	Fold: 0
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index0.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index0.csv
# 		Training : 0 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 0 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 1
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index1.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index1.csv
# 		Training : 1 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 1 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 2
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index2.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index2.csv
# 		Training : 2 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 2 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 3
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index3.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index3.csv
# 		Training : 3 -- Start: 12/12/2022, 17:46:32 --- End: 12/12/2022, 17:46:32
# 		Validation: 3 -- Start: 12/12/2022, 17:46:32---End: 12/12/2022, 17:46:32
# 	Fold: 4
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index4.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index4.csv
# 		Training : 4 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 4 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 5
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index5.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index5.csv
# 		Training : 5 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 5 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 6
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index6.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index6.csv
# 		Training : 6 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 6 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 7
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index7.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index7.csv
# 		Training : 7 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 7 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 8
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index8.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index8.csv
# 		Training : 8 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 8 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 9
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index9.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index9.csv
# 		Training : 9 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 9 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# Training 5
# 	Fold: 0
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index0.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index0.csv
# 		Training : 0 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 0 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 1
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index1.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index1.csv
# 		Training : 1 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 1 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 2
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index2.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index2.csv
# 		Training : 2 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 2 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 3
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index3.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index3.csv
# 		Training : 3 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 3 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 4
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index4.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index4.csv
# 		Training : 4 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 4 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 5
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index5.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index5.csv
# 		Training : 5 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 5 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 6
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index6.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index6.csv
# 		Training : 6 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 6 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 7
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index7.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index7.csv
# 		Training : 7 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 7 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 8
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index8.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index8.csv
# 		Training : 8 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 8 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 9
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index9.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index9.csv
# 		Training : 9 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 9 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# Training 6
# 	Fold: 0
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index0.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index0.csv
# 		Training : 0 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 0 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 1
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index1.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index1.csv
# 		Training : 1 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 1 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 2
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index2.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index2.csv
# 		Training : 2 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 2 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 3
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index3.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index3.csv
# 		Training : 3 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 3 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 4
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index4.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index4.csv
# 		Training : 4 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 4 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 5
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index5.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index5.csv
# 		Training : 5 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 5 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 6
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index6.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index6.csv
# 		Training : 6 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 6 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 7
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index7.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index7.csv
# 		Training : 7 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 7 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 8
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index8.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index8.csv
# 		Training : 8 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 8 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 9
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index9.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index9.csv
# 		Training : 9 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 9 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# Training 7
# 	Fold: 0
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index0.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index0.csv
# 		Training : 0 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 0 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 1
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index1.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index1.csv
# 		Training : 1 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 1 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 2
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index2.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index2.csv
# 		Training : 2 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 2 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 3
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index3.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index3.csv
# 		Training : 3 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 3 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 4
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index4.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index4.csv
# 		Training : 4 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 4 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 5
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index5.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index5.csv
# 		Training : 5 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 5 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 6
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index6.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index6.csv
# 		Training : 6 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 6 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 7
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index7.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index7.csv
# 		Training : 7 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 7 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 8
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index8.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index8.csv
# 		Training : 8 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 8 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 9
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index9.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index9.csv
# 		Training : 9 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 9 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# Training 8
# 	Fold: 0
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index0.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index0.csv
# 		Training : 0 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 0 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 1
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index1.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index1.csv
# 		Training : 1 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 1 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 2
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index2.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index2.csv
# 		Training : 2 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 2 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 3
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index3.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index3.csv
# 		Training : 3 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 3 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 4
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index4.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index4.csv
# 		Training : 4 -- Start: 12/12/2022, 17:46:33 --- End: 12/12/2022, 17:46:33
# 		Validation: 4 -- Start: 12/12/2022, 17:46:33---End: 12/12/2022, 17:46:33
# 	Fold: 5
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index5.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index5.csv
# 		Training : 5 -- Start: 12/12/2022, 17:46:34 --- End: 12/12/2022, 17:46:34
# 		Validation: 5 -- Start: 12/12/2022, 17:46:34---End: 12/12/2022, 17:46:34
# 	Fold: 6
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index6.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index6.csv
# 		Training : 6 -- Start: 12/12/2022, 17:46:34 --- End: 12/12/2022, 17:46:34
# 		Validation: 6 -- Start: 12/12/2022, 17:46:34---End: 12/12/2022, 17:46:34
# 	Fold: 7
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index7.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index7.csv
# 		Training : 7 -- Start: 12/12/2022, 17:46:34 --- End: 12/12/2022, 17:46:34
# 		Validation: 7 -- Start: 12/12/2022, 17:46:34---End: 12/12/2022, 17:46:34
# 	Fold: 8
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index8.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index8.csv
# 		Training : 8 -- Start: 12/12/2022, 17:46:34 --- End: 12/12/2022, 17:46:34
# 		Validation: 8 -- Start: 12/12/2022, 17:46:34---End: 12/12/2022, 17:46:34
# 	Fold: 9
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index9.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index9.csv
# 		Training : 9 -- Start: 12/12/2022, 17:46:34 --- End: 12/12/2022, 17:46:34
# 		Validation: 9 -- Start: 12/12/2022, 17:46:34---End: 12/12/2022, 17:46:34
# Training 9
# 	Fold: 0
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index0.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index0.csv
# 		Training : 0 -- Start: 12/12/2022, 17:46:34 --- End: 12/12/2022, 17:46:34
# 		Validation: 0 -- Start: 12/12/2022, 17:46:34---End: 12/12/2022, 17:46:34
# 	Fold: 1
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index1.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index1.csv
# 		Training : 1 -- Start: 12/12/2022, 17:46:34 --- End: 12/12/2022, 17:46:34
# 		Validation: 1 -- Start: 12/12/2022, 17:46:34---End: 12/12/2022, 17:46:34
# 	Fold: 2
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index2.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index2.csv
# 		Training : 2 -- Start: 12/12/2022, 17:46:34 --- End: 12/12/2022, 17:46:34
# 		Validation: 2 -- Start: 12/12/2022, 17:46:34---End: 12/12/2022, 17:46:34
# 	Fold: 3
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index3.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index3.csv
# 		Training : 3 -- Start: 12/12/2022, 17:46:34 --- End: 12/12/2022, 17:46:34
# 		Validation: 3 -- Start: 12/12/2022, 17:46:34---End: 12/12/2022, 17:46:34
# 	Fold: 4
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index4.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index4.csv
# 		Training : 4 -- Start: 12/12/2022, 17:46:34 --- End: 12/12/2022, 17:46:34
# 		Validation: 4 -- Start: 12/12/2022, 17:46:34---End: 12/12/2022, 17:46:34
# 	Fold: 5
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index5.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index5.csv
# 		Training : 5 -- Start: 12/12/2022, 17:46:34 --- End: 12/12/2022, 17:46:34
# 		Validation: 5 -- Start: 12/12/2022, 17:46:34---End: 12/12/2022, 17:46:34
# 	Fold: 6
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index6.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index6.csv
# 		Training : 6 -- Start: 12/12/2022, 17:46:34 --- End: 12/12/2022, 17:46:34
# 		Validation: 6 -- Start: 12/12/2022, 17:46:34---End: 12/12/2022, 17:46:34
# 	Fold: 7
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index7.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index7.csv
# 		Training : 7 -- Start: 12/12/2022, 17:46:34 --- End: 12/12/2022, 17:46:34
# 		Validation: 7 -- Start: 12/12/2022, 17:46:34---End: 12/12/2022, 17:46:34
# 	Fold: 8
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index8.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index8.csv
# 		Training : 8 -- Start: 12/12/2022, 17:46:34 --- End: 12/12/2022, 17:46:34
# 		Validation: 8 -- Start: 12/12/2022, 17:46:34---End: 12/12/2022, 17:46:34
# 	Fold: 9
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index9.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index9.csv
# 		Training : 9 -- Start: 12/12/2022, 17:46:34 --- End: 12/12/2022, 17:46:34
# 		Validation: 9 -- Start: 12/12/2022, 17:46:34---End: 12/12/2022, 17:46:34
# Training 10
# 	Fold: 0
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index0.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index0.csv
# 		Training : 0 -- Start: 12/12/2022, 17:46:34 --- End: 12/12/2022, 17:46:34
# 		Validation: 0 -- Start: 12/12/2022, 17:46:34---End: 12/12/2022, 17:46:34
# 	Fold: 1
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index1.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index1.csv
# 		Training : 1 -- Start: 12/12/2022, 17:46:34 --- End: 12/12/2022, 17:46:34
# 		Validation: 1 -- Start: 12/12/2022, 17:46:34---End: 12/12/2022, 17:46:34
# 	Fold: 2
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index2.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index2.csv
# 		Training : 2 -- Start: 12/12/2022, 17:46:34 --- End: 12/12/2022, 17:46:34
# 		Validation: 2 -- Start: 12/12/2022, 17:46:34---End: 12/12/2022, 17:46:34
# 	Fold: 3
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index3.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index3.csv
# 		Training : 3 -- Start: 12/12/2022, 17:46:34 --- End: 12/12/2022, 17:46:34
# 		Validation: 3 -- Start: 12/12/2022, 17:46:34---End: 12/12/2022, 17:46:34
# 	Fold: 4
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index4.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index4.csv
# 		Training : 4 -- Start: 12/12/2022, 17:46:34 --- End: 12/12/2022, 17:46:34
# 		Validation: 4 -- Start: 12/12/2022, 17:46:34---End: 12/12/2022, 17:46:34
# 	Fold: 5
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index5.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index5.csv
# 		Training : 5 -- Start: 12/12/2022, 17:46:34 --- End: 12/12/2022, 17:46:34
# 		Validation: 5 -- Start: 12/12/2022, 17:46:34---End: 12/12/2022, 17:46:34
# 	Fold: 6
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index6.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index6.csv
# 		Training : 6 -- Start: 12/12/2022, 17:46:34 --- End: 12/12/2022, 17:46:34
# 		Validation: 6 -- Start: 12/12/2022, 17:46:34---End: 12/12/2022, 17:46:34
# 	Fold: 7
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index7.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index7.csv
# 		Training : 7 -- Start: 12/12/2022, 17:46:34 --- End: 12/12/2022, 17:46:34
# 		Validation: 7 -- Start: 12/12/2022, 17:46:34---End: 12/12/2022, 17:46:34
# 	Fold: 8
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index8.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index8.csv
# 		Training : 8 -- Start: 12/12/2022, 17:46:34 --- End: 12/12/2022, 17:46:34
# 		Validation: 8 -- Start: 12/12/2022, 17:46:34---End: 12/12/2022, 17:46:34
# 	Fold: 9
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index9.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index9.csv
# 		Training : 9 -- Start: 12/12/2022, 17:46:34 --- End: 12/12/2022, 17:46:34
# 		Validation: 9 -- Start: 12/12/2022, 17:46:34---End: 12/12/2022, 17:46:34
# Training 11
# 	Fold: 0
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index0.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index0.csv
# 		Training : 0 -- Start: 12/12/2022, 17:46:34 --- End: 12/12/2022, 17:46:34
# 		Validation: 0 -- Start: 12/12/2022, 17:46:34---End: 12/12/2022, 17:46:34
# 	Fold: 1
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index1.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index1.csv
# 		Training : 1 -- Start: 12/12/2022, 17:46:34 --- End: 12/12/2022, 17:46:34
# 		Validation: 1 -- Start: 12/12/2022, 17:46:34---End: 12/12/2022, 17:46:34
# 	Fold: 2
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index2.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index2.csv
# 		Training : 2 -- Start: 12/12/2022, 17:46:34 --- End: 12/12/2022, 17:46:34
# 		Validation: 2 -- Start: 12/12/2022, 17:46:34---End: 12/12/2022, 17:46:34
# 	Fold: 3
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index3.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index3.csv
# ...
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index2.csv
# 		Training : 2 -- Start: 12/12/2022, 17:46:54 --- End: 12/12/2022, 17:46:54
# 		Validation: 2 -- Start: 12/12/2022, 17:46:54---End: 12/12/2022, 17:46:54
# 	Fold: 3
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index3.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index3.csv
# 		Training : 3 -- Start: 12/12/2022, 17:46:54 --- End: 12/12/2022, 17:46:54
# 		Validation: 3 -- Start: 12/12/2022, 17:46:54---End: 12/12/2022, 17:46:54
# 	Fold: 4
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index4.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index4.csv
# 		Training : 4 -- Start: 12/12/2022, 17:46:54 --- End: 12/12/2022, 17:46:54
# 		Validation: 4 -- Start: 12/12/2022, 17:46:54---End: 12/12/2022, 17:46:54
# 	Fold: 5
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index5.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index5.csv
# 		Training : 5 -- Start: 12/12/2022, 17:46:54 --- End: 12/12/2022, 17:46:54
# 		Validation: 5 -- Start: 12/12/2022, 17:46:54---End: 12/12/2022, 17:46:54
# 	Fold: 6
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index6.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index6.csv
# 		Training : 6 -- Start: 12/12/2022, 17:46:54 --- End: 12/12/2022, 17:46:54
# 		Validation: 6 -- Start: 12/12/2022, 17:46:54---End: 12/12/2022, 17:46:54
# 	Fold: 7
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index7.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index7.csv
# 		Training : 7 -- Start: 12/12/2022, 17:46:54 --- End: 12/12/2022, 17:46:54
# 		Validation: 7 -- Start: 12/12/2022, 17:46:54---End: 12/12/2022, 17:46:54
# 	Fold: 8
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index8.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index8.csv
# 		Training : 8 -- Start: 12/12/2022, 17:46:54 --- End: 12/12/2022, 17:46:54
# 		Validation: 8 -- Start: 12/12/2022, 17:46:54---End: 12/12/2022, 17:46:54
# 	Fold: 9
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index9.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index9.csv
# 		Training : 9 -- Start: 12/12/2022, 17:46:54 --- End: 12/12/2022, 17:46:54
# 		Validation: 9 -- Start: 12/12/2022, 17:46:54---End: 12/12/2022, 17:46:54
# Training 97
# 	Fold: 0
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index0.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index0.csv
# 		Training : 0 -- Start: 12/12/2022, 17:46:54 --- End: 12/12/2022, 17:46:54
# 		Validation: 0 -- Start: 12/12/2022, 17:46:54---End: 12/12/2022, 17:46:54
# 	Fold: 1
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index1.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index1.csv
# 		Training : 1 -- Start: 12/12/2022, 17:46:54 --- End: 12/12/2022, 17:46:54
# 		Validation: 1 -- Start: 12/12/2022, 17:46:54---End: 12/12/2022, 17:46:54
# 	Fold: 2
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index2.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index2.csv
# 		Training : 2 -- Start: 12/12/2022, 17:46:54 --- End: 12/12/2022, 17:46:54
# 		Validation: 2 -- Start: 12/12/2022, 17:46:54---End: 12/12/2022, 17:46:54
# 	Fold: 3
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index3.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index3.csv
# 		Training : 3 -- Start: 12/12/2022, 17:46:54 --- End: 12/12/2022, 17:46:54
# 		Validation: 3 -- Start: 12/12/2022, 17:46:54---End: 12/12/2022, 17:46:54
# 	Fold: 4
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index4.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index4.csv
# 		Training : 4 -- Start: 12/12/2022, 17:46:54 --- End: 12/12/2022, 17:46:54
# 		Validation: 4 -- Start: 12/12/2022, 17:46:54---End: 12/12/2022, 17:46:54
# 	Fold: 5
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index5.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index5.csv
# 		Training : 5 -- Start: 12/12/2022, 17:46:54 --- End: 12/12/2022, 17:46:54
# 		Validation: 5 -- Start: 12/12/2022, 17:46:54---End: 12/12/2022, 17:46:54
# 	Fold: 6
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index6.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index6.csv
# 		Training : 6 -- Start: 12/12/2022, 17:46:55 --- End: 12/12/2022, 17:46:55
# 		Validation: 6 -- Start: 12/12/2022, 17:46:55---End: 12/12/2022, 17:46:55
# 	Fold: 7
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index7.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index7.csv
# 		Training : 7 -- Start: 12/12/2022, 17:46:55 --- End: 12/12/2022, 17:46:55
# 		Validation: 7 -- Start: 12/12/2022, 17:46:55---End: 12/12/2022, 17:46:55
# 	Fold: 8
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index8.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index8.csv
# 		Training : 8 -- Start: 12/12/2022, 17:46:55 --- End: 12/12/2022, 17:46:55
# 		Validation: 8 -- Start: 12/12/2022, 17:46:55---End: 12/12/2022, 17:46:55
# 	Fold: 9
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index9.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index9.csv
# 		Training : 9 -- Start: 12/12/2022, 17:46:55 --- End: 12/12/2022, 17:46:55
# 		Validation: 9 -- Start: 12/12/2022, 17:46:55---End: 12/12/2022, 17:46:55
# Training 98
# 	Fold: 0
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index0.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index0.csv
# 		Training : 0 -- Start: 12/12/2022, 17:46:55 --- End: 12/12/2022, 17:46:55
# 		Validation: 0 -- Start: 12/12/2022, 17:46:55---End: 12/12/2022, 17:46:55
# 	Fold: 1
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index1.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index1.csv
# 		Training : 1 -- Start: 12/12/2022, 17:46:55 --- End: 12/12/2022, 17:46:55
# 		Validation: 1 -- Start: 12/12/2022, 17:46:55---End: 12/12/2022, 17:46:55
# 	Fold: 2
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index2.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index2.csv
# 		Training : 2 -- Start: 12/12/2022, 17:46:55 --- End: 12/12/2022, 17:46:55
# 		Validation: 2 -- Start: 12/12/2022, 17:46:55---End: 12/12/2022, 17:46:55
# 	Fold: 3
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index3.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index3.csv
# 		Training : 3 -- Start: 12/12/2022, 17:46:55 --- End: 12/12/2022, 17:46:55
# 		Validation: 3 -- Start: 12/12/2022, 17:46:55---End: 12/12/2022, 17:46:55
# 	Fold: 4
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index4.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index4.csv
# 		Training : 4 -- Start: 12/12/2022, 17:46:55 --- End: 12/12/2022, 17:46:55
# 		Validation: 4 -- Start: 12/12/2022, 17:46:55---End: 12/12/2022, 17:46:55
# 	Fold: 5
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index5.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index5.csv
# 		Training : 5 -- Start: 12/12/2022, 17:46:55 --- End: 12/12/2022, 17:46:55
# 		Validation: 5 -- Start: 12/12/2022, 17:46:55---End: 12/12/2022, 17:46:55
# 	Fold: 6
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index6.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index6.csv
# 		Training : 6 -- Start: 12/12/2022, 17:46:55 --- End: 12/12/2022, 17:46:55
# 		Validation: 6 -- Start: 12/12/2022, 17:46:55---End: 12/12/2022, 17:46:55
# 	Fold: 7
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index7.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index7.csv
# 		Training : 7 -- Start: 12/12/2022, 17:46:55 --- End: 12/12/2022, 17:46:55
# 		Validation: 7 -- Start: 12/12/2022, 17:46:55---End: 12/12/2022, 17:46:55
# 	Fold: 8
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index8.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index8.csv
# 		Training : 8 -- Start: 12/12/2022, 17:46:55 --- End: 12/12/2022, 17:46:55
# 		Validation: 8 -- Start: 12/12/2022, 17:46:55---End: 12/12/2022, 17:46:55
# 	Fold: 9
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index9.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index9.csv
# 		Training : 9 -- Start: 12/12/2022, 17:46:55 --- End: 12/12/2022, 17:46:55
# 		Validation: 9 -- Start: 12/12/2022, 17:46:55---End: 12/12/2022, 17:46:55
# Training 99
# 	Fold: 0
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index0.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index0.csv
# 		Training : 0 -- Start: 12/12/2022, 17:46:55 --- End: 12/12/2022, 17:46:55
# 		Validation: 0 -- Start: 12/12/2022, 17:46:55---End: 12/12/2022, 17:46:55
# 	Fold: 1
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index1.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index1.csv
# 		Training : 1 -- Start: 12/12/2022, 17:46:55 --- End: 12/12/2022, 17:46:55
# 		Validation: 1 -- Start: 12/12/2022, 17:46:55---End: 12/12/2022, 17:46:55
# 	Fold: 2
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index2.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index2.csv
# 		Training : 2 -- Start: 12/12/2022, 17:46:55 --- End: 12/12/2022, 17:46:55
# 		Validation: 2 -- Start: 12/12/2022, 17:46:55---End: 12/12/2022, 17:46:55
# 	Fold: 3
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index3.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index3.csv
# 		Training : 3 -- Start: 12/12/2022, 17:46:55 --- End: 12/12/2022, 17:46:55
# 		Validation: 3 -- Start: 12/12/2022, 17:46:55---End: 12/12/2022, 17:46:55
# 	Fold: 4
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index4.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index4.csv
# 		Training : 4 -- Start: 12/12/2022, 17:46:55 --- End: 12/12/2022, 17:46:55
# 		Validation: 4 -- Start: 12/12/2022, 17:46:55---End: 12/12/2022, 17:46:55
# 	Fold: 5
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index5.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index5.csv
# 		Training : 5 -- Start: 12/12/2022, 17:46:55 --- End: 12/12/2022, 17:46:55
# 		Validation: 5 -- Start: 12/12/2022, 17:46:55---End: 12/12/2022, 17:46:55
# 	Fold: 6
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index6.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index6.csv
# 		Training : 6 -- Start: 12/12/2022, 17:46:55 --- End: 12/12/2022, 17:46:55
# 		Validation: 6 -- Start: 12/12/2022, 17:46:55---End: 12/12/2022, 17:46:55
# 	Fold: 7
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index7.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index7.csv
# 		Training : 7 -- Start: 12/12/2022, 17:46:55 --- End: 12/12/2022, 17:46:55
# 		Validation: 7 -- Start: 12/12/2022, 17:46:55---End: 12/12/2022, 17:46:55
# 	Fold: 8
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index8.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index8.csv
# 		Training : 8 -- Start: 12/12/2022, 17:46:55 --- End: 12/12/2022, 17:46:55
# 		Validation: 8 -- Start: 12/12/2022, 17:46:55---End: 12/12/2022, 17:46:55
# 	Fold: 9
# 	TRAIN: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_train_100_4_3_True_Falsehisto_64_cv_index9.csv
# 	TEST: D:\Github\Stomach-Status-Classification\Data set\kmean_dataset\10cv_64\surf_test_100_4_3_True_Falsehisto_64_cv_index9.csv
# 		Training : 9 -- Start: 12/12/2022, 17:46:55 --- End: 12/12/2022, 17:46:55
# 		Validation: 9 -- Start: 12/12/2022, 17:46:55---End: 12/12/2022, 17:46:55

# %%
nt_kf_output_df = pd.DataFrame(nt_kf_output_dict)
nt_kf_output_df.head(10)
# Out:
#   Train       ACC        AP     ASens     ASpec       AF1       AUC
# 0   0_0  0.833333  0.833333  0.875000  0.750000  0.828571  0.875000
# 1   0_1  0.777778  0.762500  0.791667  0.750000  0.766234  0.791667
# 2   0_2  0.833333  0.811688  0.833333  0.833333  0.819398  0.833333
# 3   0_3  0.722222  0.772727  0.791667  0.583333  0.721362  0.791667
# 4   0_4  0.888889  0.875000  0.916667  0.833333  0.883117  0.916667
# 5   0_5  0.777778  0.762500  0.791667  0.750000  0.766234  0.791667
# 6   0_6  0.944444  0.928571  0.958333  0.916667  0.939799  0.958333
# 7   0_7  0.777778  0.800000  0.833333  0.666667  0.775000  0.833333
# 8   0_8  0.888889  0.875000  0.916667  0.833333  0.883117  0.916667
# 9   0_9  0.692308  0.666667  0.818182  0.636364  0.638889  0.818182

# %%
nt_kf_output_df.mean()
# Out:
# Train         inf
# ACC      0.813675
# AP       0.808799
# ASens    0.852652
# ASpec    0.755303
# AF1      0.802172
# AUC      0.852652
# dtype: float64

# %%
nt_kf_output_df.std(numeric_only=True)
# Out:
# ACC      0.074969
# AP       0.070454
# ASens    0.057436
# ASpec    0.098011
# AF1      0.083440
# AUC      0.057436
# dtype: float64

# %%
acc_values = nt_kf_output_df['ACC'].values.tolist()
ap_values = nt_kf_output_df['AP'].values.tolist()
asens_values = nt_kf_output_df['ASens'].values.tolist()
aspec_values = nt_kf_output_df['ASpec'].values.tolist()
af1_values = nt_kf_output_df['AF1'].values.tolist()
auc_values = nt_kf_output_df['AUC'].values.tolist()
print(len(acc_values), len(ap_values), len(asens_values), len(aspec_values), len(af1_values), len(auc_values))
# Out:
# 1000 1000 1000 1000 1000 1000

# %%
import scipy.stats as st

def CI(data, confidence_level, dis_type = 't'):
    if dis_type == 't':
        return st.t.interval(confidence=confidence_level, df=len(data)-1, 
                             loc=np.mean(data), scale=st.sem(data))
    elif dis_type == 'g':
        return st.norm.interval(confidence=confidence_level, loc=np.mean(data), scale=st.sem(data))

def CI_calculator(confidence_level, dis_type = 't'):
    for x in nt_kf_output_df.columns[1:]:
        base = nt_kf_output_df[x].values.tolist()
        print("CI of {}".format(x), CI(base, confidence_level, dis_type))

# %%
cl = 0.95

CI_calculator(confidence_level = cl, dis_type = 't')
# Out:
# CI of ACC (0.8090230373794608, 0.818327389970967)
# CI of AP (0.8044266905810414, 0.8131707120163613)
# CI of ASens (0.8490873407000338, 0.8562156896029968)
# CI of ASpec (0.7492209937207304, 0.7613850668853304)
# CI of AF1 (0.7969942961153142, 0.8073499378203857)
# CI of AUC (0.8490873407000338, 0.8562156896029968)

# %%
cl = 0.95

CI_calculator(confidence_level = cl, dis_type = 'g')
# Out:
# CI of ACC (0.8090286737279102, 0.8183217536225176)
# CI of AP (0.8044319874946282, 0.8131654151027745)
# CI of ASens (0.8490916588788529, 0.8562113714241777)
# CI of ASpec (0.7492283624177186, 0.7613776981883421)
# CI of AF1 (0.7970005693089075, 0.8073436646267924)
# CI of AUC (0.8490916588788529, 0.8562113714241777)

# %%
cl = 0.99

CI_calculator(confidence_level = cl, dis_type = 'g')
# Out:
# CI of ACC (0.807568625058901, 0.8197818022915268)
# CI of AP (0.8030598665724179, 0.8145375360249848)
# CI of ASens (0.8479730709679104, 0.8573299593351201)
# CI of ASpec (0.7473195634272422, 0.7632864971788186)
# CI of AF1 (0.7953755512606848, 0.8089686826750151)
# CI of AUC (0.8479730709679104, 0.8573299593351201)
