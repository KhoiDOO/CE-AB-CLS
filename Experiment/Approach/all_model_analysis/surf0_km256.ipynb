# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from random import randint
import math
from datetime import datetime
import pickle

import lazypredict
from lazypredict.Supervised import LazyClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import roc_curve
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_curve
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score

# %%
os.getcwd()
# Out:
# 'D:\\Github\\Stomach-Status-Classification\\Experiment\\Approach\\all_model_analysis'

# %%
for i in range(3):
    os.chdir("..")

# %%
os.getcwd()
# Out:
# 'D:\\Github\\Stomach-Status-Classification'

# %%
main_data_dir = os.getcwd() + "\\Data set"
kmean_data_dir = main_data_dir + "\\kmean_dataset"
kmean_data_10cv_dir = kmean_data_dir + "\\10cv_256"
import glob

kmean_data_10cv_lst = [x for x in glob.glob(kmean_data_10cv_dir + '\\*') if 'surf_test_0' in x or 'surf_train_0' in x and 'index' in x]
print(kmean_data_10cv_lst)
# Out:
# ['D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_test_0_4_3_True_Falsehisto_256_cv_index0.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_test_0_4_3_True_Falsehisto_256_cv_index1.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_test_0_4_3_True_Falsehisto_256_cv_index2.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_test_0_4_3_True_Falsehisto_256_cv_index3.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_test_0_4_3_True_Falsehisto_256_cv_index4.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_test_0_4_3_True_Falsehisto_256_cv_index5.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_test_0_4_3_True_Falsehisto_256_cv_index6.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_test_0_4_3_True_Falsehisto_256_cv_index7.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_test_0_4_3_True_Falsehisto_256_cv_index8.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_test_0_4_3_True_Falsehisto_256_cv_index9.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_train_0_4_3_True_Falsehisto_256_cv_index0.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_train_0_4_3_True_Falsehisto_256_cv_index1.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_train_0_4_3_True_Falsehisto_256_cv_index2.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_train_0_4_3_True_Falsehisto_256_cv_index3.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_train_0_4_3_True_Falsehisto_256_cv_index4.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_train_0_4_3_True_Falsehisto_256_cv_index5.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_train_0_4_3_True_Falsehisto_256_cv_index6.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_train_0_4_3_True_Falsehisto_256_cv_index7.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_train_0_4_3_True_Falsehisto_256_cv_index8.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_train_0_4_3_True_Falsehisto_256_cv_index9.csv']

# %%
kmean_train_paths = [x for x in kmean_data_10cv_lst if 'train' in x]
kmean_test_paths = [x for x in kmean_data_10cv_lst if 'test' in x]
print(kmean_train_paths)
print()
print(kmean_test_paths)
print(len(kmean_train_paths))
print(len(kmean_test_paths))
# Out:
# ['D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_train_0_4_3_True_Falsehisto_256_cv_index0.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_train_0_4_3_True_Falsehisto_256_cv_index1.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_train_0_4_3_True_Falsehisto_256_cv_index2.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_train_0_4_3_True_Falsehisto_256_cv_index3.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_train_0_4_3_True_Falsehisto_256_cv_index4.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_train_0_4_3_True_Falsehisto_256_cv_index5.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_train_0_4_3_True_Falsehisto_256_cv_index6.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_train_0_4_3_True_Falsehisto_256_cv_index7.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_train_0_4_3_True_Falsehisto_256_cv_index8.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_train_0_4_3_True_Falsehisto_256_cv_index9.csv']
#
# ['D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_test_0_4_3_True_Falsehisto_256_cv_index0.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_test_0_4_3_True_Falsehisto_256_cv_index1.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_test_0_4_3_True_Falsehisto_256_cv_index2.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_test_0_4_3_True_Falsehisto_256_cv_index3.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_test_0_4_3_True_Falsehisto_256_cv_index4.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_test_0_4_3_True_Falsehisto_256_cv_index5.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_test_0_4_3_True_Falsehisto_256_cv_index6.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_test_0_4_3_True_Falsehisto_256_cv_index7.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_test_0_4_3_True_Falsehisto_256_cv_index8.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_256\\surf_test_0_4_3_True_Falsehisto_256_cv_index9.csv']
# 10
# 10

# %%
clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric = None)

# %%
count = 0
for train_index, test_index in zip(kmean_train_paths, kmean_test_paths):
    print("\t\tFold: {}".format(count))
    train_df, test_df = pd.read_csv(train_index), pd.read_csv(test_index)
    
    x_train, y_train = train_df.iloc[:, 2:-1], train_df.iloc[:, -1]
    x_test, y_test = test_df.iloc[:, 2:-1], test_df.iloc[:, -1]
    
    models, predictions = clf.fit(x_train, x_test, y_train, y_test)
    
    print(models)
    print(predictions)
    count += 1
# Out:
# 		Fold: 0
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 29/29 [00:01<00:00, 25.40it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# PassiveAggressiveClassifier        0.94               0.96     0.96      0.95
# AdaBoostClassifier                 0.94               0.92     0.92      0.94
# KNeighborsClassifier               0.89               0.88     0.87      0.89
# LogisticRegression                 0.89               0.88     0.87      0.89
# LinearDiscriminantAnalysis         0.89               0.88     0.87      0.89
# LinearSVC                          0.89               0.88     0.87      0.89
# GaussianNB                         0.83               0.83     0.83      0.84
# Perceptron                         0.83               0.83     0.83      0.84
# NearestCentroid                    0.83               0.83     0.83      0.84
# SGDClassifier                      0.89               0.83     0.83      0.88
# NuSVC                              0.83               0.79     0.79      0.83
# SVC                                0.83               0.79     0.79      0.83
# BernoulliNB                        0.78               0.75     0.75      0.78
# RidgeClassifierCV                  0.83               0.75     0.75      0.81
# RidgeClassifier                    0.83               0.75     0.75      0.81
# RandomForestClassifier             0.83               0.75     0.75      0.81
# LGBMClassifier                     0.83               0.75     0.75      0.81
# ExtraTreesClassifier               0.83               0.75     0.75      0.81
# CalibratedClassifierCV             0.83               0.75     0.75      0.81
# BaggingClassifier                  0.83               0.75     0.75      0.81
# XGBClassifier                      0.78               0.71     0.71      0.76
# DecisionTreeClassifier             0.72               0.67     0.67      0.72
# QuadraticDiscriminantAnalysis      0.61               0.62     0.63      0.62
# ExtraTreeClassifier                0.67               0.62     0.62      0.67
# LabelSpreading                     0.33               0.50     0.50      0.17
# LabelPropagation                   0.33               0.50     0.50      0.17
# DummyClassifier                    0.67               0.50     0.50      0.53
#
#                                Time Taken
# Model
# PassiveAggressiveClassifier          0.01
# AdaBoostClassifier                   0.21
# KNeighborsClassifier                 0.06
# LogisticRegression                   0.02
# LinearDiscriminantAnalysis           0.04
# LinearSVC                            0.02
# GaussianNB                           0.02
# Perceptron                           0.02
# NearestCentroid                      0.01
# SGDClassifier                        0.01
# NuSVC                                0.01
# SVC                                  0.02
# BernoulliNB                          0.01
# RidgeClassifierCV                    0.08
# RidgeClassifier                      0.03
# RandomForestClassifier               0.15
# LGBMClassifier                       0.04
# ExtraTreesClassifier                 0.10
# CalibratedClassifierCV               0.04
# BaggingClassifier                    0.07
# XGBClassifier                        0.05
# DecisionTreeClassifier               0.02
# QuadraticDiscriminantAnalysis        0.04
# ExtraTreeClassifier                  0.01
# LabelSpreading                       0.01
# LabelPropagation                     0.01
# DummyClassifier                      0.01
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# PassiveAggressiveClassifier        0.94               0.96     0.96      0.95
# AdaBoostClassifier                 0.94               0.92     0.92      0.94
# KNeighborsClassifier               0.89               0.88     0.87      0.89
# LogisticRegression                 0.89               0.88     0.87      0.89
# LinearDiscriminantAnalysis         0.89               0.88     0.87      0.89
# LinearSVC                          0.89               0.88     0.87      0.89
# GaussianNB                         0.83               0.83     0.83      0.84
# Perceptron                         0.83               0.83     0.83      0.84
# NearestCentroid                    0.83               0.83     0.83      0.84
# SGDClassifier                      0.89               0.83     0.83      0.88
# NuSVC                              0.83               0.79     0.79      0.83
# SVC                                0.83               0.79     0.79      0.83
# BernoulliNB                        0.78               0.75     0.75      0.78
# RidgeClassifierCV                  0.83               0.75     0.75      0.81
# RidgeClassifier                    0.83               0.75     0.75      0.81
# RandomForestClassifier             0.83               0.75     0.75      0.81
# LGBMClassifier                     0.83               0.75     0.75      0.81
# ExtraTreesClassifier               0.83               0.75     0.75      0.81
# CalibratedClassifierCV             0.83               0.75     0.75      0.81
# BaggingClassifier                  0.83               0.75     0.75      0.81
# XGBClassifier                      0.78               0.71     0.71      0.76
# DecisionTreeClassifier             0.72               0.67     0.67      0.72
# QuadraticDiscriminantAnalysis      0.61               0.62     0.63      0.62
# ExtraTreeClassifier                0.67               0.62     0.62      0.67
# LabelSpreading                     0.33               0.50     0.50      0.17
# LabelPropagation                   0.33               0.50     0.50      0.17
# DummyClassifier                    0.67               0.50     0.50      0.53
#
#                                Time Taken
# Model
# PassiveAggressiveClassifier          0.01
# AdaBoostClassifier                   0.21
# KNeighborsClassifier                 0.06
# LogisticRegression                   0.02
# LinearDiscriminantAnalysis           0.04
# LinearSVC                            0.02
# GaussianNB                           0.02
# Perceptron                           0.02
# NearestCentroid                      0.01
# SGDClassifier                        0.01
# NuSVC                                0.01
# SVC                                  0.02
# BernoulliNB                          0.01
# RidgeClassifierCV                    0.08
# RidgeClassifier                      0.03
# RandomForestClassifier               0.15
# LGBMClassifier                       0.04
# ExtraTreesClassifier                 0.10
# CalibratedClassifierCV               0.04
# BaggingClassifier                    0.07
# XGBClassifier                        0.05
# DecisionTreeClassifier               0.02
# QuadraticDiscriminantAnalysis        0.04
# ExtraTreeClassifier                  0.01
# LabelSpreading                       0.01
# LabelPropagation                     0.01
# DummyClassifier                      0.01
# 		Fold: 1
# 'tuple' object has no attribute '__name__'
# Invalid Classifier(s)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 29/29 [00:00<00:00, 29.15it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# RidgeClassifierCV                  0.94               0.96     0.96      0.95
# RidgeClassifier                    0.89               0.92     0.92      0.89
# Perceptron                         0.89               0.88     0.87      0.89
# PassiveAggressiveClassifier        0.89               0.88     0.87      0.89
# LinearSVC                          0.89               0.83     0.83      0.88
# SVC                                0.89               0.83     0.83      0.88
# ExtraTreesClassifier               0.89               0.83     0.83      0.88
# NuSVC                              0.89               0.83     0.83      0.88
# GaussianNB                         0.78               0.79     0.79      0.78
# LogisticRegression                 0.83               0.79     0.79      0.83
# QuadraticDiscriminantAnalysis      0.83               0.79     0.79      0.83
# LinearDiscriminantAnalysis         0.83               0.79     0.79      0.83
# XGBClassifier                      0.83               0.75     0.75      0.81
# SGDClassifier                      0.83               0.75     0.75      0.81
# LGBMClassifier                     0.83               0.75     0.75      0.81
# CalibratedClassifierCV             0.83               0.75     0.75      0.81
# NearestCentroid                    0.72               0.71     0.71      0.73
# BaggingClassifier                  0.78               0.71     0.71      0.76
# KNeighborsClassifier               0.78               0.71     0.71      0.76
# RandomForestClassifier             0.78               0.67     0.67      0.74
# DecisionTreeClassifier             0.67               0.62     0.62      0.67
# AdaBoostClassifier                 0.72               0.62     0.62      0.69
# ExtraTreeClassifier                0.67               0.54     0.54      0.61
# BernoulliNB                        0.61               0.54     0.54      0.60
# LabelSpreading                     0.33               0.50     0.50      0.17
# LabelPropagation                   0.33               0.50     0.50      0.17
# DummyClassifier                    0.67               0.50     0.50      0.53
#
#                                Time Taken
# Model
# RidgeClassifierCV                    0.02
# RidgeClassifier                      0.01
# Perceptron                           0.01
# PassiveAggressiveClassifier          0.01
# LinearSVC                            0.02
# SVC                                  0.01
# ExtraTreesClassifier                 0.10
# NuSVC                                0.01
# GaussianNB                           0.02
# LogisticRegression                   0.03
# QuadraticDiscriminantAnalysis        0.03
# LinearDiscriminantAnalysis           0.03
# XGBClassifier                        0.06
# SGDClassifier                        0.01
# LGBMClassifier                       0.03
# CalibratedClassifierCV               0.04
# NearestCentroid                      0.01
# BaggingClassifier                    0.07
# KNeighborsClassifier                 0.01
# RandomForestClassifier               0.16
# DecisionTreeClassifier               0.02
# AdaBoostClassifier                   0.19
# ExtraTreeClassifier                  0.01
# BernoulliNB                          0.01
# LabelSpreading                       0.01
# LabelPropagation                     0.01
# DummyClassifier                      0.01
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# RidgeClassifierCV                  0.94               0.96     0.96      0.95
# RidgeClassifier                    0.89               0.92     0.92      0.89
# Perceptron                         0.89               0.88     0.87      0.89
# PassiveAggressiveClassifier        0.89               0.88     0.87      0.89
# LinearSVC                          0.89               0.83     0.83      0.88
# SVC                                0.89               0.83     0.83      0.88
# ExtraTreesClassifier               0.89               0.83     0.83      0.88
# NuSVC                              0.89               0.83     0.83      0.88
# GaussianNB                         0.78               0.79     0.79      0.78
# LogisticRegression                 0.83               0.79     0.79      0.83
# QuadraticDiscriminantAnalysis      0.83               0.79     0.79      0.83
# LinearDiscriminantAnalysis         0.83               0.79     0.79      0.83
# XGBClassifier                      0.83               0.75     0.75      0.81
# SGDClassifier                      0.83               0.75     0.75      0.81
# LGBMClassifier                     0.83               0.75     0.75      0.81
# CalibratedClassifierCV             0.83               0.75     0.75      0.81
# NearestCentroid                    0.72               0.71     0.71      0.73
# BaggingClassifier                  0.78               0.71     0.71      0.76
# KNeighborsClassifier               0.78               0.71     0.71      0.76
# RandomForestClassifier             0.78               0.67     0.67      0.74
# DecisionTreeClassifier             0.67               0.62     0.62      0.67
# AdaBoostClassifier                 0.72               0.62     0.62      0.69
# ExtraTreeClassifier                0.67               0.54     0.54      0.61
# BernoulliNB                        0.61               0.54     0.54      0.60
# LabelSpreading                     0.33               0.50     0.50      0.17
# LabelPropagation                   0.33               0.50     0.50      0.17
# DummyClassifier                    0.67               0.50     0.50      0.53
#
#                                Time Taken
# Model
# RidgeClassifierCV                    0.02
# RidgeClassifier                      0.01
# Perceptron                           0.01
# PassiveAggressiveClassifier          0.01
# LinearSVC                            0.02
# SVC                                  0.01
# ExtraTreesClassifier                 0.10
# NuSVC                                0.01
# GaussianNB                           0.02
# LogisticRegression                   0.03
# QuadraticDiscriminantAnalysis        0.03
# LinearDiscriminantAnalysis           0.03
# XGBClassifier                        0.06
# SGDClassifier                        0.01
# LGBMClassifier                       0.03
# CalibratedClassifierCV               0.04
# NearestCentroid                      0.01
# BaggingClassifier                    0.07
# KNeighborsClassifier                 0.01
# RandomForestClassifier               0.16
# DecisionTreeClassifier               0.02
# AdaBoostClassifier                   0.19
# ExtraTreeClassifier                  0.01
# BernoulliNB                          0.01
# LabelSpreading                       0.01
# LabelPropagation                     0.01
# DummyClassifier                      0.01
# 		Fold: 2
# 'tuple' object has no attribute '__name__'
# Invalid Classifier(s)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 29/29 [00:00<00:00, 29.08it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LinearSVC                          1.00               1.00     1.00      1.00
# LogisticRegression                 1.00               1.00     1.00      1.00
# SVC                                1.00               1.00     1.00      1.00
# CalibratedClassifierCV             1.00               1.00     1.00      1.00
# SGDClassifier                      1.00               1.00     1.00      1.00
# PassiveAggressiveClassifier        1.00               1.00     1.00      1.00
# ExtraTreesClassifier               1.00               1.00     1.00      1.00
# NuSVC                              1.00               1.00     1.00      1.00
# KNeighborsClassifier               1.00               1.00     1.00      1.00
# Perceptron                         0.94               0.96     0.96      0.95
# NearestCentroid                    0.94               0.96     0.96      0.95
# LGBMClassifier                     0.94               0.96     0.96      0.95
# GaussianNB                         0.94               0.96     0.96      0.95
# BernoulliNB                        0.94               0.96     0.96      0.95
# RandomForestClassifier             0.94               0.92     0.92      0.94
# LinearDiscriminantAnalysis         0.89               0.88     0.87      0.89
# BaggingClassifier                  0.89               0.88     0.87      0.89
# RidgeClassifierCV                  0.83               0.88     0.88      0.84
# XGBClassifier                      0.89               0.88     0.87      0.89
# AdaBoostClassifier                 0.89               0.88     0.87      0.89
# ExtraTreeClassifier                0.83               0.83     0.83      0.84
# RidgeClassifier                    0.72               0.79     0.79      0.73
# DecisionTreeClassifier             0.78               0.75     0.75      0.78
# QuadraticDiscriminantAnalysis      0.56               0.54     0.54      0.57
# LabelSpreading                     0.33               0.50     0.50      0.17
# LabelPropagation                   0.33               0.50     0.50      0.17
# DummyClassifier                    0.67               0.50     0.50      0.53
#
#                                Time Taken
# Model
# LinearSVC                            0.01
# LogisticRegression                   0.02
# SVC                                  0.01
# CalibratedClassifierCV               0.04
# SGDClassifier                        0.01
# PassiveAggressiveClassifier          0.01
# ExtraTreesClassifier                 0.10
# NuSVC                                0.01
# KNeighborsClassifier                 0.01
# Perceptron                           0.01
# NearestCentroid                      0.02
# LGBMClassifier                       0.05
# GaussianNB                           0.01
# BernoulliNB                          0.01
# RandomForestClassifier               0.15
# LinearDiscriminantAnalysis           0.03
# BaggingClassifier                    0.08
# RidgeClassifierCV                    0.02
# XGBClassifier                        0.06
# AdaBoostClassifier                   0.20
# ExtraTreeClassifier                  0.01
# RidgeClassifier                      0.02
# DecisionTreeClassifier               0.02
# QuadraticDiscriminantAnalysis        0.02
# LabelSpreading                       0.01
# LabelPropagation                     0.01
# DummyClassifier                      0.01
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LinearSVC                          1.00               1.00     1.00      1.00
# LogisticRegression                 1.00               1.00     1.00      1.00
# SVC                                1.00               1.00     1.00      1.00
# CalibratedClassifierCV             1.00               1.00     1.00      1.00
# SGDClassifier                      1.00               1.00     1.00      1.00
# PassiveAggressiveClassifier        1.00               1.00     1.00      1.00
# ExtraTreesClassifier               1.00               1.00     1.00      1.00
# NuSVC                              1.00               1.00     1.00      1.00
# KNeighborsClassifier               1.00               1.00     1.00      1.00
# Perceptron                         0.94               0.96     0.96      0.95
# NearestCentroid                    0.94               0.96     0.96      0.95
# LGBMClassifier                     0.94               0.96     0.96      0.95
# GaussianNB                         0.94               0.96     0.96      0.95
# BernoulliNB                        0.94               0.96     0.96      0.95
# RandomForestClassifier             0.94               0.92     0.92      0.94
# LinearDiscriminantAnalysis         0.89               0.88     0.87      0.89
# BaggingClassifier                  0.89               0.88     0.87      0.89
# RidgeClassifierCV                  0.83               0.88     0.88      0.84
# XGBClassifier                      0.89               0.88     0.87      0.89
# AdaBoostClassifier                 0.89               0.88     0.87      0.89
# ExtraTreeClassifier                0.83               0.83     0.83      0.84
# RidgeClassifier                    0.72               0.79     0.79      0.73
# DecisionTreeClassifier             0.78               0.75     0.75      0.78
# QuadraticDiscriminantAnalysis      0.56               0.54     0.54      0.57
# LabelSpreading                     0.33               0.50     0.50      0.17
# LabelPropagation                   0.33               0.50     0.50      0.17
# DummyClassifier                    0.67               0.50     0.50      0.53
#
#                                Time Taken
# Model
# LinearSVC                            0.01
# LogisticRegression                   0.02
# SVC                                  0.01
# CalibratedClassifierCV               0.04
# SGDClassifier                        0.01
# PassiveAggressiveClassifier          0.01
# ExtraTreesClassifier                 0.10
# NuSVC                                0.01
# KNeighborsClassifier                 0.01
# Perceptron                           0.01
# NearestCentroid                      0.02
# LGBMClassifier                       0.05
# GaussianNB                           0.01
# BernoulliNB                          0.01
# RandomForestClassifier               0.15
# LinearDiscriminantAnalysis           0.03
# BaggingClassifier                    0.08
# RidgeClassifierCV                    0.02
# XGBClassifier                        0.06
# AdaBoostClassifier                   0.20
# ExtraTreeClassifier                  0.01
# RidgeClassifier                      0.02
# DecisionTreeClassifier               0.02
# QuadraticDiscriminantAnalysis        0.02
# LabelSpreading                       0.01
# LabelPropagation                     0.01
# DummyClassifier                      0.01
# 		Fold: 3
# 'tuple' object has no attribute '__name__'
# Invalid Classifier(s)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 29/29 [00:00<00:00, 29.11it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# GaussianNB                         0.94               0.96     0.96      0.95
# NearestCentroid                    0.94               0.96     0.96      0.95
# PassiveAggressiveClassifier        0.94               0.92     0.92      0.94
# LogisticRegression                 0.94               0.92     0.92      0.94
# BaggingClassifier                  0.94               0.92     0.92      0.94
# Perceptron                         0.94               0.92     0.92      0.94
# RandomForestClassifier             0.94               0.92     0.92      0.94
# AdaBoostClassifier                 0.94               0.92     0.92      0.94
# ExtraTreesClassifier               0.94               0.92     0.92      0.94
# SVC                                0.94               0.92     0.92      0.94
# XGBClassifier                      0.94               0.92     0.92      0.94
# CalibratedClassifierCV             0.94               0.92     0.92      0.94
# BernoulliNB                        0.89               0.92     0.92      0.89
# NuSVC                              0.94               0.92     0.92      0.94
# RidgeClassifierCV                  0.89               0.88     0.87      0.89
# RidgeClassifier                    0.89               0.88     0.87      0.89
# SGDClassifier                      0.89               0.88     0.87      0.89
# LinearSVC                          0.89               0.88     0.87      0.89
# ExtraTreeClassifier                0.89               0.88     0.87      0.89
# DecisionTreeClassifier             0.89               0.88     0.87      0.89
# LGBMClassifier                     0.89               0.83     0.83      0.88
# KNeighborsClassifier               0.83               0.79     0.79      0.83
# LinearDiscriminantAnalysis         0.78               0.71     0.71      0.76
# QuadraticDiscriminantAnalysis      0.61               0.58     0.58      0.62
# LabelSpreading                     0.33               0.50     0.50      0.17
# LabelPropagation                   0.33               0.50     0.50      0.17
# DummyClassifier                    0.67               0.50     0.50      0.53
#
#                                Time Taken
# Model
# GaussianNB                           0.01
# NearestCentroid                      0.01
# PassiveAggressiveClassifier          0.01
# LogisticRegression                   0.02
# BaggingClassifier                    0.08
# Perceptron                           0.01
# RandomForestClassifier               0.15
# AdaBoostClassifier                   0.20
# ExtraTreesClassifier                 0.10
# SVC                                  0.02
# XGBClassifier                        0.06
# CalibratedClassifierCV               0.04
# BernoulliNB                          0.01
# NuSVC                                0.02
# RidgeClassifierCV                    0.02
# RidgeClassifier                      0.02
# SGDClassifier                        0.01
# LinearSVC                            0.02
# ExtraTreeClassifier                  0.01
# DecisionTreeClassifier               0.02
# LGBMClassifier                       0.04
# KNeighborsClassifier                 0.01
# LinearDiscriminantAnalysis           0.03
# QuadraticDiscriminantAnalysis        0.03
# LabelSpreading                       0.01
# LabelPropagation                     0.01
# DummyClassifier                      0.01
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# GaussianNB                         0.94               0.96     0.96      0.95
# NearestCentroid                    0.94               0.96     0.96      0.95
# PassiveAggressiveClassifier        0.94               0.92     0.92      0.94
# LogisticRegression                 0.94               0.92     0.92      0.94
# BaggingClassifier                  0.94               0.92     0.92      0.94
# Perceptron                         0.94               0.92     0.92      0.94
# RandomForestClassifier             0.94               0.92     0.92      0.94
# AdaBoostClassifier                 0.94               0.92     0.92      0.94
# ExtraTreesClassifier               0.94               0.92     0.92      0.94
# SVC                                0.94               0.92     0.92      0.94
# XGBClassifier                      0.94               0.92     0.92      0.94
# CalibratedClassifierCV             0.94               0.92     0.92      0.94
# BernoulliNB                        0.89               0.92     0.92      0.89
# NuSVC                              0.94               0.92     0.92      0.94
# RidgeClassifierCV                  0.89               0.88     0.87      0.89
# RidgeClassifier                    0.89               0.88     0.87      0.89
# SGDClassifier                      0.89               0.88     0.87      0.89
# LinearSVC                          0.89               0.88     0.87      0.89
# ExtraTreeClassifier                0.89               0.88     0.87      0.89
# DecisionTreeClassifier             0.89               0.88     0.87      0.89
# LGBMClassifier                     0.89               0.83     0.83      0.88
# KNeighborsClassifier               0.83               0.79     0.79      0.83
# LinearDiscriminantAnalysis         0.78               0.71     0.71      0.76
# QuadraticDiscriminantAnalysis      0.61               0.58     0.58      0.62
# LabelSpreading                     0.33               0.50     0.50      0.17
# LabelPropagation                   0.33               0.50     0.50      0.17
# DummyClassifier                    0.67               0.50     0.50      0.53
#
#                                Time Taken
# Model
# GaussianNB                           0.01
# NearestCentroid                      0.01
# PassiveAggressiveClassifier          0.01
# LogisticRegression                   0.02
# BaggingClassifier                    0.08
# Perceptron                           0.01
# RandomForestClassifier               0.15
# AdaBoostClassifier                   0.20
# ExtraTreesClassifier                 0.10
# SVC                                  0.02
# XGBClassifier                        0.06
# CalibratedClassifierCV               0.04
# BernoulliNB                          0.01
# NuSVC                                0.02
# RidgeClassifierCV                    0.02
# RidgeClassifier                      0.02
# SGDClassifier                        0.01
# LinearSVC                            0.02
# ExtraTreeClassifier                  0.01
# DecisionTreeClassifier               0.02
# LGBMClassifier                       0.04
# KNeighborsClassifier                 0.01
# LinearDiscriminantAnalysis           0.03
# QuadraticDiscriminantAnalysis        0.03
# LabelSpreading                       0.01
# LabelPropagation                     0.01
# DummyClassifier                      0.01
# 		Fold: 4
# 'tuple' object has no attribute '__name__'
# Invalid Classifier(s)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 29/29 [00:01<00:00, 28.74it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# NearestCentroid                    0.78               0.83     0.83      0.78
# GaussianNB                         0.78               0.83     0.83      0.78
# BernoulliNB                        0.72               0.79     0.79      0.73
# PassiveAggressiveClassifier        0.78               0.79     0.79      0.78
# BaggingClassifier                  0.83               0.79     0.79      0.83
# XGBClassifier                      0.83               0.79     0.79      0.83
# RandomForestClassifier             0.83               0.79     0.79      0.83
# AdaBoostClassifier                 0.78               0.75     0.75      0.78
# SGDClassifier                      0.78               0.75     0.75      0.78
# LGBMClassifier                     0.78               0.75     0.75      0.78
# Perceptron                         0.78               0.71     0.71      0.76
# ExtraTreesClassifier               0.78               0.71     0.71      0.76
# SVC                                0.78               0.71     0.71      0.76
# NuSVC                              0.78               0.71     0.71      0.76
# LinearSVC                          0.72               0.71     0.71      0.73
# LogisticRegression                 0.72               0.67     0.67      0.72
# KNeighborsClassifier               0.72               0.67     0.67      0.72
# CalibratedClassifierCV             0.78               0.67     0.67      0.74
# RidgeClassifierCV                  0.67               0.62     0.62      0.67
# DecisionTreeClassifier             0.67               0.58     0.58      0.65
# RidgeClassifier                    0.61               0.58     0.58      0.62
# LinearDiscriminantAnalysis         0.61               0.54     0.54      0.60
# LabelSpreading                     0.33               0.50     0.50      0.17
# DummyClassifier                    0.67               0.50     0.50      0.53
# LabelPropagation                   0.33               0.50     0.50      0.17
# ExtraTreeClassifier                0.61               0.46     0.46      0.51
# QuadraticDiscriminantAnalysis      0.44               0.38     0.38      0.44
#
#                                Time Taken
# Model
# NearestCentroid                      0.01
# GaussianNB                           0.01
# BernoulliNB                          0.01
# PassiveAggressiveClassifier          0.01
# BaggingClassifier                    0.08
# XGBClassifier                        0.06
# RandomForestClassifier               0.15
# AdaBoostClassifier                   0.21
# SGDClassifier                        0.01
# LGBMClassifier                       0.04
# Perceptron                           0.01
# ExtraTreesClassifier                 0.10
# SVC                                  0.01
# NuSVC                                0.01
# LinearSVC                            0.01
# LogisticRegression                   0.03
# KNeighborsClassifier                 0.01
# CalibratedClassifierCV               0.04
# RidgeClassifierCV                    0.02
# DecisionTreeClassifier               0.02
# RidgeClassifier                      0.01
# LinearDiscriminantAnalysis           0.03
# LabelSpreading                       0.01
# DummyClassifier                      0.01
# LabelPropagation                     0.01
# ExtraTreeClassifier                  0.01
# QuadraticDiscriminantAnalysis        0.03
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# NearestCentroid                    0.78               0.83     0.83      0.78
# GaussianNB                         0.78               0.83     0.83      0.78
# BernoulliNB                        0.72               0.79     0.79      0.73
# PassiveAggressiveClassifier        0.78               0.79     0.79      0.78
# BaggingClassifier                  0.83               0.79     0.79      0.83
# XGBClassifier                      0.83               0.79     0.79      0.83
# RandomForestClassifier             0.83               0.79     0.79      0.83
# AdaBoostClassifier                 0.78               0.75     0.75      0.78
# SGDClassifier                      0.78               0.75     0.75      0.78
# LGBMClassifier                     0.78               0.75     0.75      0.78
# Perceptron                         0.78               0.71     0.71      0.76
# ExtraTreesClassifier               0.78               0.71     0.71      0.76
# SVC                                0.78               0.71     0.71      0.76
# NuSVC                              0.78               0.71     0.71      0.76
# LinearSVC                          0.72               0.71     0.71      0.73
# LogisticRegression                 0.72               0.67     0.67      0.72
# KNeighborsClassifier               0.72               0.67     0.67      0.72
# CalibratedClassifierCV             0.78               0.67     0.67      0.74
# RidgeClassifierCV                  0.67               0.62     0.62      0.67
# DecisionTreeClassifier             0.67               0.58     0.58      0.65
# RidgeClassifier                    0.61               0.58     0.58      0.62
# LinearDiscriminantAnalysis         0.61               0.54     0.54      0.60
# LabelSpreading                     0.33               0.50     0.50      0.17
# DummyClassifier                    0.67               0.50     0.50      0.53
# LabelPropagation                   0.33               0.50     0.50      0.17
# ExtraTreeClassifier                0.61               0.46     0.46      0.51
# QuadraticDiscriminantAnalysis      0.44               0.38     0.38      0.44
#
#                                Time Taken
# Model
# NearestCentroid                      0.01
# GaussianNB                           0.01
# BernoulliNB                          0.01
# PassiveAggressiveClassifier          0.01
# BaggingClassifier                    0.08
# XGBClassifier                        0.06
# RandomForestClassifier               0.15
# AdaBoostClassifier                   0.21
# SGDClassifier                        0.01
# LGBMClassifier                       0.04
# Perceptron                           0.01
# ExtraTreesClassifier                 0.10
# SVC                                  0.01
# NuSVC                                0.01
# LinearSVC                            0.01
# LogisticRegression                   0.03
# KNeighborsClassifier                 0.01
# CalibratedClassifierCV               0.04
# RidgeClassifierCV                    0.02
# DecisionTreeClassifier               0.02
# RidgeClassifier                      0.01
# LinearDiscriminantAnalysis           0.03
# LabelSpreading                       0.01
# DummyClassifier                      0.01
# LabelPropagation                     0.01
# ExtraTreeClassifier                  0.01
# QuadraticDiscriminantAnalysis        0.03
# 		Fold: 5
# 'tuple' object has no attribute '__name__'
# Invalid Classifier(s)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 29/29 [00:00<00:00, 29.01it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# SVC                                0.89               0.92     0.92      0.89
# SGDClassifier                      0.89               0.92     0.92      0.89
# RidgeClassifier                    0.89               0.92     0.92      0.89
# NuSVC                              0.89               0.92     0.92      0.89
# RandomForestClassifier             0.83               0.88     0.88      0.84
# GaussianNB                         0.83               0.88     0.88      0.84
# Perceptron                         0.83               0.88     0.88      0.84
# AdaBoostClassifier                 0.83               0.83     0.83      0.84
# DecisionTreeClassifier             0.83               0.83     0.83      0.84
# NearestCentroid                    0.78               0.83     0.83      0.78
# RidgeClassifierCV                  0.78               0.83     0.83      0.78
# LinearSVC                          0.78               0.83     0.83      0.78
# BernoulliNB                        0.78               0.83     0.83      0.78
# BaggingClassifier                  0.78               0.79     0.79      0.78
# LogisticRegression                 0.78               0.79     0.79      0.78
# CalibratedClassifierCV             0.83               0.79     0.79      0.83
# LinearDiscriminantAnalysis         0.78               0.75     0.75      0.78
# PassiveAggressiveClassifier        0.72               0.75     0.75      0.73
# ExtraTreesClassifier               0.78               0.75     0.75      0.78
# XGBClassifier                      0.72               0.71     0.71      0.73
# KNeighborsClassifier               0.72               0.67     0.67      0.72
# ExtraTreeClassifier                0.67               0.67     0.67      0.68
# LGBMClassifier                     0.67               0.67     0.67      0.68
# LabelSpreading                     0.33               0.50     0.50      0.17
# LabelPropagation                   0.33               0.50     0.50      0.17
# DummyClassifier                    0.67               0.50     0.50      0.53
# QuadraticDiscriminantAnalysis      0.50               0.46     0.46      0.51
#
#                                Time Taken
# Model
# SVC                                  0.01
# SGDClassifier                        0.01
# RidgeClassifier                      0.01
# NuSVC                                0.01
# RandomForestClassifier               0.15
# GaussianNB                           0.01
# Perceptron                           0.01
# AdaBoostClassifier                   0.20
# DecisionTreeClassifier               0.02
# NearestCentroid                      0.01
# RidgeClassifierCV                    0.02
# LinearSVC                            0.01
# BernoulliNB                          0.01
# BaggingClassifier                    0.08
# LogisticRegression                   0.03
# CalibratedClassifierCV               0.04
# LinearDiscriminantAnalysis           0.03
# PassiveAggressiveClassifier          0.01
# ExtraTreesClassifier                 0.10
# XGBClassifier                        0.05
# KNeighborsClassifier                 0.01
# ExtraTreeClassifier                  0.01
# LGBMClassifier                       0.05
# LabelSpreading                       0.01
# LabelPropagation                     0.01
# DummyClassifier                      0.01
# QuadraticDiscriminantAnalysis        0.03
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# SVC                                0.89               0.92     0.92      0.89
# SGDClassifier                      0.89               0.92     0.92      0.89
# RidgeClassifier                    0.89               0.92     0.92      0.89
# NuSVC                              0.89               0.92     0.92      0.89
# RandomForestClassifier             0.83               0.88     0.88      0.84
# GaussianNB                         0.83               0.88     0.88      0.84
# Perceptron                         0.83               0.88     0.88      0.84
# AdaBoostClassifier                 0.83               0.83     0.83      0.84
# DecisionTreeClassifier             0.83               0.83     0.83      0.84
# NearestCentroid                    0.78               0.83     0.83      0.78
# RidgeClassifierCV                  0.78               0.83     0.83      0.78
# LinearSVC                          0.78               0.83     0.83      0.78
# BernoulliNB                        0.78               0.83     0.83      0.78
# BaggingClassifier                  0.78               0.79     0.79      0.78
# LogisticRegression                 0.78               0.79     0.79      0.78
# CalibratedClassifierCV             0.83               0.79     0.79      0.83
# LinearDiscriminantAnalysis         0.78               0.75     0.75      0.78
# PassiveAggressiveClassifier        0.72               0.75     0.75      0.73
# ExtraTreesClassifier               0.78               0.75     0.75      0.78
# XGBClassifier                      0.72               0.71     0.71      0.73
# KNeighborsClassifier               0.72               0.67     0.67      0.72
# ExtraTreeClassifier                0.67               0.67     0.67      0.68
# LGBMClassifier                     0.67               0.67     0.67      0.68
# LabelSpreading                     0.33               0.50     0.50      0.17
# LabelPropagation                   0.33               0.50     0.50      0.17
# DummyClassifier                    0.67               0.50     0.50      0.53
# QuadraticDiscriminantAnalysis      0.50               0.46     0.46      0.51
#
#                                Time Taken
# Model
# SVC                                  0.01
# SGDClassifier                        0.01
# RidgeClassifier                      0.01
# NuSVC                                0.01
# RandomForestClassifier               0.15
# GaussianNB                           0.01
# Perceptron                           0.01
# AdaBoostClassifier                   0.20
# DecisionTreeClassifier               0.02
# NearestCentroid                      0.01
# RidgeClassifierCV                    0.02
# LinearSVC                            0.01
# BernoulliNB                          0.01
# BaggingClassifier                    0.08
# LogisticRegression                   0.03
# CalibratedClassifierCV               0.04
# LinearDiscriminantAnalysis           0.03
# PassiveAggressiveClassifier          0.01
# ExtraTreesClassifier                 0.10
# XGBClassifier                        0.05
# KNeighborsClassifier                 0.01
# ExtraTreeClassifier                  0.01
# LGBMClassifier                       0.05
# LabelSpreading                       0.01
# LabelPropagation                     0.01
# DummyClassifier                      0.01
# QuadraticDiscriminantAnalysis        0.03
# 		Fold: 6
# 'tuple' object has no attribute '__name__'
# Invalid Classifier(s)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 29/29 [00:01<00:00, 28.45it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# AdaBoostClassifier                 1.00               1.00     1.00      1.00
# LogisticRegression                 1.00               1.00     1.00      1.00
# PassiveAggressiveClassifier        1.00               1.00     1.00      1.00
# GaussianNB                         0.94               0.96     0.96      0.95
# SVC                                0.94               0.92     0.92      0.94
# RandomForestClassifier             0.94               0.92     0.92      0.94
# NuSVC                              0.94               0.92     0.92      0.94
# NearestCentroid                    0.89               0.92     0.92      0.89
# Perceptron                         0.89               0.88     0.87      0.89
# LinearSVC                          0.83               0.83     0.83      0.84
# LGBMClassifier                     0.89               0.83     0.83      0.88
# XGBClassifier                      0.89               0.83     0.83      0.88
# KNeighborsClassifier               0.89               0.83     0.83      0.88
# ExtraTreesClassifier               0.89               0.83     0.83      0.88
# SGDClassifier                      0.89               0.83     0.83      0.88
# BaggingClassifier                  0.83               0.79     0.79      0.83
# BernoulliNB                        0.78               0.75     0.75      0.78
# RidgeClassifierCV                  0.83               0.75     0.75      0.81
# RidgeClassifier                    0.83               0.75     0.75      0.81
# CalibratedClassifierCV             0.78               0.67     0.67      0.74
# DecisionTreeClassifier             0.72               0.62     0.62      0.69
# QuadraticDiscriminantAnalysis      0.56               0.62     0.62      0.56
# ExtraTreeClassifier                0.67               0.62     0.62      0.67
# LinearDiscriminantAnalysis         0.67               0.58     0.58      0.65
# LabelSpreading                     0.33               0.50     0.50      0.17
# DummyClassifier                    0.67               0.50     0.50      0.53
# LabelPropagation                   0.33               0.50     0.50      0.17
#
#                                Time Taken
# Model
# AdaBoostClassifier                   0.21
# LogisticRegression                   0.03
# PassiveAggressiveClassifier          0.01
# GaussianNB                           0.01
# SVC                                  0.01
# RandomForestClassifier               0.15
# NuSVC                                0.01
# NearestCentroid                      0.01
# Perceptron                           0.01
# LinearSVC                            0.02
# LGBMClassifier                       0.03
# XGBClassifier                        0.06
# KNeighborsClassifier                 0.01
# ExtraTreesClassifier                 0.10
# ...
# CalibratedClassifierCV               0.04
# SVC                                  0.01
# NuSVC                                0.01
# LogisticRegression                   0.02
# LinearSVC                            0.02
# ExtraTreesClassifier                 0.10
# GaussianNB                           0.01
# SGDClassifier                        0.01
# XGBClassifier                        0.06
# LinearDiscriminantAnalysis           0.02
# PassiveAggressiveClassifier          0.01
# Perceptron                           0.01
# DecisionTreeClassifier               0.02
# NearestCentroid                      0.02
# BernoulliNB                          0.01
# RandomForestClassifier               0.15
# ExtraTreeClassifier                  0.01
# BaggingClassifier                    0.07
# QuadraticDiscriminantAnalysis        0.03
# AdaBoostClassifier                   0.20
# LGBMClassifier                       0.05
# LabelSpreading                       0.01
# LabelPropagation                     0.01
# DummyClassifier                      0.01
# 		Fold: 8
# 'tuple' object has no attribute '__name__'
# Invalid Classifier(s)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 29/29 [00:01<00:00, 28.68it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# Perceptron                         0.89               0.92     0.92      0.89
# LinearDiscriminantAnalysis         0.89               0.92     0.92      0.89
# BernoulliNB                        0.83               0.88     0.88      0.84
# DecisionTreeClassifier             0.83               0.88     0.88      0.84
# GaussianNB                         0.83               0.88     0.88      0.84
# LinearSVC                          0.83               0.83     0.83      0.84
# LogisticRegression                 0.83               0.83     0.83      0.84
# SVC                                0.83               0.83     0.83      0.84
# SGDClassifier                      0.83               0.83     0.83      0.84
# RandomForestClassifier             0.83               0.83     0.83      0.84
# NuSVC                              0.83               0.83     0.83      0.84
# CalibratedClassifierCV             0.89               0.83     0.83      0.88
# NearestCentroid                    0.78               0.83     0.83      0.78
# PassiveAggressiveClassifier        0.78               0.79     0.79      0.78
# LGBMClassifier                     0.78               0.79     0.79      0.78
# KNeighborsClassifier               0.83               0.79     0.79      0.83
# RidgeClassifier                    0.78               0.75     0.75      0.78
# ExtraTreeClassifier                0.78               0.75     0.75      0.78
# XGBClassifier                      0.78               0.75     0.75      0.78
# BaggingClassifier                  0.72               0.71     0.71      0.73
# ExtraTreesClassifier               0.72               0.71     0.71      0.73
# RidgeClassifierCV                  0.72               0.71     0.71      0.73
# AdaBoostClassifier                 0.72               0.71     0.71      0.73
# LabelSpreading                     0.33               0.50     0.50      0.17
# LabelPropagation                   0.33               0.50     0.50      0.17
# DummyClassifier                    0.67               0.50     0.50      0.53
# QuadraticDiscriminantAnalysis      0.39               0.46     0.46      0.38
#
#                                Time Taken
# Model
# Perceptron                           0.01
# LinearDiscriminantAnalysis           0.03
# BernoulliNB                          0.01
# DecisionTreeClassifier               0.02
# GaussianNB                           0.01
# LinearSVC                            0.02
# LogisticRegression                   0.03
# SVC                                  0.01
# SGDClassifier                        0.01
# RandomForestClassifier               0.15
# NuSVC                                0.01
# CalibratedClassifierCV               0.04
# NearestCentroid                      0.01
# PassiveAggressiveClassifier          0.01
# LGBMClassifier                       0.04
# KNeighborsClassifier                 0.01
# RidgeClassifier                      0.01
# ExtraTreeClassifier                  0.01
# XGBClassifier                        0.06
# BaggingClassifier                    0.08
# ExtraTreesClassifier                 0.10
# RidgeClassifierCV                    0.02
# AdaBoostClassifier                   0.20
# LabelSpreading                       0.01
# LabelPropagation                     0.01
# DummyClassifier                      0.01
# QuadraticDiscriminantAnalysis        0.03
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# Perceptron                         0.89               0.92     0.92      0.89
# LinearDiscriminantAnalysis         0.89               0.92     0.92      0.89
# BernoulliNB                        0.83               0.88     0.88      0.84
# DecisionTreeClassifier             0.83               0.88     0.88      0.84
# GaussianNB                         0.83               0.88     0.88      0.84
# LinearSVC                          0.83               0.83     0.83      0.84
# LogisticRegression                 0.83               0.83     0.83      0.84
# SVC                                0.83               0.83     0.83      0.84
# SGDClassifier                      0.83               0.83     0.83      0.84
# RandomForestClassifier             0.83               0.83     0.83      0.84
# NuSVC                              0.83               0.83     0.83      0.84
# CalibratedClassifierCV             0.89               0.83     0.83      0.88
# NearestCentroid                    0.78               0.83     0.83      0.78
# PassiveAggressiveClassifier        0.78               0.79     0.79      0.78
# LGBMClassifier                     0.78               0.79     0.79      0.78
# KNeighborsClassifier               0.83               0.79     0.79      0.83
# RidgeClassifier                    0.78               0.75     0.75      0.78
# ExtraTreeClassifier                0.78               0.75     0.75      0.78
# XGBClassifier                      0.78               0.75     0.75      0.78
# BaggingClassifier                  0.72               0.71     0.71      0.73
# ExtraTreesClassifier               0.72               0.71     0.71      0.73
# RidgeClassifierCV                  0.72               0.71     0.71      0.73
# AdaBoostClassifier                 0.72               0.71     0.71      0.73
# LabelSpreading                     0.33               0.50     0.50      0.17
# LabelPropagation                   0.33               0.50     0.50      0.17
# DummyClassifier                    0.67               0.50     0.50      0.53
# QuadraticDiscriminantAnalysis      0.39               0.46     0.46      0.38
#
#                                Time Taken
# Model
# Perceptron                           0.01
# LinearDiscriminantAnalysis           0.03
# BernoulliNB                          0.01
# DecisionTreeClassifier               0.02
# GaussianNB                           0.01
# LinearSVC                            0.02
# LogisticRegression                   0.03
# SVC                                  0.01
# SGDClassifier                        0.01
# RandomForestClassifier               0.15
# NuSVC                                0.01
# CalibratedClassifierCV               0.04
# NearestCentroid                      0.01
# PassiveAggressiveClassifier          0.01
# LGBMClassifier                       0.04
# KNeighborsClassifier                 0.01
# RidgeClassifier                      0.01
# ExtraTreeClassifier                  0.01
# XGBClassifier                        0.06
# BaggingClassifier                    0.08
# ExtraTreesClassifier                 0.10
# RidgeClassifierCV                    0.02
# AdaBoostClassifier                   0.20
# LabelSpreading                       0.01
# LabelPropagation                     0.01
# DummyClassifier                      0.01
# QuadraticDiscriminantAnalysis        0.03
# 		Fold: 9
# 'tuple' object has no attribute '__name__'
# Invalid Classifier(s)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 29/29 [00:01<00:00, 28.84it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# AdaBoostClassifier                 1.00               1.00     1.00      1.00
# NuSVC                              1.00               1.00     1.00      1.00
# XGBClassifier                      1.00               1.00     1.00      1.00
# SVC                                1.00               1.00     1.00      1.00
# LGBMClassifier                     1.00               1.00     1.00      1.00
# DecisionTreeClassifier             0.92               0.95     0.95      0.93
# LogisticRegression                 0.92               0.95     0.95      0.93
# CalibratedClassifierCV             0.92               0.95     0.95      0.93
# SGDClassifier                      0.92               0.95     0.95      0.93
# RidgeClassifierCV                  0.92               0.95     0.95      0.93
# RidgeClassifier                    0.92               0.95     0.95      0.93
# NearestCentroid                    0.92               0.95     0.95      0.93
# LinearSVC                          0.92               0.95     0.95      0.93
# KNeighborsClassifier               0.92               0.95     0.95      0.93
# GaussianNB                         0.92               0.95     0.95      0.93
# PassiveAggressiveClassifier        0.85               0.91     0.91      0.86
# Perceptron                         0.85               0.91     0.91      0.86
# ExtraTreeClassifier                0.77               0.86     0.86      0.80
# BernoulliNB                        0.92               0.75     0.75      0.91
# BaggingClassifier                  0.85               0.70     0.70      0.85
# RandomForestClassifier             0.85               0.70     0.70      0.85
# ExtraTreesClassifier               0.85               0.70     0.70      0.85
# LinearDiscriminantAnalysis         0.69               0.61     0.61      0.73
# LabelSpreading                     0.15               0.50     0.50      0.04
# LabelPropagation                   0.15               0.50     0.50      0.04
# DummyClassifier                    0.85               0.50     0.50      0.78
# QuadraticDiscriminantAnalysis      0.46               0.48     0.48      0.53
#
#                                Time Taken
# Model
# AdaBoostClassifier                   0.20
# NuSVC                                0.01
# XGBClassifier                        0.05
# SVC                                  0.01
# LGBMClassifier                       0.05
# DecisionTreeClassifier               0.02
# LogisticRegression                   0.03
# CalibratedClassifierCV               0.04
# SGDClassifier                        0.02
# RidgeClassifierCV                    0.02
# RidgeClassifier                      0.02
# NearestCentroid                      0.01
# LinearSVC                            0.01
# KNeighborsClassifier                 0.01
# GaussianNB                           0.01
# PassiveAggressiveClassifier          0.01
# Perceptron                           0.01
# ExtraTreeClassifier                  0.01
# BernoulliNB                          0.01
# BaggingClassifier                    0.08
# RandomForestClassifier               0.14
# ExtraTreesClassifier                 0.10
# LinearDiscriminantAnalysis           0.03
# LabelSpreading                       0.01
# LabelPropagation                     0.01
# DummyClassifier                      0.01
# QuadraticDiscriminantAnalysis        0.03
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# AdaBoostClassifier                 1.00               1.00     1.00      1.00
# NuSVC                              1.00               1.00     1.00      1.00
# XGBClassifier                      1.00               1.00     1.00      1.00
# SVC                                1.00               1.00     1.00      1.00
# LGBMClassifier                     1.00               1.00     1.00      1.00
# DecisionTreeClassifier             0.92               0.95     0.95      0.93
# LogisticRegression                 0.92               0.95     0.95      0.93
# CalibratedClassifierCV             0.92               0.95     0.95      0.93
# SGDClassifier                      0.92               0.95     0.95      0.93
# RidgeClassifierCV                  0.92               0.95     0.95      0.93
# RidgeClassifier                    0.92               0.95     0.95      0.93
# NearestCentroid                    0.92               0.95     0.95      0.93
# LinearSVC                          0.92               0.95     0.95      0.93
# KNeighborsClassifier               0.92               0.95     0.95      0.93
# GaussianNB                         0.92               0.95     0.95      0.93
# PassiveAggressiveClassifier        0.85               0.91     0.91      0.86
# Perceptron                         0.85               0.91     0.91      0.86
# ExtraTreeClassifier                0.77               0.86     0.86      0.80
# BernoulliNB                        0.92               0.75     0.75      0.91
# BaggingClassifier                  0.85               0.70     0.70      0.85
# RandomForestClassifier             0.85               0.70     0.70      0.85
# ExtraTreesClassifier               0.85               0.70     0.70      0.85
# LinearDiscriminantAnalysis         0.69               0.61     0.61      0.73
# LabelSpreading                     0.15               0.50     0.50      0.04
# LabelPropagation                   0.15               0.50     0.50      0.04
# DummyClassifier                    0.85               0.50     0.50      0.78
# QuadraticDiscriminantAnalysis      0.46               0.48     0.48      0.53
#
#                                Time Taken
# Model
# AdaBoostClassifier                   0.20
# NuSVC                                0.01
# XGBClassifier                        0.05
# SVC                                  0.01
# LGBMClassifier                       0.05
# DecisionTreeClassifier               0.02
# LogisticRegression                   0.03
# CalibratedClassifierCV               0.04
# SGDClassifier                        0.02
# RidgeClassifierCV                    0.02
# RidgeClassifier                      0.02
# NearestCentroid                      0.01
# LinearSVC                            0.01
# KNeighborsClassifier                 0.01
# GaussianNB                           0.01
# PassiveAggressiveClassifier          0.01
# Perceptron                           0.01
# ExtraTreeClassifier                  0.01
# BernoulliNB                          0.01
# BaggingClassifier                    0.08
# RandomForestClassifier               0.14
# ExtraTreesClassifier                 0.10
# LinearDiscriminantAnalysis           0.03
# LabelSpreading                       0.01
# LabelPropagation                     0.01
# DummyClassifier                      0.01
# QuadraticDiscriminantAnalysis        0.03
