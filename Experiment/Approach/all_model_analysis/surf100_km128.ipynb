# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from random import randint
import math
from datetime import datetime
import pickle

import lazypredict
from lazypredict.Supervised import LazyClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import roc_curve
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_curve
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score

# %%
os.getcwd()
# Out:
# 'D:\\Github\\Stomach-Status-Classification\\Experiment\\Approach\\all_model_analysis'

# %%
for i in range(3):
    os.chdir("..")

# %%
os.getcwd()
# Out:
# 'D:\\Github\\Stomach-Status-Classification'

# %%
main_data_dir = os.getcwd() + "\\Data set"
kmean_data_dir = main_data_dir + "\\kmean_dataset"
kmean_data_10cv_dir = kmean_data_dir + "\\10cv_128"
import glob

kmean_data_10cv_lst = [x for x in glob.glob(kmean_data_10cv_dir + '\\*') if 'surf' in x and 'index' in x and '100' in x]
print(kmean_data_10cv_lst)
# Out:
# ['D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_test_100_4_3_True_Falsehisto_128_cv_index0.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_test_100_4_3_True_Falsehisto_128_cv_index1.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_test_100_4_3_True_Falsehisto_128_cv_index2.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_test_100_4_3_True_Falsehisto_128_cv_index3.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_test_100_4_3_True_Falsehisto_128_cv_index4.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_test_100_4_3_True_Falsehisto_128_cv_index5.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_test_100_4_3_True_Falsehisto_128_cv_index6.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_test_100_4_3_True_Falsehisto_128_cv_index7.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_test_100_4_3_True_Falsehisto_128_cv_index8.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_test_100_4_3_True_Falsehisto_128_cv_index9.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_train_100_4_3_True_Falsehisto_128_cv_index0.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_train_100_4_3_True_Falsehisto_128_cv_index1.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_train_100_4_3_True_Falsehisto_128_cv_index2.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_train_100_4_3_True_Falsehisto_128_cv_index3.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_train_100_4_3_True_Falsehisto_128_cv_index4.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_train_100_4_3_True_Falsehisto_128_cv_index5.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_train_100_4_3_True_Falsehisto_128_cv_index6.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_train_100_4_3_True_Falsehisto_128_cv_index7.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_train_100_4_3_True_Falsehisto_128_cv_index8.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_train_100_4_3_True_Falsehisto_128_cv_index9.csv']

# %%
kmean_train_paths = [x for x in kmean_data_10cv_lst if 'train' in x]
kmean_test_paths = [x for x in kmean_data_10cv_lst if 'test' in x]
print(kmean_train_paths)
print()
print(kmean_test_paths)
print(len(kmean_train_paths))
print(len(kmean_test_paths))
# Out:
# ['D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_train_100_4_3_True_Falsehisto_128_cv_index0.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_train_100_4_3_True_Falsehisto_128_cv_index1.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_train_100_4_3_True_Falsehisto_128_cv_index2.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_train_100_4_3_True_Falsehisto_128_cv_index3.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_train_100_4_3_True_Falsehisto_128_cv_index4.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_train_100_4_3_True_Falsehisto_128_cv_index5.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_train_100_4_3_True_Falsehisto_128_cv_index6.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_train_100_4_3_True_Falsehisto_128_cv_index7.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_train_100_4_3_True_Falsehisto_128_cv_index8.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_train_100_4_3_True_Falsehisto_128_cv_index9.csv']
#
# ['D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_test_100_4_3_True_Falsehisto_128_cv_index0.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_test_100_4_3_True_Falsehisto_128_cv_index1.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_test_100_4_3_True_Falsehisto_128_cv_index2.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_test_100_4_3_True_Falsehisto_128_cv_index3.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_test_100_4_3_True_Falsehisto_128_cv_index4.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_test_100_4_3_True_Falsehisto_128_cv_index5.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_test_100_4_3_True_Falsehisto_128_cv_index6.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_test_100_4_3_True_Falsehisto_128_cv_index7.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_test_100_4_3_True_Falsehisto_128_cv_index8.csv', 'D:\\Github\\Stomach-Status-Classification\\Data set\\kmean_dataset\\10cv_128\\surf_test_100_4_3_True_Falsehisto_128_cv_index9.csv']
# 10
# 10

# %%
clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric = None)

# %%
count = 0
for train_index, test_index in zip(kmean_train_paths, kmean_test_paths):
    print("\t\tFold: {}".format(count))
    train_df, test_df = pd.read_csv(train_index), pd.read_csv(test_index)
    
    x_train, y_train = train_df.iloc[:, 2:-1], train_df.iloc[:, -1]
    x_test, y_test = test_df.iloc[:, 2:-1], test_df.iloc[:, -1]
    
    models, predictions = clf.fit(x_train, x_test, y_train, y_test)
    
    print(models)
    print(predictions)
    count += 1
# Out:
# 		Fold: 0
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 29/29 [00:01<00:00, 19.56it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# ExtraTreesClassifier               0.94               0.96     0.96      0.95
# AdaBoostClassifier                 0.89               0.92     0.92      0.89
# RandomForestClassifier             0.89               0.88     0.87      0.89
# NuSVC                              0.83               0.88     0.88      0.84
# NearestCentroid                    0.89               0.88     0.87      0.89
# GaussianNB                         0.83               0.88     0.88      0.84
# LGBMClassifier                     0.83               0.83     0.83      0.84
# BernoulliNB                        0.83               0.83     0.83      0.84
# SVC                                0.78               0.79     0.79      0.78
# LogisticRegression                 0.83               0.79     0.79      0.83
# XGBClassifier                      0.78               0.75     0.75      0.78
# RidgeClassifierCV                  0.78               0.75     0.75      0.78
# ExtraTreeClassifier                0.72               0.71     0.71      0.73
# CalibratedClassifierCV             0.78               0.71     0.71      0.76
# QuadraticDiscriminantAnalysis      0.72               0.71     0.71      0.73
# PassiveAggressiveClassifier        0.72               0.71     0.71      0.73
# DecisionTreeClassifier             0.72               0.71     0.71      0.73
# LinearSVC                          0.72               0.71     0.71      0.73
# SGDClassifier                      0.72               0.67     0.67      0.72
# RidgeClassifier                    0.67               0.67     0.67      0.68
# KNeighborsClassifier               0.78               0.67     0.67      0.74
# Perceptron                         0.67               0.62     0.62      0.67
# BaggingClassifier                  0.72               0.62     0.62      0.69
# LinearDiscriminantAnalysis         0.56               0.54     0.54      0.57
# LabelSpreading                     0.39               0.54     0.54      0.28
# LabelPropagation                   0.39               0.54     0.54      0.28
# DummyClassifier                    0.67               0.50     0.50      0.53
#
#                                Time Taken
# Model
# ExtraTreesClassifier                 0.10
# AdaBoostClassifier                   0.22
# RandomForestClassifier               0.13
# NuSVC                                0.01
# NearestCentroid                      0.02
# GaussianNB                           0.01
# LGBMClassifier                       0.05
# BernoulliNB                          0.04
# SVC                                  0.01
# LogisticRegression                   0.11
# XGBClassifier                        0.04
# RidgeClassifierCV                    0.02
# ExtraTreeClassifier                  0.01
# CalibratedClassifierCV               0.11
# QuadraticDiscriminantAnalysis        0.07
# PassiveAggressiveClassifier          0.05
# DecisionTreeClassifier               0.02
# LinearSVC                            0.01
# SGDClassifier                        0.02
# RidgeClassifier                      0.05
# KNeighborsClassifier                 0.14
# Perceptron                           0.01
# BaggingClassifier                    0.07
# LinearDiscriminantAnalysis           0.12
# LabelSpreading                       0.01
# LabelPropagation                     0.01
# DummyClassifier                      0.01
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# ExtraTreesClassifier               0.94               0.96     0.96      0.95
# AdaBoostClassifier                 0.89               0.92     0.92      0.89
# RandomForestClassifier             0.89               0.88     0.87      0.89
# NuSVC                              0.83               0.88     0.88      0.84
# NearestCentroid                    0.89               0.88     0.87      0.89
# GaussianNB                         0.83               0.88     0.88      0.84
# LGBMClassifier                     0.83               0.83     0.83      0.84
# BernoulliNB                        0.83               0.83     0.83      0.84
# SVC                                0.78               0.79     0.79      0.78
# LogisticRegression                 0.83               0.79     0.79      0.83
# XGBClassifier                      0.78               0.75     0.75      0.78
# RidgeClassifierCV                  0.78               0.75     0.75      0.78
# ExtraTreeClassifier                0.72               0.71     0.71      0.73
# CalibratedClassifierCV             0.78               0.71     0.71      0.76
# QuadraticDiscriminantAnalysis      0.72               0.71     0.71      0.73
# PassiveAggressiveClassifier        0.72               0.71     0.71      0.73
# DecisionTreeClassifier             0.72               0.71     0.71      0.73
# LinearSVC                          0.72               0.71     0.71      0.73
# SGDClassifier                      0.72               0.67     0.67      0.72
# RidgeClassifier                    0.67               0.67     0.67      0.68
# KNeighborsClassifier               0.78               0.67     0.67      0.74
# Perceptron                         0.67               0.62     0.62      0.67
# BaggingClassifier                  0.72               0.62     0.62      0.69
# LinearDiscriminantAnalysis         0.56               0.54     0.54      0.57
# LabelSpreading                     0.39               0.54     0.54      0.28
# LabelPropagation                   0.39               0.54     0.54      0.28
# DummyClassifier                    0.67               0.50     0.50      0.53
#
#                                Time Taken
# Model
# ExtraTreesClassifier                 0.10
# AdaBoostClassifier                   0.22
# RandomForestClassifier               0.13
# NuSVC                                0.01
# NearestCentroid                      0.02
# GaussianNB                           0.01
# LGBMClassifier                       0.05
# BernoulliNB                          0.04
# SVC                                  0.01
# LogisticRegression                   0.11
# XGBClassifier                        0.04
# RidgeClassifierCV                    0.02
# ExtraTreeClassifier                  0.01
# CalibratedClassifierCV               0.11
# QuadraticDiscriminantAnalysis        0.07
# PassiveAggressiveClassifier          0.05
# DecisionTreeClassifier               0.02
# LinearSVC                            0.01
# SGDClassifier                        0.02
# RidgeClassifier                      0.05
# KNeighborsClassifier                 0.14
# Perceptron                           0.01
# BaggingClassifier                    0.07
# LinearDiscriminantAnalysis           0.12
# LabelSpreading                       0.01
# LabelPropagation                     0.01
# DummyClassifier                      0.01
# 		Fold: 1
# 'tuple' object has no attribute '__name__'
# Invalid Classifier(s)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 29/29 [00:00<00:00, 39.52it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# BernoulliNB                        0.89               0.92     0.92      0.89
# AdaBoostClassifier                 0.89               0.88     0.87      0.89
# BaggingClassifier                  0.89               0.88     0.87      0.89
# XGBClassifier                      0.89               0.88     0.87      0.89
# SVC                                0.89               0.88     0.87      0.89
# RandomForestClassifier             0.89               0.88     0.87      0.89
# NuSVC                              0.89               0.88     0.87      0.89
# LGBMClassifier                     0.89               0.88     0.87      0.89
# ExtraTreesClassifier               0.89               0.88     0.87      0.89
# GaussianNB                         0.83               0.83     0.83      0.84
# NearestCentroid                    0.83               0.83     0.83      0.84
# Perceptron                         0.83               0.79     0.79      0.83
# CalibratedClassifierCV             0.83               0.75     0.75      0.81
# SGDClassifier                      0.78               0.71     0.71      0.76
# RidgeClassifierCV                  0.78               0.71     0.71      0.76
# QuadraticDiscriminantAnalysis      0.72               0.71     0.71      0.73
# LinearSVC                          0.78               0.71     0.71      0.76
# LogisticRegression                 0.78               0.71     0.71      0.76
# LinearDiscriminantAnalysis         0.78               0.71     0.71      0.76
# ExtraTreeClassifier                0.72               0.67     0.67      0.72
# PassiveAggressiveClassifier        0.72               0.67     0.67      0.72
# RidgeClassifier                    0.67               0.58     0.58      0.65
# LabelSpreading                     0.44               0.58     0.58      0.37
# DecisionTreeClassifier             0.67               0.58     0.58      0.65
# LabelPropagation                   0.44               0.58     0.58      0.37
# KNeighborsClassifier               0.67               0.54     0.54      0.61
# DummyClassifier                    0.67               0.50     0.50      0.53
#
#                                Time Taken
# Model
# BernoulliNB                          0.01
# AdaBoostClassifier                   0.12
# BaggingClassifier                    0.05
# XGBClassifier                        0.04
# SVC                                  0.02
# RandomForestClassifier               0.12
# NuSVC                                0.01
# LGBMClassifier                       0.02
# ExtraTreesClassifier                 0.08
# GaussianNB                           0.01
# NearestCentroid                      0.01
# Perceptron                           0.02
# CalibratedClassifierCV               0.02
# SGDClassifier                        0.01
# RidgeClassifierCV                    0.01
# QuadraticDiscriminantAnalysis        0.02
# LinearSVC                            0.01
# LogisticRegression                   0.01
# LinearDiscriminantAnalysis           0.02
# ExtraTreeClassifier                  0.02
# PassiveAggressiveClassifier          0.01
# RidgeClassifier                      0.02
# LabelSpreading                       0.01
# DecisionTreeClassifier               0.01
# LabelPropagation                     0.01
# KNeighborsClassifier                 0.01
# DummyClassifier                      0.01
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# BernoulliNB                        0.89               0.92     0.92      0.89
# AdaBoostClassifier                 0.89               0.88     0.87      0.89
# BaggingClassifier                  0.89               0.88     0.87      0.89
# XGBClassifier                      0.89               0.88     0.87      0.89
# SVC                                0.89               0.88     0.87      0.89
# RandomForestClassifier             0.89               0.88     0.87      0.89
# NuSVC                              0.89               0.88     0.87      0.89
# LGBMClassifier                     0.89               0.88     0.87      0.89
# ExtraTreesClassifier               0.89               0.88     0.87      0.89
# GaussianNB                         0.83               0.83     0.83      0.84
# NearestCentroid                    0.83               0.83     0.83      0.84
# Perceptron                         0.83               0.79     0.79      0.83
# CalibratedClassifierCV             0.83               0.75     0.75      0.81
# SGDClassifier                      0.78               0.71     0.71      0.76
# RidgeClassifierCV                  0.78               0.71     0.71      0.76
# QuadraticDiscriminantAnalysis      0.72               0.71     0.71      0.73
# LinearSVC                          0.78               0.71     0.71      0.76
# LogisticRegression                 0.78               0.71     0.71      0.76
# LinearDiscriminantAnalysis         0.78               0.71     0.71      0.76
# ExtraTreeClassifier                0.72               0.67     0.67      0.72
# PassiveAggressiveClassifier        0.72               0.67     0.67      0.72
# RidgeClassifier                    0.67               0.58     0.58      0.65
# LabelSpreading                     0.44               0.58     0.58      0.37
# DecisionTreeClassifier             0.67               0.58     0.58      0.65
# LabelPropagation                   0.44               0.58     0.58      0.37
# KNeighborsClassifier               0.67               0.54     0.54      0.61
# DummyClassifier                    0.67               0.50     0.50      0.53
#
#                                Time Taken
# Model
# BernoulliNB                          0.01
# AdaBoostClassifier                   0.12
# BaggingClassifier                    0.05
# XGBClassifier                        0.04
# SVC                                  0.02
# RandomForestClassifier               0.12
# NuSVC                                0.01
# LGBMClassifier                       0.02
# ExtraTreesClassifier                 0.08
# GaussianNB                           0.01
# NearestCentroid                      0.01
# Perceptron                           0.02
# CalibratedClassifierCV               0.02
# SGDClassifier                        0.01
# RidgeClassifierCV                    0.01
# QuadraticDiscriminantAnalysis        0.02
# LinearSVC                            0.01
# LogisticRegression                   0.01
# LinearDiscriminantAnalysis           0.02
# ExtraTreeClassifier                  0.02
# PassiveAggressiveClassifier          0.01
# RidgeClassifier                      0.02
# LabelSpreading                       0.01
# DecisionTreeClassifier               0.01
# LabelPropagation                     0.01
# KNeighborsClassifier                 0.01
# DummyClassifier                      0.01
# 		Fold: 2
# 'tuple' object has no attribute '__name__'
# Invalid Classifier(s)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 29/29 [00:00<00:00, 38.14it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LinearSVC                          1.00               1.00     1.00      1.00
# ExtraTreeClassifier                1.00               1.00     1.00      1.00
# PassiveAggressiveClassifier        1.00               1.00     1.00      1.00
# LogisticRegression                 1.00               1.00     1.00      1.00
# BaggingClassifier                  1.00               1.00     1.00      1.00
# LGBMClassifier                     1.00               1.00     1.00      1.00
# RandomForestClassifier             0.94               0.92     0.92      0.94
# XGBClassifier                      0.94               0.92     0.92      0.94
# SVC                                0.94               0.92     0.92      0.94
# SGDClassifier                      0.94               0.92     0.92      0.94
# LinearDiscriminantAnalysis         0.94               0.92     0.92      0.94
# DecisionTreeClassifier             0.94               0.92     0.92      0.94
# CalibratedClassifierCV             0.94               0.92     0.92      0.94
# RidgeClassifierCV                  0.94               0.92     0.92      0.94
# ExtraTreesClassifier               0.94               0.92     0.92      0.94
# BernoulliNB                        0.94               0.92     0.92      0.94
# Perceptron                         0.94               0.92     0.92      0.94
# NuSVC                              0.89               0.88     0.87      0.89
# GaussianNB                         0.89               0.88     0.87      0.89
# RidgeClassifier                    0.89               0.83     0.83      0.88
# AdaBoostClassifier                 0.89               0.83     0.83      0.88
# NearestCentroid                    0.89               0.83     0.83      0.88
# KNeighborsClassifier               0.83               0.75     0.75      0.81
# LabelSpreading                     0.61               0.71     0.71      0.60
# LabelPropagation                   0.61               0.71     0.71      0.60
# QuadraticDiscriminantAnalysis      0.61               0.50     0.50      0.57
# DummyClassifier                    0.67               0.50     0.50      0.53
#
#                                Time Taken
# Model
# LinearSVC                            0.01
# ExtraTreeClassifier                  0.01
# PassiveAggressiveClassifier          0.02
# LogisticRegression                   0.01
# BaggingClassifier                    0.05
# LGBMClassifier                       0.03
# RandomForestClassifier               0.13
# XGBClassifier                        0.04
# SVC                                  0.01
# SGDClassifier                        0.01
# LinearDiscriminantAnalysis           0.03
# DecisionTreeClassifier               0.02
# CalibratedClassifierCV               0.03
# RidgeClassifierCV                    0.02
# ExtraTreesClassifier                 0.09
# BernoulliNB                          0.01
# Perceptron                           0.01
# NuSVC                                0.01
# GaussianNB                           0.01
# RidgeClassifier                      0.01
# AdaBoostClassifier                   0.13
# NearestCentroid                      0.01
# KNeighborsClassifier                 0.01
# LabelSpreading                       0.01
# LabelPropagation                     0.01
# QuadraticDiscriminantAnalysis        0.02
# DummyClassifier                      0.01
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LinearSVC                          1.00               1.00     1.00      1.00
# ExtraTreeClassifier                1.00               1.00     1.00      1.00
# PassiveAggressiveClassifier        1.00               1.00     1.00      1.00
# LogisticRegression                 1.00               1.00     1.00      1.00
# BaggingClassifier                  1.00               1.00     1.00      1.00
# LGBMClassifier                     1.00               1.00     1.00      1.00
# RandomForestClassifier             0.94               0.92     0.92      0.94
# XGBClassifier                      0.94               0.92     0.92      0.94
# SVC                                0.94               0.92     0.92      0.94
# SGDClassifier                      0.94               0.92     0.92      0.94
# LinearDiscriminantAnalysis         0.94               0.92     0.92      0.94
# DecisionTreeClassifier             0.94               0.92     0.92      0.94
# CalibratedClassifierCV             0.94               0.92     0.92      0.94
# RidgeClassifierCV                  0.94               0.92     0.92      0.94
# ExtraTreesClassifier               0.94               0.92     0.92      0.94
# BernoulliNB                        0.94               0.92     0.92      0.94
# Perceptron                         0.94               0.92     0.92      0.94
# NuSVC                              0.89               0.88     0.87      0.89
# GaussianNB                         0.89               0.88     0.87      0.89
# RidgeClassifier                    0.89               0.83     0.83      0.88
# AdaBoostClassifier                 0.89               0.83     0.83      0.88
# NearestCentroid                    0.89               0.83     0.83      0.88
# KNeighborsClassifier               0.83               0.75     0.75      0.81
# LabelSpreading                     0.61               0.71     0.71      0.60
# LabelPropagation                   0.61               0.71     0.71      0.60
# QuadraticDiscriminantAnalysis      0.61               0.50     0.50      0.57
# DummyClassifier                    0.67               0.50     0.50      0.53
#
#                                Time Taken
# Model
# LinearSVC                            0.01
# ExtraTreeClassifier                  0.01
# PassiveAggressiveClassifier          0.02
# LogisticRegression                   0.01
# BaggingClassifier                    0.05
# LGBMClassifier                       0.03
# RandomForestClassifier               0.13
# XGBClassifier                        0.04
# SVC                                  0.01
# SGDClassifier                        0.01
# LinearDiscriminantAnalysis           0.03
# DecisionTreeClassifier               0.02
# CalibratedClassifierCV               0.03
# RidgeClassifierCV                    0.02
# ExtraTreesClassifier                 0.09
# BernoulliNB                          0.01
# Perceptron                           0.01
# NuSVC                                0.01
# GaussianNB                           0.01
# RidgeClassifier                      0.01
# AdaBoostClassifier                   0.13
# NearestCentroid                      0.01
# KNeighborsClassifier                 0.01
# LabelSpreading                       0.01
# LabelPropagation                     0.01
# QuadraticDiscriminantAnalysis        0.02
# DummyClassifier                      0.01
# 		Fold: 3
# 'tuple' object has no attribute '__name__'
# Invalid Classifier(s)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 29/29 [00:00<00:00, 36.18it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LinearSVC                          0.94               0.96     0.96      0.95
# GaussianNB                         0.94               0.96     0.96      0.95
# SVC                                0.94               0.96     0.96      0.95
# SGDClassifier                      0.94               0.96     0.96      0.95
# RandomForestClassifier             0.94               0.96     0.96      0.95
# NuSVC                              0.94               0.96     0.96      0.95
# LogisticRegression                 0.94               0.96     0.96      0.95
# BaggingClassifier                  0.94               0.96     0.96      0.95
# LGBMClassifier                     0.94               0.96     0.96      0.95
# ExtraTreesClassifier               0.94               0.96     0.96      0.95
# CalibratedClassifierCV             0.94               0.96     0.96      0.95
# Perceptron                         0.89               0.92     0.92      0.89
# PassiveAggressiveClassifier        0.89               0.92     0.92      0.89
# XGBClassifier                      0.89               0.92     0.92      0.89
# BernoulliNB                        0.89               0.92     0.92      0.89
# RidgeClassifierCV                  0.89               0.92     0.92      0.89
# DecisionTreeClassifier             0.89               0.92     0.92      0.89
# AdaBoostClassifier                 0.89               0.92     0.92      0.89
# NearestCentroid                    0.89               0.92     0.92      0.89
# RidgeClassifier                    0.78               0.83     0.83      0.78
# LinearDiscriminantAnalysis         0.78               0.83     0.83      0.78
# KNeighborsClassifier               0.83               0.79     0.79      0.83
# ExtraTreeClassifier                0.67               0.62     0.62      0.67
# LabelPropagation                   0.44               0.58     0.58      0.37
# QuadraticDiscriminantAnalysis      0.44               0.58     0.58      0.37
# LabelSpreading                     0.44               0.58     0.58      0.37
# DummyClassifier                    0.67               0.50     0.50      0.53
#
#                                Time Taken
# Model
# LinearSVC                            0.02
# GaussianNB                           0.01
# SVC                                  0.01
# SGDClassifier                        0.01
# RandomForestClassifier               0.14
# NuSVC                                0.01
# LogisticRegression                   0.02
# BaggingClassifier                    0.05
# LGBMClassifier                       0.02
# ExtraTreesClassifier                 0.10
# CalibratedClassifierCV               0.03
# Perceptron                           0.01
# PassiveAggressiveClassifier          0.01
# XGBClassifier                        0.04
# BernoulliNB                          0.01
# RidgeClassifierCV                    0.02
# DecisionTreeClassifier               0.02
# AdaBoostClassifier                   0.14
# NearestCentroid                      0.01
# RidgeClassifier                      0.01
# LinearDiscriminantAnalysis           0.01
# KNeighborsClassifier                 0.01
# ExtraTreeClassifier                  0.01
# LabelPropagation                     0.01
# QuadraticDiscriminantAnalysis        0.02
# LabelSpreading                       0.01
# DummyClassifier                      0.01
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LinearSVC                          0.94               0.96     0.96      0.95
# GaussianNB                         0.94               0.96     0.96      0.95
# SVC                                0.94               0.96     0.96      0.95
# SGDClassifier                      0.94               0.96     0.96      0.95
# RandomForestClassifier             0.94               0.96     0.96      0.95
# NuSVC                              0.94               0.96     0.96      0.95
# LogisticRegression                 0.94               0.96     0.96      0.95
# BaggingClassifier                  0.94               0.96     0.96      0.95
# LGBMClassifier                     0.94               0.96     0.96      0.95
# ExtraTreesClassifier               0.94               0.96     0.96      0.95
# CalibratedClassifierCV             0.94               0.96     0.96      0.95
# Perceptron                         0.89               0.92     0.92      0.89
# PassiveAggressiveClassifier        0.89               0.92     0.92      0.89
# XGBClassifier                      0.89               0.92     0.92      0.89
# BernoulliNB                        0.89               0.92     0.92      0.89
# RidgeClassifierCV                  0.89               0.92     0.92      0.89
# DecisionTreeClassifier             0.89               0.92     0.92      0.89
# AdaBoostClassifier                 0.89               0.92     0.92      0.89
# NearestCentroid                    0.89               0.92     0.92      0.89
# RidgeClassifier                    0.78               0.83     0.83      0.78
# LinearDiscriminantAnalysis         0.78               0.83     0.83      0.78
# KNeighborsClassifier               0.83               0.79     0.79      0.83
# ExtraTreeClassifier                0.67               0.62     0.62      0.67
# LabelPropagation                   0.44               0.58     0.58      0.37
# QuadraticDiscriminantAnalysis      0.44               0.58     0.58      0.37
# LabelSpreading                     0.44               0.58     0.58      0.37
# DummyClassifier                    0.67               0.50     0.50      0.53
#
#                                Time Taken
# Model
# LinearSVC                            0.02
# GaussianNB                           0.01
# SVC                                  0.01
# SGDClassifier                        0.01
# RandomForestClassifier               0.14
# NuSVC                                0.01
# LogisticRegression                   0.02
# BaggingClassifier                    0.05
# LGBMClassifier                       0.02
# ExtraTreesClassifier                 0.10
# CalibratedClassifierCV               0.03
# Perceptron                           0.01
# PassiveAggressiveClassifier          0.01
# XGBClassifier                        0.04
# BernoulliNB                          0.01
# RidgeClassifierCV                    0.02
# DecisionTreeClassifier               0.02
# AdaBoostClassifier                   0.14
# NearestCentroid                      0.01
# RidgeClassifier                      0.01
# LinearDiscriminantAnalysis           0.01
# KNeighborsClassifier                 0.01
# ExtraTreeClassifier                  0.01
# LabelPropagation                     0.01
# QuadraticDiscriminantAnalysis        0.02
# LabelSpreading                       0.01
# DummyClassifier                      0.01
# 		Fold: 4
# 'tuple' object has no attribute '__name__'
# Invalid Classifier(s)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 29/29 [00:00<00:00, 37.28it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# XGBClassifier                      1.00               1.00     1.00      1.00
# RandomForestClassifier             1.00               1.00     1.00      1.00
# SVC                                0.94               0.96     0.96      0.95
# PassiveAggressiveClassifier        0.94               0.96     0.96      0.95
# GaussianNB                         0.94               0.96     0.96      0.95
# NuSVC                              0.94               0.96     0.96      0.95
# Perceptron                         0.89               0.92     0.92      0.89
# AdaBoostClassifier                 0.89               0.88     0.87      0.89
# LogisticRegression                 0.89               0.88     0.87      0.89
# SGDClassifier                      0.89               0.88     0.87      0.89
# NearestCentroid                    0.83               0.88     0.88      0.84
# LinearSVC                          0.89               0.88     0.87      0.89
# ExtraTreesClassifier               0.89               0.88     0.87      0.89
# DecisionTreeClassifier             0.89               0.88     0.87      0.89
# CalibratedClassifierCV             0.89               0.88     0.87      0.89
# BernoulliNB                        0.83               0.88     0.88      0.84
# LGBMClassifier                     0.89               0.88     0.87      0.89
# LinearDiscriminantAnalysis         0.83               0.83     0.83      0.84
# RidgeClassifierCV                  0.83               0.83     0.83      0.84
# RidgeClassifier                    0.78               0.79     0.79      0.78
# ExtraTreeClassifier                0.83               0.79     0.79      0.83
# BaggingClassifier                  0.78               0.75     0.75      0.78
# KNeighborsClassifier               0.78               0.71     0.71      0.76
# QuadraticDiscriminantAnalysis      0.67               0.67     0.67      0.68
# LabelSpreading                     0.39               0.54     0.54      0.28
# LabelPropagation                   0.39               0.54     0.54      0.28
# DummyClassifier                    0.67               0.50     0.50      0.53
#
#                                Time Taken
# Model
# XGBClassifier                        0.04
# RandomForestClassifier               0.13
# SVC                                  0.01
# PassiveAggressiveClassifier          0.01
# GaussianNB                           0.01
# NuSVC                                0.01
# Perceptron                           0.01
# AdaBoostClassifier                   0.14
# LogisticRegression                   0.02
# SGDClassifier                        0.01
# NearestCentroid                      0.01
# LinearSVC                            0.01
# ExtraTreesClassifier                 0.09
# DecisionTreeClassifier               0.01
# CalibratedClassifierCV               0.03
# BernoulliNB                          0.01
# LGBMClassifier                       0.03
# LinearDiscriminantAnalysis           0.02
# RidgeClassifierCV                    0.02
# RidgeClassifier                      0.01
# ExtraTreeClassifier                  0.01
# BaggingClassifier                    0.05
# KNeighborsClassifier                 0.01
# QuadraticDiscriminantAnalysis        0.02
# LabelSpreading                       0.01
# LabelPropagation                     0.01
# DummyClassifier                      0.01
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# XGBClassifier                      1.00               1.00     1.00      1.00
# RandomForestClassifier             1.00               1.00     1.00      1.00
# SVC                                0.94               0.96     0.96      0.95
# PassiveAggressiveClassifier        0.94               0.96     0.96      0.95
# GaussianNB                         0.94               0.96     0.96      0.95
# NuSVC                              0.94               0.96     0.96      0.95
# Perceptron                         0.89               0.92     0.92      0.89
# AdaBoostClassifier                 0.89               0.88     0.87      0.89
# LogisticRegression                 0.89               0.88     0.87      0.89
# SGDClassifier                      0.89               0.88     0.87      0.89
# NearestCentroid                    0.83               0.88     0.88      0.84
# LinearSVC                          0.89               0.88     0.87      0.89
# ExtraTreesClassifier               0.89               0.88     0.87      0.89
# DecisionTreeClassifier             0.89               0.88     0.87      0.89
# CalibratedClassifierCV             0.89               0.88     0.87      0.89
# BernoulliNB                        0.83               0.88     0.88      0.84
# LGBMClassifier                     0.89               0.88     0.87      0.89
# LinearDiscriminantAnalysis         0.83               0.83     0.83      0.84
# RidgeClassifierCV                  0.83               0.83     0.83      0.84
# RidgeClassifier                    0.78               0.79     0.79      0.78
# ExtraTreeClassifier                0.83               0.79     0.79      0.83
# BaggingClassifier                  0.78               0.75     0.75      0.78
# KNeighborsClassifier               0.78               0.71     0.71      0.76
# QuadraticDiscriminantAnalysis      0.67               0.67     0.67      0.68
# LabelSpreading                     0.39               0.54     0.54      0.28
# LabelPropagation                   0.39               0.54     0.54      0.28
# DummyClassifier                    0.67               0.50     0.50      0.53
#
#                                Time Taken
# Model
# XGBClassifier                        0.04
# RandomForestClassifier               0.13
# SVC                                  0.01
# PassiveAggressiveClassifier          0.01
# GaussianNB                           0.01
# NuSVC                                0.01
# Perceptron                           0.01
# AdaBoostClassifier                   0.14
# LogisticRegression                   0.02
# SGDClassifier                        0.01
# NearestCentroid                      0.01
# LinearSVC                            0.01
# ExtraTreesClassifier                 0.09
# DecisionTreeClassifier               0.01
# CalibratedClassifierCV               0.03
# BernoulliNB                          0.01
# LGBMClassifier                       0.03
# LinearDiscriminantAnalysis           0.02
# RidgeClassifierCV                    0.02
# RidgeClassifier                      0.01
# ExtraTreeClassifier                  0.01
# BaggingClassifier                    0.05
# KNeighborsClassifier                 0.01
# QuadraticDiscriminantAnalysis        0.02
# LabelSpreading                       0.01
# LabelPropagation                     0.01
# DummyClassifier                      0.01
# 		Fold: 5
# 'tuple' object has no attribute '__name__'
# Invalid Classifier(s)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 29/29 [00:00<00:00, 37.14it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# AdaBoostClassifier                 0.94               0.96     0.96      0.95
# BaggingClassifier                  0.94               0.96     0.96      0.95
# SVC                                0.94               0.96     0.96      0.95
# RidgeClassifierCV                  0.94               0.96     0.96      0.95
# RidgeClassifier                    0.94               0.96     0.96      0.95
# RandomForestClassifier             0.94               0.96     0.96      0.95
# NuSVC                              0.94               0.96     0.96      0.95
# NearestCentroid                    0.94               0.96     0.96      0.95
# LogisticRegression                 0.94               0.96     0.96      0.95
# LGBMClassifier                     0.94               0.96     0.96      0.95
# BernoulliNB                        0.94               0.96     0.96      0.95
# GaussianNB                         0.94               0.96     0.96      0.95
# Perceptron                         0.89               0.88     0.87      0.89
# PassiveAggressiveClassifier        0.89               0.88     0.87      0.89
# XGBClassifier                      0.89               0.88     0.87      0.89
# SGDClassifier                      0.89               0.88     0.87      0.89
# CalibratedClassifierCV             0.89               0.88     0.87      0.89
# LinearSVC                          0.89               0.88     0.87      0.89
# ExtraTreeClassifier                0.89               0.88     0.87      0.89
# ExtraTreesClassifier               0.89               0.88     0.87      0.89
# LinearDiscriminantAnalysis         0.78               0.83     0.83      0.78
# DecisionTreeClassifier             0.83               0.79     0.79      0.83
# LabelSpreading                     0.56               0.67     0.67      0.53
# KNeighborsClassifier               0.78               0.67     0.67      0.74
# LabelPropagation                   0.56               0.67     0.67      0.53
# QuadraticDiscriminantAnalysis      0.50               0.62     0.62      0.46
# DummyClassifier                    0.67               0.50     0.50      0.53
#
#                                Time Taken
# Model
# AdaBoostClassifier                   0.13
# BaggingClassifier                    0.05
# SVC                                  0.01
# RidgeClassifierCV                    0.02
# RidgeClassifier                      0.01
# RandomForestClassifier               0.14
# NuSVC                                0.01
# NearestCentroid                      0.01
# LogisticRegression                   0.02
# LGBMClassifier                       0.03
# BernoulliNB                          0.01
# GaussianNB                           0.01
# Perceptron                           0.01
# PassiveAggressiveClassifier          0.01
# XGBClassifier                        0.04
# SGDClassifier                        0.01
# CalibratedClassifierCV               0.03
# LinearSVC                            0.01
# ExtraTreeClassifier                  0.01
# ExtraTreesClassifier                 0.10
# LinearDiscriminantAnalysis           0.02
# DecisionTreeClassifier               0.01
# LabelSpreading                       0.01
# KNeighborsClassifier                 0.01
# LabelPropagation                     0.01
# QuadraticDiscriminantAnalysis        0.02
# DummyClassifier                      0.01
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# AdaBoostClassifier                 0.94               0.96     0.96      0.95
# BaggingClassifier                  0.94               0.96     0.96      0.95
# SVC                                0.94               0.96     0.96      0.95
# RidgeClassifierCV                  0.94               0.96     0.96      0.95
# RidgeClassifier                    0.94               0.96     0.96      0.95
# RandomForestClassifier             0.94               0.96     0.96      0.95
# NuSVC                              0.94               0.96     0.96      0.95
# NearestCentroid                    0.94               0.96     0.96      0.95
# LogisticRegression                 0.94               0.96     0.96      0.95
# LGBMClassifier                     0.94               0.96     0.96      0.95
# BernoulliNB                        0.94               0.96     0.96      0.95
# GaussianNB                         0.94               0.96     0.96      0.95
# Perceptron                         0.89               0.88     0.87      0.89
# PassiveAggressiveClassifier        0.89               0.88     0.87      0.89
# XGBClassifier                      0.89               0.88     0.87      0.89
# SGDClassifier                      0.89               0.88     0.87      0.89
# CalibratedClassifierCV             0.89               0.88     0.87      0.89
# LinearSVC                          0.89               0.88     0.87      0.89
# ExtraTreeClassifier                0.89               0.88     0.87      0.89
# ExtraTreesClassifier               0.89               0.88     0.87      0.89
# LinearDiscriminantAnalysis         0.78               0.83     0.83      0.78
# DecisionTreeClassifier             0.83               0.79     0.79      0.83
# LabelSpreading                     0.56               0.67     0.67      0.53
# KNeighborsClassifier               0.78               0.67     0.67      0.74
# LabelPropagation                   0.56               0.67     0.67      0.53
# QuadraticDiscriminantAnalysis      0.50               0.62     0.62      0.46
# DummyClassifier                    0.67               0.50     0.50      0.53
#
#                                Time Taken
# Model
# AdaBoostClassifier                   0.13
# BaggingClassifier                    0.05
# SVC                                  0.01
# RidgeClassifierCV                    0.02
# RidgeClassifier                      0.01
# RandomForestClassifier               0.14
# NuSVC                                0.01
# NearestCentroid                      0.01
# LogisticRegression                   0.02
# LGBMClassifier                       0.03
# BernoulliNB                          0.01
# GaussianNB                           0.01
# Perceptron                           0.01
# PassiveAggressiveClassifier          0.01
# XGBClassifier                        0.04
# SGDClassifier                        0.01
# CalibratedClassifierCV               0.03
# LinearSVC                            0.01
# ExtraTreeClassifier                  0.01
# ExtraTreesClassifier                 0.10
# LinearDiscriminantAnalysis           0.02
# DecisionTreeClassifier               0.01
# LabelSpreading                       0.01
# KNeighborsClassifier                 0.01
# LabelPropagation                     0.01
# QuadraticDiscriminantAnalysis        0.02
# DummyClassifier                      0.01
# 		Fold: 6
# 'tuple' object has no attribute '__name__'
# Invalid Classifier(s)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 29/29 [00:00<00:00, 37.69it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# AdaBoostClassifier                 1.00               1.00     1.00      1.00
# ExtraTreesClassifier               1.00               1.00     1.00      1.00
# SGDClassifier                      0.94               0.96     0.96      0.95
# RidgeClassifierCV                  0.94               0.96     0.96      0.95
# RandomForestClassifier             0.94               0.96     0.96      0.95
# NearestCentroid                    0.94               0.96     0.96      0.95
# NuSVC                              0.89               0.92     0.92      0.89
# BernoulliNB                        0.89               0.92     0.92      0.89
# SVC                                0.89               0.92     0.92      0.89
# Perceptron                         0.89               0.92     0.92      0.89
# BaggingClassifier                  0.89               0.92     0.92      0.89
# LogisticRegression                 0.94               0.92     0.92      0.94
# CalibratedClassifierCV             0.89               0.88     0.87      0.89
# XGBClassifier                      0.89               0.88     0.87      0.89
# QuadraticDiscriminantAnalysis      0.83               0.88     0.88      0.84
# PassiveAggressiveClassifier        0.89               0.88     0.87      0.89
# LinearSVC                          0.83               0.83     0.83      0.84
# ExtraTreeClassifier                0.83               0.83     0.83      0.84
# LGBMClassifier                     0.83               0.83     0.83      0.84
# DecisionTreeClassifier             0.78               0.79     0.79      0.78
# KNeighborsClassifier               0.83               0.75     0.75      0.81
# GaussianNB                         0.78               0.75     0.75      0.78
# LinearDiscriminantAnalysis         0.72               0.67     0.67      0.72
# RidgeClassifier                    0.72               0.67     0.67      0.72
# LabelSpreading                     0.50               0.62     0.62      0.46
# LabelPropagation                   0.50               0.62     0.62      0.46
# DummyClassifier                    0.67               0.50     0.50      0.53
#
#                                Time Taken
# Model
# AdaBoostClassifier                   0.13
# ExtraTreesClassifier                 0.09
# SGDClassifier                        0.01
# RidgeClassifierCV                    0.02
# RandomForestClassifier               0.14
# NearestCentroid                      0.01
# NuSVC                                0.01
# BernoulliNB                          0.01
# SVC                                  0.01
# Perceptron                           0.01
# BaggingClassifier                    0.05
# LogisticRegression                   0.02
# CalibratedClassifierCV               0.03
# XGBClassifier                        0.04
# ...
# LGBMClassifier                       0.03
# CalibratedClassifierCV               0.03
# PassiveAggressiveClassifier          0.02
# RidgeClassifierCV                    0.02
# LogisticRegression                   0.02
# ExtraTreeClassifier                  0.01
# GaussianNB                           0.01
# LinearDiscriminantAnalysis           0.02
# Perceptron                           0.01
# RandomForestClassifier               0.13
# NearestCentroid                      0.01
# SVC                                  0.01
# SGDClassifier                        0.01
# AdaBoostClassifier                   0.12
# NuSVC                                0.01
# QuadraticDiscriminantAnalysis        0.02
# BernoulliNB                          0.00
# ExtraTreesClassifier                 0.10
# DecisionTreeClassifier               0.01
# LabelSpreading                       0.01
# LabelPropagation                     0.01
# KNeighborsClassifier                 0.01
# BaggingClassifier                    0.06
# DummyClassifier                      0.01
# 		Fold: 8
# 'tuple' object has no attribute '__name__'
# Invalid Classifier(s)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 29/29 [00:00<00:00, 38.58it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# GaussianNB                         0.94               0.96     0.96      0.95
# SVC                                0.94               0.96     0.96      0.95
# RidgeClassifierCV                  0.94               0.96     0.96      0.95
# PassiveAggressiveClassifier        0.94               0.96     0.96      0.95
# NuSVC                              0.94               0.96     0.96      0.95
# LogisticRegression                 0.94               0.96     0.96      0.95
# LinearSVC                          0.89               0.92     0.92      0.89
# RidgeClassifier                    0.94               0.92     0.92      0.94
# LGBMClassifier                     0.94               0.92     0.92      0.94
# Perceptron                         0.89               0.88     0.87      0.89
# RandomForestClassifier             0.89               0.88     0.87      0.89
# SGDClassifier                      0.89               0.88     0.87      0.89
# BaggingClassifier                  0.83               0.83     0.83      0.84
# XGBClassifier                      0.89               0.83     0.83      0.88
# LinearDiscriminantAnalysis         0.89               0.83     0.83      0.88
# ExtraTreesClassifier               0.83               0.79     0.79      0.83
# NearestCentroid                    0.83               0.79     0.79      0.83
# DecisionTreeClassifier             0.83               0.79     0.79      0.83
# CalibratedClassifierCV             0.83               0.75     0.75      0.81
# AdaBoostClassifier                 0.83               0.75     0.75      0.81
# QuadraticDiscriminantAnalysis      0.67               0.71     0.71      0.68
# ExtraTreeClassifier                0.72               0.71     0.71      0.73
# KNeighborsClassifier               0.78               0.67     0.67      0.74
# BernoulliNB                        0.67               0.62     0.62      0.67
# LabelPropagation                   0.39               0.54     0.54      0.28
# LabelSpreading                     0.39               0.54     0.54      0.28
# DummyClassifier                    0.67               0.50     0.50      0.53
#
#                                Time Taken
# Model
# GaussianNB                           0.01
# SVC                                  0.01
# RidgeClassifierCV                    0.02
# PassiveAggressiveClassifier          0.00
# NuSVC                                0.01
# LogisticRegression                   0.02
# LinearSVC                            0.01
# RidgeClassifier                      0.01
# LGBMClassifier                       0.03
# Perceptron                           0.02
# RandomForestClassifier               0.13
# SGDClassifier                        0.00
# BaggingClassifier                    0.05
# XGBClassifier                        0.03
# LinearDiscriminantAnalysis           0.02
# ExtraTreesClassifier                 0.10
# NearestCentroid                      0.01
# DecisionTreeClassifier               0.01
# CalibratedClassifierCV               0.02
# AdaBoostClassifier                   0.12
# QuadraticDiscriminantAnalysis        0.02
# ExtraTreeClassifier                  0.01
# KNeighborsClassifier                 0.01
# BernoulliNB                          0.01
# LabelPropagation                     0.01
# LabelSpreading                       0.01
# DummyClassifier                      0.01
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# GaussianNB                         0.94               0.96     0.96      0.95
# SVC                                0.94               0.96     0.96      0.95
# RidgeClassifierCV                  0.94               0.96     0.96      0.95
# PassiveAggressiveClassifier        0.94               0.96     0.96      0.95
# NuSVC                              0.94               0.96     0.96      0.95
# LogisticRegression                 0.94               0.96     0.96      0.95
# LinearSVC                          0.89               0.92     0.92      0.89
# RidgeClassifier                    0.94               0.92     0.92      0.94
# LGBMClassifier                     0.94               0.92     0.92      0.94
# Perceptron                         0.89               0.88     0.87      0.89
# RandomForestClassifier             0.89               0.88     0.87      0.89
# SGDClassifier                      0.89               0.88     0.87      0.89
# BaggingClassifier                  0.83               0.83     0.83      0.84
# XGBClassifier                      0.89               0.83     0.83      0.88
# LinearDiscriminantAnalysis         0.89               0.83     0.83      0.88
# ExtraTreesClassifier               0.83               0.79     0.79      0.83
# NearestCentroid                    0.83               0.79     0.79      0.83
# DecisionTreeClassifier             0.83               0.79     0.79      0.83
# CalibratedClassifierCV             0.83               0.75     0.75      0.81
# AdaBoostClassifier                 0.83               0.75     0.75      0.81
# QuadraticDiscriminantAnalysis      0.67               0.71     0.71      0.68
# ExtraTreeClassifier                0.72               0.71     0.71      0.73
# KNeighborsClassifier               0.78               0.67     0.67      0.74
# BernoulliNB                        0.67               0.62     0.62      0.67
# LabelPropagation                   0.39               0.54     0.54      0.28
# LabelSpreading                     0.39               0.54     0.54      0.28
# DummyClassifier                    0.67               0.50     0.50      0.53
#
#                                Time Taken
# Model
# GaussianNB                           0.01
# SVC                                  0.01
# RidgeClassifierCV                    0.02
# PassiveAggressiveClassifier          0.00
# NuSVC                                0.01
# LogisticRegression                   0.02
# LinearSVC                            0.01
# RidgeClassifier                      0.01
# LGBMClassifier                       0.03
# Perceptron                           0.02
# RandomForestClassifier               0.13
# SGDClassifier                        0.00
# BaggingClassifier                    0.05
# XGBClassifier                        0.03
# LinearDiscriminantAnalysis           0.02
# ExtraTreesClassifier                 0.10
# NearestCentroid                      0.01
# DecisionTreeClassifier               0.01
# CalibratedClassifierCV               0.02
# AdaBoostClassifier                   0.12
# QuadraticDiscriminantAnalysis        0.02
# ExtraTreeClassifier                  0.01
# KNeighborsClassifier                 0.01
# BernoulliNB                          0.01
# LabelPropagation                     0.01
# LabelSpreading                       0.01
# DummyClassifier                      0.01
# 		Fold: 9
# 'tuple' object has no attribute '__name__'
# Invalid Classifier(s)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 29/29 [00:00<00:00, 38.36it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# AdaBoostClassifier                 1.00               1.00     1.00      1.00
# LogisticRegression                 1.00               1.00     1.00      1.00
# XGBClassifier                      1.00               1.00     1.00      1.00
# SVC                                1.00               1.00     1.00      1.00
# RidgeClassifierCV                  1.00               1.00     1.00      1.00
# RandomForestClassifier             1.00               1.00     1.00      1.00
# PassiveAggressiveClassifier        1.00               1.00     1.00      1.00
# NuSVC                              1.00               1.00     1.00      1.00
# LinearSVC                          1.00               1.00     1.00      1.00
# ExtraTreesClassifier               1.00               1.00     1.00      1.00
# CalibratedClassifierCV             1.00               1.00     1.00      1.00
# GaussianNB                         1.00               1.00     1.00      1.00
# ExtraTreeClassifier                1.00               1.00     1.00      1.00
# Perceptron                         0.92               0.95     0.95      0.93
# SGDClassifier                      0.92               0.95     0.95      0.93
# DecisionTreeClassifier             0.92               0.95     0.95      0.93
# LGBMClassifier                     0.92               0.95     0.95      0.93
# BaggingClassifier                  0.92               0.95     0.95      0.93
# NearestCentroid                    0.85               0.91     0.91      0.86
# BernoulliNB                        0.85               0.91     0.91      0.86
# RidgeClassifier                    0.92               0.75     0.75      0.91
# LinearDiscriminantAnalysis         0.92               0.75     0.75      0.91
# LabelPropagation                   0.38               0.64     0.64      0.41
# LabelSpreading                     0.38               0.64     0.64      0.41
# DummyClassifier                    0.85               0.50     0.50      0.78
# KNeighborsClassifier               0.85               0.50     0.50      0.78
# QuadraticDiscriminantAnalysis      0.15               0.30     0.30      0.15
#
#                                Time Taken
# Model
# AdaBoostClassifier                   0.12
# LogisticRegression                   0.02
# XGBClassifier                        0.04
# SVC                                  0.01
# RidgeClassifierCV                    0.03
# RandomForestClassifier               0.13
# PassiveAggressiveClassifier          0.02
# NuSVC                                0.01
# LinearSVC                            0.01
# ExtraTreesClassifier                 0.09
# CalibratedClassifierCV               0.02
# GaussianNB                           0.01
# ExtraTreeClassifier                  0.01
# Perceptron                           0.01
# SGDClassifier                        0.01
# DecisionTreeClassifier               0.01
# LGBMClassifier                       0.03
# BaggingClassifier                    0.05
# NearestCentroid                      0.01
# BernoulliNB                          0.01
# RidgeClassifier                      0.01
# LinearDiscriminantAnalysis           0.02
# LabelPropagation                     0.01
# LabelSpreading                       0.01
# DummyClassifier                      0.01
# KNeighborsClassifier                 0.01
# QuadraticDiscriminantAnalysis        0.02
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# AdaBoostClassifier                 1.00               1.00     1.00      1.00
# LogisticRegression                 1.00               1.00     1.00      1.00
# XGBClassifier                      1.00               1.00     1.00      1.00
# SVC                                1.00               1.00     1.00      1.00
# RidgeClassifierCV                  1.00               1.00     1.00      1.00
# RandomForestClassifier             1.00               1.00     1.00      1.00
# PassiveAggressiveClassifier        1.00               1.00     1.00      1.00
# NuSVC                              1.00               1.00     1.00      1.00
# LinearSVC                          1.00               1.00     1.00      1.00
# ExtraTreesClassifier               1.00               1.00     1.00      1.00
# CalibratedClassifierCV             1.00               1.00     1.00      1.00
# GaussianNB                         1.00               1.00     1.00      1.00
# ExtraTreeClassifier                1.00               1.00     1.00      1.00
# Perceptron                         0.92               0.95     0.95      0.93
# SGDClassifier                      0.92               0.95     0.95      0.93
# DecisionTreeClassifier             0.92               0.95     0.95      0.93
# LGBMClassifier                     0.92               0.95     0.95      0.93
# BaggingClassifier                  0.92               0.95     0.95      0.93
# NearestCentroid                    0.85               0.91     0.91      0.86
# BernoulliNB                        0.85               0.91     0.91      0.86
# RidgeClassifier                    0.92               0.75     0.75      0.91
# LinearDiscriminantAnalysis         0.92               0.75     0.75      0.91
# LabelPropagation                   0.38               0.64     0.64      0.41
# LabelSpreading                     0.38               0.64     0.64      0.41
# DummyClassifier                    0.85               0.50     0.50      0.78
# KNeighborsClassifier               0.85               0.50     0.50      0.78
# QuadraticDiscriminantAnalysis      0.15               0.30     0.30      0.15
#
#                                Time Taken
# Model
# AdaBoostClassifier                   0.12
# LogisticRegression                   0.02
# XGBClassifier                        0.04
# SVC                                  0.01
# RidgeClassifierCV                    0.03
# RandomForestClassifier               0.13
# PassiveAggressiveClassifier          0.02
# NuSVC                                0.01
# LinearSVC                            0.01
# ExtraTreesClassifier                 0.09
# CalibratedClassifierCV               0.02
# GaussianNB                           0.01
# ExtraTreeClassifier                  0.01
# Perceptron                           0.01
# SGDClassifier                        0.01
# DecisionTreeClassifier               0.01
# LGBMClassifier                       0.03
# BaggingClassifier                    0.05
# NearestCentroid                      0.01
# BernoulliNB                          0.01
# RidgeClassifier                      0.01
# LinearDiscriminantAnalysis           0.02
# LabelPropagation                     0.01
# LabelSpreading                       0.01
# DummyClassifier                      0.01
# KNeighborsClassifier                 0.01
# QuadraticDiscriminantAnalysis        0.02
